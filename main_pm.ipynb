# %% [markdown]
# ### main_pm.ipynb – Datenextraktion & Vorverarbeitung
#
# Dieses Notebook umfasst die automatisierte Extraktion und strukturierte Vorverarbeitung der Pressemitteilungen der BVG als Grundlage für die weitere Analyse.
#
# Die zentralen Schritte:
# - Automatisiertes Webscraping und lokale Speicherung der HTML-Dateien
# - Extraktion von Veröffentlichungsdatum und weiteren Metadaten
# - Bereinigung der Inhalte mit BeautifulSoup
# - Entfernung von Stoppwörtern und Zählung der Wortfrequenzen pro Mitteilung
# - Speicherung der Ergebnisse in einer SQLite-Datenbank

# %% [markdown]
# #### 1. Import der benötigten Pakete

# %%
# Standard
import os  # Dateipfade und Dateisystem
import time  # Zeitsteuerung
import sys  # Systemfunktionen 

# Datenanalyse
import pandas as pd
import sqlite3  # Speicherung in SQLite-Datenbanken

# Webscraping mit Selenium
import undetected_chromedriver as uc # Browser automatisch steuern
from selenium.webdriver.common.by import By # Elemente auf Webseiten finden
from selenium.webdriver.common.action_chains import ActionChains # Interaktionen auf Webseiten 
from selenium.webdriver.support.ui import WebDriverWait # Warten auf Elemente
from selenium.webdriver.support import expected_conditions as EC # Bedingungen für Webscraping

# Bearbeiten von HTML-Dateien
from bs4 import BeautifulSoup  # HTML auslesen und bereinigen

# Eigene Funktionen (ausgelagert)
sys.path.append("../scripts") # Pfad zu den Funktionen
# Funktionen aus datenaufbereitung.py importieren
from datenaufbereitung import (
    load_stopwords,
    read_html_file,
    process_html
)
stopwords_list = load_stopwords()

# %%
# Pfade 

# Input 
SAVE_FOLDER = os.path.join("input", "pm_bvg_raw") # Pfad für html-Dateien

# Output
OUTPUT_FOLDER = os.path.join("output") # Ordner für Output
CSV_PATH = os.path.join("output", "pm_bvg_valid.csv") # Pfad für CSV-Datei
SQL_PATH = os.path.join(OUTPUT_FOLDER, "dwh_pm_bvg.sqlite3") # Pfad für SQL-Datenbank

# %% [markdown]
# #### 2. Scraping der BVG-Webseite (Link-Extraktion)

# %%
# Scraping starten
print("Starte Webscraping der Pressemitteilungen...")

# Browser öffnen
driver = uc.Chrome()
driver.get("https://www.bvg.de/de/unternehmen/medienportal/pressemitteilungen")
time.sleep(5)

# Cookies akzeptieren 
try:
    WebDriverWait(driver, 10).until(
        EC.presence_of_element_located((By.ID, "didomi-notice-agree-button"))
    )
    cookie_button = driver.find_element(By.ID, "didomi-notice-agree-button")

    # Klick per JavaScript 
    driver.execute_script("arguments[0].click();", cookie_button)
    print("[INFO] Cookies akzeptiert.")
    time.sleep(2)

except Exception as e:
    print(f"[ERROR] Cookie konnte nicht geklickt werden: {e}")

all_links = set()  # Leeres Set für Links
current_page = 1   # Start bei Seite 1

while True:
    print(f"[INFO] Seite {current_page}")
    time.sleep(3)

    # URLs sammeln
    links = driver.find_elements(By.CSS_SELECTOR, "a[href^='/de/unternehmen/medienportal/pressemitteilungen/']")
    for link in links:
        href = link.get_attribute("href")
        if href:
            all_links.add(href)

    try:
        # Button für nächste Seite finden und klicken
        next_page_number = str(current_page + 1)
        wait = WebDriverWait(driver, 10)
        next_button = wait.until(EC.presence_of_element_located(
            (By.XPATH, f"//button[normalize-space(text())='{next_page_number}']"))
        )

        driver.execute_script("arguments[0].scrollIntoView({block: 'center'});", next_button)
        time.sleep(1)
        ActionChains(driver).move_to_element(next_button).click().perform()

        current_page += 1
        time.sleep(4)

    except Exception as e:
        print(f"[INFO] Keine weitere Seite gefunden oder Fehler bei Seite {current_page}: {e}")
        break

# Browser schließen
driver.quit()
print(f"[INFO] Anzahl gesammelter Links: {len(all_links)}")
# Out:
# Starte Webscraping der Pressemitteilungen...
# [INFO] Cookies akzeptiert.
# [INFO] Seite 1
# [INFO] Seite 2
# [INFO] Seite 3
# [INFO] Seite 4
# [INFO] Seite 5
# [INFO] Seite 6
# [INFO] Seite 7
# [INFO] Seite 8
# [INFO] Seite 9
# [INFO] Seite 10
# [INFO] Seite 11
# [INFO] Seite 12
# [INFO] Seite 13
# [INFO] Seite 14
# [INFO] Seite 15
# [INFO] Seite 16
# [INFO] Seite 17
# [INFO] Seite 18
# [INFO] Seite 19
# [INFO] Seite 20
# [INFO] Seite 21
# [INFO] Seite 22
# [INFO] Seite 23
# [INFO] Seite 24
# [INFO] Seite 25
# [INFO] Seite 26
# [INFO] Seite 27
# [INFO] Seite 28
# [INFO] Seite 29
# [INFO] Seite 30
# [INFO] Seite 31
# [INFO] Seite 32
# [INFO] Seite 33
# [INFO] Seite 34
# [INFO] Seite 35
# [INFO] Seite 36
# [INFO] Seite 37
# [INFO] Seite 38
# [INFO] Seite 39
# [INFO] Seite 40
# [INFO] Seite 41
# [INFO] Seite 42
# [INFO] Seite 43
# [INFO] Seite 44
# [INFO] Seite 45
# [INFO] Seite 46
# [INFO] Seite 47
# [INFO] Seite 48
# [INFO] Seite 49
# [INFO] Seite 50
# [INFO] Seite 51
# [INFO] Seite 52
# [INFO] Seite 53
# [INFO] Seite 54
# [INFO] Seite 55
# [INFO] Seite 56
# [INFO] Seite 57
# [INFO] Seite 58
# [INFO] Seite 59
# [INFO] Seite 60
# [INFO] Seite 61
# [INFO] Seite 62
# [INFO] Seite 63
# [INFO] Seite 64
# [INFO] Seite 65
# [INFO] Seite 66
# [INFO] Seite 67
# [INFO] Seite 68
# [INFO] Seite 69
# [INFO] Seite 70
# [INFO] Seite 71
# [INFO] Seite 72
# [INFO] Seite 73
# [INFO] Seite 74
# [INFO] Seite 75
# [INFO] Seite 76
# [INFO] Seite 77
# [INFO] Seite 78
# [INFO] Keine weitere Seite gefunden oder Fehler bei Seite 78: Message:
# Stacktrace:
# 	GetHandleVerifier [0x0040FBD3+61635]
# 	GetHandleVerifier [0x0040FC14+61700]
# 	(No symbol) [0x002305D3]
# 	(No symbol) [0x0027899E]
# 	(No symbol) [0x00278D3B]
# 	(No symbol) [0x002C0E12]
# 	(No symbol) [0x0029D2E4]
# 	(No symbol) [0x002BE61B]
# 	(No symbol) [0x0029D096]
# 	(No symbol) [0x0026C840]
# 	(No symbol) [0x0026D6A4]
# 	GetHandleVerifier [0x00657043+2450739]
# 	GetHandleVerifier [0x006527C6+2432182]
# 	GetHandleVerifier [0x0066D50E+2542078]
# 	GetHandleVerifier [0x00426895+155013]
# 	GetHandleVerifier [0x0042CF7D+181357]
# 	GetHandleVerifier [0x00417428+92440]
# 	GetHandleVerifier [0x004175D0+92864]
# 	GetHandleVerifier [0x00401FC0+5296]
# 	BaseThreadInitThunk [0x763CFCC9+25]
# 	RtlGetAppContainerNamedObjectPath [0x77E382AE+286]
# 	RtlGetAppContainerNamedObjectPath [0x77E3827E+238]
#
# [INFO] Anzahl gesammelter Links: 936

# %%
# Prüfung
if all_links:
    print(f"\n[INFO] Es wurden {len(all_links)} Pressemitteilungen gefunden.")
    print("[INFO] Beispiel-Links:")
    for link in list(sorted(all_links))[:5]:  # Nur die ersten 5 anzeigen
        print(" -", link)
else:
    print("[WARNUNG] Es wurden keine Links gefunden!")
# Out:
# [INFO] Es wurden 936 Pressemitteilungen gefunden.
# [INFO] Beispiel-Links:
#  - https://www.bvg.de/de/unternehmen/medienportal/pressemitteilungen/10-uhr-karten-gelten-eine-stunde-frueher
#  - https://www.bvg.de/de/unternehmen/medienportal/pressemitteilungen/13-points-go-to
#  - https://www.bvg.de/de/unternehmen/medienportal/pressemitteilungen/140-jahre-unter-strom
#  - https://www.bvg.de/de/unternehmen/medienportal/pressemitteilungen/155-000-mal-5
#  - https://www.bvg.de/de/unternehmen/medienportal/pressemitteilungen/17-000-kostenlose-fahrscheine-s-bahn-berlin-und-bvg-unterstuetzen-ehrenamtliche

# %% [markdown]
# #### 3. Download und lokale Speicherung

# %%
# Driver starten
driver = uc.Chrome()

# HTML-Inhalt herunterladen
for url in all_links:
    try:
        # Dateinamen aus URL erstellen
        slug = url.strip("/").split("/")[-1]
        filename = f"{slug}.html"
        save_path = os.path.join(SAVE_FOLDER, filename)

        # Wenn schon vorhanden → überspringen
        if os.path.exists(save_path):
            print(f"[INFO] Datei schon vorhanden: {filename}")
            continue

        # Seite aufrufen und HTML holen
        driver.get(url)
        time.sleep(2)  
        content = driver.page_source.encode("utf-8")

        # Speichern
        with open(save_path, "wb") as f:
            f.write(content)
        print(f"[INFO] Gespeichert: {filename}")

    except Exception as e:
        print(f"[FEHLER] bei {url}: {e}")

        # Test: Wenn der Browser weg ist → Neustart
        try:
            _ = driver.title
        except:
            print("[NEUSTART] Browser war nicht mehr erreichbar. Neuer Versuch...")
            try:
                driver.quit()
            except:
                pass  
            driver = uc.Chrome()

# Browser schließen
driver.quit()
# Out:
# [INFO] Datei schon vorhanden: klangvoll-im-untergrund.html
# [INFO] Datei schon vorhanden: hasta-la-wista.html
# [INFO] Datei schon vorhanden: 2025-01-29-pm-bvg-muva-barrierefrei-ab-maerz-berlinweit.html
# [INFO] Datei schon vorhanden: berliner-wasserbetriebe-buddeln-der-tram-den-weg-frei.html
# [INFO] Datei schon vorhanden: aussenrum.html
# [INFO] Datei schon vorhanden: hintereinanderweg.html
# [INFO] Datei schon vorhanden: doppeltes-liftchen.html
# [INFO] Datei schon vorhanden: tueren-auf.html
# [INFO] Datei schon vorhanden: gemeinsam-fuer-die-mobilitaetswende.html
# [INFO] Datei schon vorhanden: dein-anschluss-unter-dieser-nummer.html
# [INFO] Datei schon vorhanden: sommer-comeback-fuer-die-u12.html
# [INFO] Datei schon vorhanden: zweimal-anders-einmal-neu.html
# [INFO] Datei schon vorhanden: sechsstellig-auf-bestellung.html
# [INFO] Datei schon vorhanden: mit-bus-und-bahn-zu-den-em-spielen-vbb-bvg-und-s-bahn-ziehen-positive-bilanz.html
# [INFO] Datei schon vorhanden: gut-gedaemmt.html
# [INFO] Datei schon vorhanden: von-audit-bis-zertifiziert.html
# [INFO] Datei schon vorhanden: einbahnstrasse.html
# [INFO] Datei schon vorhanden: pride-month-berlin-bvg-ohne-mundhaltestelle.html
# [INFO] Datei schon vorhanden: kroenchen-richten.html
# [INFO] Datei schon vorhanden: verstaerkung-ahoi.html
# [INFO] Datei schon vorhanden: ziemlich-beste-freunde.html
# [INFO] Datei schon vorhanden: einsteigen-in-die-zukunft-bitte.html
# [INFO] Datei schon vorhanden: verkehrssicherheit-fuer-alle.html
# [INFO] Datei schon vorhanden: kontrolle-ist-besser.html
# [INFO] Datei schon vorhanden: schotte-rockt-die-linie-100.html
# [INFO] Datei schon vorhanden: bvg-hebt-das-niveau.html
# [INFO] Datei schon vorhanden: gleisberechtigung-fuer-die-u5.html
# [INFO] Datei schon vorhanden: alles-nach-plan-macht-der-mai.html
# [INFO] Datei schon vorhanden: streik-beendet-busse-und-bahnen-der-bvg-kommen-wieder-in-den-gewohnten-takt.html
# [INFO] Datei schon vorhanden: schwarz-weiss-schoen.html
# [INFO] Datei schon vorhanden: neues-gleis-im-koepenicker-kreis.html
# [INFO] Datei schon vorhanden: wir-uebernehmen-die-leitung.html
# [INFO] Datei schon vorhanden: nachtschwermer.html
# [INFO] Datei schon vorhanden: an-die-riemen.html
# [INFO] Datei schon vorhanden: gleise-glaetten.html
# [INFO] Datei schon vorhanden: machs-fuers-gelb.html
# [INFO] Datei schon vorhanden: bayern-gehoert-jetzt-zu-berlin.html
# [INFO] Datei schon vorhanden: gelb-galaktisch-gut.html
# [INFO] Datei schon vorhanden: mast-be.html
# [INFO] Datei schon vorhanden: der-anschluss-wird-erreicht.html
# [INFO] Datei schon vorhanden: wendemanoever.html
# [INFO] Datei schon vorhanden: an-oberster-stelle.html
# [INFO] Datei schon vorhanden: was-bvgeht-im-sommer-fuenf-coole-tipps-zur-ferienzeit.html
# [INFO] Datei schon vorhanden: bvg-bindet-sich.html
# [INFO] Datei schon vorhanden: drei-auf-einen-streich.html
# [INFO] Datei schon vorhanden: mobilitaetstrainings-finden-wieder-statt.html
# [INFO] Datei schon vorhanden: gleis-wirds-wieder-besser.html
# [INFO] Datei schon vorhanden: geteilte-freude.html
# [INFO] Datei schon vorhanden: bvg-spendet-preisgeld.html
# [INFO] Datei schon vorhanden: planung-zur-verlaengerung-der-u8-nimmt-fahrt-auf.html
# [INFO] Datei schon vorhanden: das-wird-ein-kappes-ding.html
# [INFO] Datei schon vorhanden: manchmal-kann-man-nichts-machen-ausser-weiter.html
# [INFO] Datei schon vorhanden: machen-wir-den-friedrich-wilhelm-drunter.html
# [INFO] Datei schon vorhanden: eins-zwei-barrierefrei.html
# [INFO] Datei schon vorhanden: bvg-unter-dem-regenbogen.html
# [INFO] Datei schon vorhanden: laeuft.html
# [INFO] Datei schon vorhanden: berlkoenig-faehrt-wieder-regulaer.html
# [INFO] Datei schon vorhanden: hin-und-her.html
# [INFO] Datei schon vorhanden: 2025-01-03-pm-kleidersammelaktion0.html
# [INFO] Datei schon vorhanden: aehm-2.html
# [INFO] Datei schon vorhanden: s-bahn-berlin-und-bvg-geben-17-000-fahrscheine-fuer-freiwillig-engagierte-2.html
# [INFO] Datei schon vorhanden: flugs-in-die-schule.html
# [INFO] Datei schon vorhanden: bvg-hat-den-richtigen-draht-nach-oben.html
# [INFO] Datei schon vorhanden: vier-gewinnt.html
# [INFO] Datei schon vorhanden: naechster-halt-weltkulturerbe__trashed.html
# [INFO] Datei schon vorhanden: berlin-im-quadrat.html
# [INFO] Datei schon vorhanden: wir-lassen-keinen-fahren.html
# [INFO] Datei schon vorhanden: bvg-ist-auf-draht.html
# [INFO] Datei schon vorhanden: sicher-ist-sicher.html
# [INFO] Datei schon vorhanden: komm-mal-zum-punkt.html
# [INFO] Datei schon vorhanden: gemeinsamer-einsatz-geht-weiter.html
# [INFO] Datei schon vorhanden: berliner-verkehrsbetriebe-bvg-vergeben-vertrag-fuer-fahrgastunterstaende-exklusiv-an-die-wall-gmbh.html
# [INFO] Datei schon vorhanden: voller-tatendrang.html
# [INFO] Datei schon vorhanden: e-schlenkis-erobern-berlin.html
# [INFO] Datei schon vorhanden: bund-fuer-bunt.html
# [INFO] Datei schon vorhanden: countdown-fuer-die-autonomen-minibusse.html
# [INFO] Datei schon vorhanden: ja-wo-laufen-sie-denn.html
# [INFO] Datei schon vorhanden: seitenwechsel-4.html
# [INFO] Datei schon vorhanden: das-zauberwort-gegen-die-krise-kommunikation.html
# [INFO] Datei schon vorhanden: 21-geteilt-durch-zwei.html
# [INFO] Datei schon vorhanden: viel-gleis-und-etwas-fahrleitung.html
# [INFO] Datei schon vorhanden: bvg-nimmt-aufzug-am-nauener-platz-in-betrieb.html
# [INFO] Datei schon vorhanden: aller-guten-dinge-sind-vier.html
# [INFO] Datei schon vorhanden: 2025-04-16-neue-linie-215.html
# [INFO] Datei schon vorhanden: mut-zur-bruecke.html
# [INFO] Datei schon vorhanden: die-bvg-feiert-90-geburtstag.html
# [INFO] Datei schon vorhanden: bvg-macht-sich-keine-platte.html
# [INFO] Datei schon vorhanden: gleisbau-in-marzahn.html
# [INFO] Datei schon vorhanden: vordereinstieg-beim-bus-startet-wieder.html
# [INFO] Datei schon vorhanden: gute-nacht.html
# [INFO] Datei schon vorhanden: luft-nach-oben.html
# [INFO] Datei schon vorhanden: u-bahn-sportliche-leistung-in-herausfordernden-zeiten.html
# [INFO] Datei schon vorhanden: in-bus-und-bahn-nicht-oben-ohne.html
# [INFO] Datei schon vorhanden: das-wird-eine-runde-sache.html
# [INFO] Datei schon vorhanden: ein-bussi-fuer-den-csd.html
# [INFO] Datei schon vorhanden: bvg-und-stadler-stellen-vor-die-zugkunft-der-berliner-u-bahn.html
# [INFO] Datei schon vorhanden: mueggelseetram-2.html
# [INFO] Datei schon vorhanden: juchei-eiii.html
# [INFO] Datei schon vorhanden: intermodal-royal-berlkoenig-jetzt-mit-integrierten-reiseketten.html
# [INFO] Datei schon vorhanden: edison-stell-den-strom-ab.html
# [INFO] Datei schon vorhanden: deckenarbeiten-am-kaiserdamm.html
# [INFO] Datei schon vorhanden: damm-entnehmen-wir-mal-proben.html
# [INFO] Datei schon vorhanden: friedrichsfelde-nicht-zu-stoppen.html
# [INFO] Datei schon vorhanden: die-bauweiche-muss-weichen.html
# [INFO] Datei schon vorhanden: 140-jahre-unter-strom.html
# [INFO] Datei schon vorhanden: die-bvg-macht-nachts-ordentlich-schotter.html
# [INFO] Datei schon vorhanden: elsenbruecke-teilweise-gesperrt.html
# [INFO] Datei schon vorhanden: einmal-mit-allem.html
# [INFO] Datei schon vorhanden: vier-grosse-gelbe-und-tram-teile-fuer-die-ukraine.html
# [INFO] Datei schon vorhanden: bahnbruecke-ueber-karl-liebknecht-strasse-bekommt-neuen-witterungsschutz.html
# [INFO] Datei schon vorhanden: bvg-uebernimmt-die-leitung.html
# [INFO] Datei schon vorhanden: gelbe-perspektiven.html
# [INFO] Datei schon vorhanden: inklusionspreis-fuer-den-berlkoenig.html
# [INFO] Datei schon vorhanden: u55-pausiert.html
# [INFO] Datei schon vorhanden: bundeskanzler-scholz-besucht-die-bvg.html
# [INFO] Datei schon vorhanden: voll-im-training-2.html
# [INFO] Datei schon vorhanden: von-langer-hans-geplant.html
# [INFO] Datei schon vorhanden: schnitt.html
# [INFO] Datei schon vorhanden: moabit-im-trampenlicht.html
# [INFO] Datei schon vorhanden: grosser-bahnhof-fuer-glinka.html
# [INFO] Datei schon vorhanden: scheibenkleister.html
# [INFO] Datei schon vorhanden: bvg-beginnt-mit-gleiseinbau-in-moabit.html
# [INFO] Datei schon vorhanden: kurze-unterbrechung-auf-der-suedlichen-u7.html
# [INFO] Datei schon vorhanden: neuer-stahl-fuer-johannisthal.html
# [INFO] Datei schon vorhanden: unterwegs-im-netz.html
# [INFO] Datei schon vorhanden: u5-pendelt-sich-ein.html
# [INFO] Datei schon vorhanden: onkel-toms-huette-u3-nach-brand-in-benachbarter-ladenpassage-weiter-unterbrochen.html
# [INFO] Datei schon vorhanden: ja-mai.html
# [INFO] Datei schon vorhanden: gruen-und-drahtig.html
# [INFO] Datei schon vorhanden: titel-verteidigt.html
# [INFO] Datei schon vorhanden: tramhafte-aussichten-fuer-moabit-2.html
# [INFO] Datei schon vorhanden: kurze-pendelei-im-westen-der-u2.html
# [INFO] Datei schon vorhanden: kleiner-gelber-faehrt-sich-selber.html
# [INFO] Datei schon vorhanden: mehr-bitte.html
# [INFO] Datei schon vorhanden: insgesummt-lecker.html
# [INFO] Datei schon vorhanden: ausgezeichneter-klang.html
# [INFO] Datei schon vorhanden: ein-stiefel-voller-busse-und-bahnen.html
# [INFO] Datei schon vorhanden: bau-an-bruecke-sorgt-fuer-luecke.html
# [INFO] Datei schon vorhanden: fahrstreifen-auf-dem-tempelhofer-damm-gesperrt.html
# [INFO] Datei schon vorhanden: berlin-tief-verbunden-die-neue-u5-ist-eroeffnet.html
# [INFO] Datei schon vorhanden: wir-bauen-auf-ausbildung-2.html
# [INFO] Datei schon vorhanden: unterwegs-auf-der-zeitschiene.html
# [INFO] Datei schon vorhanden: die-bvg-verbindet.html
# [INFO] Datei schon vorhanden: inspektor-bvg.html
# [INFO] Datei schon vorhanden: auf-einen-pieks-zur-bvg.html
# [INFO] Datei schon vorhanden: bvg-ruestet-auf.html
# [INFO] Datei schon vorhanden: soziale-verantwortung-bei-der-e-bus-beschaffung.html
# [INFO] Datei schon vorhanden: vielfalt-auf-ganzer-linie.html
# [INFO] Datei schon vorhanden: verlaengerung-zwischen-b-und-c.html
# [INFO] Datei schon vorhanden: nachts-in-neukoelln.html
# [INFO] Datei schon vorhanden: die-bvg-stellt-ein.html
# [INFO] Datei schon vorhanden: ruh-bahn.html
# [INFO] Datei schon vorhanden: fast-fertig.html
# [INFO] Datei schon vorhanden: die-busse-und-bahnen-der-bvg-fahren-am-21-april-wie-gewohnt.html
# [INFO] Datei schon vorhanden: 13-points-go-to.html
# [INFO] Datei schon vorhanden: 25-jahre-strassenbahn-auf-dem-alex.html
# [INFO] Datei schon vorhanden: drum-pruefe.html
# [INFO] Datei schon vorhanden: kultfaehrdaechtig.html
# [INFO] Datei schon vorhanden: ein-muster-das-bewegt.html
# [INFO] Datei schon vorhanden: grossprojekt-erfolgreich-beendet-highspeed-mobilfunk-fuer-alle-in-der-berliner-u-bahn.html
# [INFO] Datei schon vorhanden: verlaengerung-fuer-u2-hertha-sonderverkehr.html
# [INFO] Datei schon vorhanden: ahoi-paule-iii.html
# [INFO] Datei schon vorhanden: dort-unten-leuchten-die-sterne.html
# [INFO] Datei schon vorhanden: besser-laenger-haeufiger.html
# [INFO] Datei schon vorhanden: verlaengerung-in-der-eldenaer.html
# [INFO] Datei schon vorhanden: weichen-muessen-weichen.html
# [INFO] Datei schon vorhanden: bvg-hilft-gefluechteten.html
# [INFO] Datei schon vorhanden: neue-schien-fuer-treskow-und-rhin.html
# [INFO] Datei schon vorhanden: fit-fuer-die-fahrt-2.html
# [INFO] Datei schon vorhanden: stufenlose-u4.html
# [INFO] Datei schon vorhanden: platz-fuer-neues-2.html
# [INFO] Datei schon vorhanden: verlaengerung-auf-der-see-meile.html
# [INFO] Datei schon vorhanden: komm-se-rin-koenn-se-rausfahren.html
# [INFO] Datei schon vorhanden: jelbi-geht-bis-an-die-grenze.html
# [INFO] Datei schon vorhanden: voll-im-training.html
# [INFO] Datei schon vorhanden: mit-sicherheit-gut-ausgestattet.html
# [INFO] Datei schon vorhanden: alles-nach-plan.html
# [INFO] Datei schon vorhanden: astreine-arbeiten.html
# [INFO] Datei schon vorhanden: bitte-nicht-moeckern.html
# [INFO] Datei schon vorhanden: bvg-machts-nachts.html
# [INFO] Datei schon vorhanden: mit-der-oeffis-bande-in-die-arche.html
# [INFO] Datei schon vorhanden: weiterarbeiten.html
# [INFO] Datei schon vorhanden: bargeldlos-im-bus.html
# [INFO] Datei schon vorhanden: jede-karte-ein-treffer.html
# [INFO] Datei schon vorhanden: hier-gehts-lang.html
# [INFO] Datei schon vorhanden: weitere-e-busse-fuer-die-bvg.html
# [INFO] Datei schon vorhanden: start-corporate-influencer-programm.html
# [INFO] Datei schon vorhanden: bvg-laesst-ausrichten.html
# [INFO] Datei schon vorhanden: volle-info-diggi.html
# [INFO] Datei schon vorhanden: freiertag-in-berlin.html
# [INFO] Datei schon vorhanden: spieglein-spieglein-in-der-hand.html
# [INFO] Datei schon vorhanden: kosmische-gleisarbeiten.html
# [INFO] Datei schon vorhanden: barrierefrei-zur-u3.html
# [INFO] Datei schon vorhanden: gleis-raus-gleis-rein.html
# [INFO] Datei schon vorhanden: tour-de-berlin.html
# [INFO] Datei schon vorhanden: appy-birthday.html
# [INFO] Datei schon vorhanden: kleine-massnahme-grosse-wirkung.html
# [INFO] Datei schon vorhanden: streik-bei-der-db-busse-und-bahnen-der-bvg-fahren-zum-wochenstart-planmaessig.html
# [INFO] Datei schon vorhanden: strom-fuer-allee.html
# [INFO] Datei schon vorhanden: gelbwerter-vorteil.html
# [INFO] Datei schon vorhanden: zusaetzliche-einschraenkung-fuer-den-txl.html
# [INFO] Datei schon vorhanden: elektrobusse-intelligent-laden-forschungscampus-mobility2grid-nimmt-innovative-ladestation-in-betrieb.html
# [INFO] Datei schon vorhanden: demo-fuer-verkehrswende-in-weissensee-stoppt-auch-den-oepnv.html
# [INFO] Datei schon vorhanden: der-berlkoenig-rollt-durch-berlin.html
# [INFO] Datei schon vorhanden: 2025-01-08-pm-zahlen-2024.html
# [INFO] Datei schon vorhanden: relais-ade.html
# [INFO] Datei schon vorhanden: rampenbau.html
# [INFO] Datei schon vorhanden: 155-000-mal-5.html
# [INFO] Datei schon vorhanden: einige-anpassungen-fuer-viel-zuverlaessigkeit.html
# [INFO] Datei schon vorhanden: hoer-mal-wer-da-spricht-2.html
# [INFO] Datei schon vorhanden: winter-laesst-uns-kalt.html
# [INFO] Datei schon vorhanden: sperr-die-loeffel-ab.html
# [INFO] Datei schon vorhanden: gleis-an-gleis.html
# [INFO] Datei schon vorhanden: schmoll-doch-nicht.html
# [INFO] Datei schon vorhanden: knifflige-reparatur-auf-engstem-raum.html
# [INFO] Datei schon vorhanden: hip-hip-jelbi.html
# [INFO] Datei schon vorhanden: gib-8.html
# [INFO] Datei schon vorhanden: janz-schoen-liftig-hier.html
# [INFO] Datei schon vorhanden: gute-luft-in-bus-und-bahn.html
# [INFO] Datei schon vorhanden: fundige-schnaeppchen.html
# [INFO] Datei schon vorhanden: musterhafte-einigung.html
# [INFO] Datei schon vorhanden: kommt-zeit-kommt-draht.html
# [INFO] Datei schon vorhanden: jelbi-hat-den-sixten-sinn.html
# [INFO] Datei schon vorhanden: besser-planen-koennen.html
# [INFO] Datei schon vorhanden: zweifache-nachtschicht.html
# [INFO] Datei schon vorhanden: die-busse-und-bahnen-der-bvg-werden-nicht-bestreikt.html
# [INFO] Datei schon vorhanden: 2025-02-19-aufsichtsrat-beschliesst-neuaufstellung-des-bvg-vorstands.html
# [INFO] Datei schon vorhanden: zauberhafte-reise-fuer-gross-und-klein.html
# [INFO] Datei schon vorhanden: busse-und-bahnen-der-bvg-sind-am-27-maerz-wie-gewohnt-unterwegs.html
# [INFO] Datei schon vorhanden: mal-ganz-ohne-gag-innehalten-mitmachen.html
# [INFO] Datei schon vorhanden: letzter-schliff-fuer-die-u2-am-alexanderplatz.html
# [INFO] Datei schon vorhanden: 10-uhr-karten-gelten-eine-stunde-frueher.html
# [INFO] Datei schon vorhanden: tunnelpflege-und-weichenteilaustausch.html
# [INFO] Datei schon vorhanden: meisterhaft.html
# [INFO] Datei schon vorhanden: am-automaten-kann-mans-auch-guthaben.html
# [INFO] Datei schon vorhanden: ausgezeichnet-ausgebildet.html
# [INFO] Datei schon vorhanden: x36er-wieder-an-bord.html
# [INFO] Datei schon vorhanden: gelbe-seiten.html
# [INFO] Datei schon vorhanden: orientierung-zum-tasten.html
# [INFO] Datei schon vorhanden: berlkoenig-sonderfahrten-fuer-das-gesundheitswesen-bediengebiet-erneut-ausgeweitet-betriebszeiten-verlaengert.html
# [INFO] Datei schon vorhanden: restarbeiten.html
# [INFO] Datei schon vorhanden: gleis-und-gleis-gesellt-sich-gern.html
# [INFO] Datei schon vorhanden: passgenauer-einsatz.html
# [INFO] Datei schon vorhanden: kreuz-und-quer.html
# [INFO] Datei schon vorhanden: verschweisst-und-zugedeckelt.html
# [INFO] Datei schon vorhanden: zwei-mobilitaetstrainings-finden-nicht-statt.html
# [INFO] Datei schon vorhanden: frischzellenkur-fuer-tegeler-u6.html
# [INFO] Datei schon vorhanden: tramhafte-aussichten-fuer-moabit.html
# [INFO] Datei schon vorhanden: ausbildungsplaetze-fertig-los.html
# [INFO] Datei schon vorhanden: sauber-sicher-jetzt-auf-ganzer-linie.html
# [INFO] Datei schon vorhanden: we-love-to-share-you-to-fu.html
# [INFO] Datei schon vorhanden: fuersorge-fuer-gleise.html
# [INFO] Datei schon vorhanden: neu-gestimmt.html
# [INFO] Datei schon vorhanden: den-kutschi-umkurven.html
# [INFO] Datei schon vorhanden: das-machen-wir-gleis-richtig.html
# [INFO] Datei schon vorhanden: herzschmerz.html
# [INFO] Datei schon vorhanden: ein-modell-fuer-die-zukunft.html
# [INFO] Datei schon vorhanden: drahtzieher.html
# [INFO] Datei schon vorhanden: mehr-ordnung-in-mitte-na-bitte.html
# [INFO] Datei schon vorhanden: ein-gleis-im-doerpfeld.html
# [INFO] Datei schon vorhanden: welcome-to-berlin.html
# [INFO] Datei schon vorhanden: bus-jetzt-auch-mal-sein.html
# [INFO] Datei schon vorhanden: kaeptn-bvg-ab-auf-die-see.html
# [INFO] Datei schon vorhanden: gleis-gehts-weiter.html
# [INFO] Datei schon vorhanden: der-strom-kommt-kurz-vor-schluss.html
# [INFO] Datei schon vorhanden: ein-schotte-verstaerkt-die-flotte.html
# [INFO] Datei schon vorhanden: das-geheimnis-wird-geliftet.html
# [INFO] Datei schon vorhanden: um-den-alex-rum.html
# [INFO] Datei schon vorhanden: sonntagsausflug-mit-historischer-u-bahn.html
# [INFO] Datei schon vorhanden: senat-zu-besuch-bei-der-bvg-berlin-2035-mobilitaet-im-zeitalter-von-ki.html
# [INFO] Datei schon vorhanden: da-muessen-wir-mal-schnell-ran.html
# [INFO] Datei schon vorhanden: sonntagnacht-ecke-eberswalde.html
# [INFO] Datei schon vorhanden: lieber-mal-gleich-richten.html
# [INFO] Datei schon vorhanden: aufzuege-von-v-bis-z.html
# [INFO] Datei schon vorhanden: berlin-tief-verbunden-u5-faehrt-bald-durch.html
# [INFO] Datei schon vorhanden: thats-it.html
# [INFO] Datei schon vorhanden: u1-und-u3-nach-boeschungsbrand-weiterhin-unterbrochen.html
# [INFO] Datei schon vorhanden: deutsche-bahn-und-berliner-verkehrsbetriebe-kooperieren-im-bereich-autonomes-fahren.html
# [INFO] Datei schon vorhanden: frauen-erobert-das-gelb.html
# [INFO] Datei schon vorhanden: bauarbeiten-bei-der-s-bahn-u5-faehrt-den-ganzen-tag-im-dichten-takt.html
# [INFO] Datei schon vorhanden: halt-mal.html
# [INFO] Datei schon vorhanden: gleis-gehts-los.html
# [INFO] Datei schon vorhanden: bvg-unterstuetzt-kleiderspende-aktion.html
# [INFO] Datei schon vorhanden: einigung-in-den-bvg-tarifverhandlungen.html
# [INFO] Datei schon vorhanden: sei-ein-fuchs-fuer-dich-und-die-umwelt.html
# [INFO] Datei schon vorhanden: glattgezogen.html
# [INFO] Datei schon vorhanden: siegfried-und-neu.html
# [INFO] Datei schon vorhanden: die-naechste-bitte.html
# [INFO] Datei schon vorhanden: ohne-fleiss-kein-gleis.html
# [INFO] Datei schon vorhanden: autofrei-wir-sind-dabei.html
# [INFO] Datei schon vorhanden: u1-zum-zweiten-u3.html
# [INFO] Datei schon vorhanden: von-der-notloesung-zum-klassiker.html
# [INFO] Datei schon vorhanden: platz-fuer-neue-bahnsteige.html
# [INFO] Datei schon vorhanden: wer-wird-denn-gleich-an-die-decke-gehen.html
# [INFO] Datei schon vorhanden: welkom-in-berlijn.html
# [INFO] Datei schon vorhanden: panktastische-bahnsteige.html
# [INFO] Datei schon vorhanden: triple-fuer-die-bvg.html
# [INFO] Datei schon vorhanden: auch-schon-mal-zweigleisig-gefahren.html
# [INFO] Datei schon vorhanden: mal-wieder-gerade-machen.html
# [INFO] Datei schon vorhanden: my-way.html
# [INFO] Datei schon vorhanden: bvg-parkts-an.html
# [INFO] Datei schon vorhanden: sechszellent.html
# [INFO] Datei schon vorhanden: das-pendelt-sich-ein.html
# [INFO] Datei schon vorhanden: dorotheenstrasse-neu-vergleist.html
# [INFO] Datei schon vorhanden: bvg-faehrt-jetzt-auf-der-wissenschaftsschiene.html
# [INFO] Datei schon vorhanden: gib-fuenf.html
# [INFO] Datei schon vorhanden: mieten-auf-einen-streich.html
# [INFO] Datei schon vorhanden: wettervorhersage-meist-gleisig.html
# [INFO] Datei schon vorhanden: bvg-schliesst-servicestuetzpunkt.html
# [INFO] Datei schon vorhanden: hundert-seiten-liebe.html
# [INFO] Datei schon vorhanden: vitejte.html
# [INFO] Datei schon vorhanden: kiek-ma-die-neue.html
# [INFO] Datei schon vorhanden: job-store-on-tour.html
# [INFO] Datei schon vorhanden: schnittgerecht.html
# [INFO] Datei schon vorhanden: schienenfleissarbeiten.html
# [INFO] Datei schon vorhanden: telefonica-deutschland-telekom-und-vodafone-schalten-gemeinsam-lte-auf-ersten-u-bahn-linien-in-berlin-ein.html
# [INFO] Datei schon vorhanden: naechtliche-pendelei-auf-der-u6.html
# [INFO] Datei schon vorhanden: gemeinsam-fuer-sicherheit.html
# [INFO] Datei schon vorhanden: jahresbilanz-2023-mehr-von-allem.html
# [INFO] Datei schon vorhanden: es-geht-aufwaerts-2.html
# [INFO] Datei schon vorhanden: limeted-edition.html
# [INFO] Datei schon vorhanden: aus-zwei-mach-zweihundert.html
# [INFO] Datei schon vorhanden: eine-runde-bitte.html
# [INFO] Datei schon vorhanden: tauschrausch.html
# [INFO] Datei schon vorhanden: so-ists-gleis-viel-besser.html
# [INFO] Datei schon vorhanden: jede-menge-tram-tram.html
# [INFO] Datei schon vorhanden: in-diesem-aufzug-kann-man-sich-sehen-lassen.html
# [INFO] Datei schon vorhanden: geschmeidiger-uebergang.html
# [INFO] Datei schon vorhanden: simply-the-west.html
# [INFO] Datei schon vorhanden: niedrigerer-preis-hoehere-qualitaet.html
# [INFO] Datei schon vorhanden: praktische-anzeigen-gegen-hektisches-umsteigen.html
# [INFO] Datei schon vorhanden: mit-dem-zweiten-faehrt-man-besser.html
# [INFO] Datei schon vorhanden: verflixt-und-zugemuellt.html
# [INFO] Datei schon vorhanden: schoen-sie-rennenzulernen.html
# [INFO] Datei schon vorhanden: gepoolt-wie-gerufen.html
# [INFO] Datei schon vorhanden: bauleitung.html
# [INFO] Datei schon vorhanden: 2025-01-13-pm-neuer-e-gelenkbus.html
# [INFO] Datei schon vorhanden: die-bvg-legt-immer-die-gleiche-platte-auf.html
# [INFO] Datei schon vorhanden: urbanliner-ganz-laaaaanger-fahrspass.html
# [INFO] Datei schon vorhanden: was-ist-denn-jetzt-phase.html
# [INFO] Datei schon vorhanden: 2025-03-10-update-stabilitaet-der-bvg0.html
# [INFO] Datei schon vorhanden: jelbi-app-bietet-jetzt-noch-mehr-mobileeeetaet.html
# [INFO] Datei schon vorhanden: schnelle-arbeit-u1-und-u3-fahren-bald-wieder.html
# [INFO] Datei schon vorhanden: bvg-bleibt-am-ball.html
# [INFO] Datei schon vorhanden: bvg-tragbar.html
# [INFO] Datei schon vorhanden: da-muessen-wir-ran.html
# [INFO] Datei schon vorhanden: auf-die-gleise-fertig-los.html
# [INFO] Datei schon vorhanden: sperrung-der-bahnbruecke-in-marienfelde.html
# [INFO] Datei schon vorhanden: royaler-gesundheitscheck.html
# [INFO] Datei schon vorhanden: eine-neue-bindung-eingehen.html
# [INFO] Datei schon vorhanden: schienenfleissig-in-friedrichshain.html
# [INFO] Datei schon vorhanden: bvg-erneuert-die-fahrleitungen.html
# [INFO] Datei schon vorhanden: bitte-jetzt-wenden.html
# [INFO] Datei schon vorhanden: wir-bauen-auf-ausbildung.html
# [INFO] Datei schon vorhanden: grenzenlos-vernetzt.html
# [INFO] Datei schon vorhanden: nachtschichten-auf-der-u6.html
# [INFO] Datei schon vorhanden: sperrung-elsenbruecke-drei-buslinien-betroffen.html
# [INFO] Datei schon vorhanden: neues-jahr-neue-bahnsteige.html
# [INFO] Datei schon vorhanden: es-geht-aufwaerts.html
# [INFO] Datei schon vorhanden: packen-wirs-an.html
# [INFO] Datei schon vorhanden: bvg-tauscht-aus.html
# [INFO] Datei schon vorhanden: die-bvg-hat-den-bogen-raus.html
# [INFO] Datei schon vorhanden: weichenmacher.html
# [INFO] Datei schon vorhanden: bitte-recht-fahrradfreundlich.html
# [INFO] Datei schon vorhanden: mal-ordentlich-die-meinung-sagen.html
# [INFO] Datei schon vorhanden: fuer-stabilitaet-und-verlaesslichkeit.html
# [INFO] Datei schon vorhanden: faehrmann-erhol-lieber.html
# [INFO] Datei schon vorhanden: drahtige-angelegenheit.html
# [INFO] Datei schon vorhanden: mit-abstand-die-beste-verbindung.html
# [INFO] Datei schon vorhanden: ungekehrt.html
# [INFO] Datei schon vorhanden: 2025-01-15-tarif-2025.html
# [INFO] Datei schon vorhanden: nachtschicht-unterm-adenauerplatz.html
# [INFO] Datei schon vorhanden: bei-der-bvg-kann-mans-richtig-guthaben.html
# [INFO] Datei schon vorhanden: gewobag-und-bvg-eroeffnen-ersten-mobilitaetshub-berlins.html
# [INFO] Datei schon vorhanden: wieder-im-takt.html
# [INFO] Datei schon vorhanden: bvg-kontrolliert-einhaltung-der-maskenpflicht.html
# [INFO] Datei schon vorhanden: das-dasein-hat-auch-noch-gute-seiten.html
# [INFO] Datei schon vorhanden: fahrgastinformation-bei-der-ubahn-verbessert.html
# [INFO] Datei schon vorhanden: laenger-unter-strom-2.html
# [INFO] Datei schon vorhanden: kurze-unterbrechung.html
# [INFO] Datei schon vorhanden: neue-gleise-fuer-alt-koepenick.html
# [INFO] Datei schon vorhanden: sauber-gemacht.html
# [INFO] Datei schon vorhanden: mausgezeichnete-zukunftsperspektiven.html
# [INFO] Datei schon vorhanden: 2025-02-04-ideen-die-berlin-bewegen.html
# [INFO] Datei schon vorhanden: auf-ein-neues.html
# [INFO] Datei schon vorhanden: dickes-b-trifft-auf-ganz-d.html
# [INFO] Datei schon vorhanden: bvg-kontrolliert-3g.html
# [INFO] Datei schon vorhanden: jelbi-birthday.html
# [INFO] Datei schon vorhanden: noch-ein-wechsel-bei-der-bvg.html
# [INFO] Datei schon vorhanden: allee-an-bord.html
# [INFO] Datei schon vorhanden: gleis-gehts-ins-all.html
# [INFO] Datei schon vorhanden: berlins-aelteste-untergrundbewegung.html
# [INFO] Datei schon vorhanden: bvg-haelt-berlin-weiterhin-mobil.html
# [INFO] Datei schon vorhanden: berlkoenig-geht-neue-angebote-kommen.html
# [INFO] Datei schon vorhanden: immer-auf-draht.html
# [INFO] Datei schon vorhanden: bvg-macht-boden-gut.html
# [INFO] Datei schon vorhanden: neue-wege-gehen.html
# [INFO] Datei schon vorhanden: und-hier-die-gewinnzahlen-zum-wochenende-46-47-42-195.html
# [INFO] Datei schon vorhanden: kleine-wochenend-kuren-fuer-die-strassenbahn.html
# [INFO] Datei schon vorhanden: seitenwechsel-2.html
# [INFO] Datei schon vorhanden: maske-auf-film-ab.html
# [INFO] Datei schon vorhanden: mit-netz-in-der-tram.html
# [INFO] Datei schon vorhanden: neue-gleise-fuer-die-m6-und-die-18.html
# [INFO] Datei schon vorhanden: weiter-zuverlaessig-unterwegs.html
# [INFO] Datei schon vorhanden: 2025-05-02-muva-zwischenbilanz.html
# [INFO] Datei schon vorhanden: auf-ein-letztes-mal.html
# [INFO] Datei schon vorhanden: kreuzberg-und-friedrichshain-wieder-vereint.html
# [INFO] Datei schon vorhanden: nachts-im-u-bahnhof-museumsinsel.html
# [INFO] Datei schon vorhanden: rhinjehoben.html
# [INFO] Datei schon vorhanden: im-zeichen-des-regenbogens.html
# [INFO] Datei schon vorhanden: ausgezeichnete-kommunikation.html
# [INFO] Datei schon vorhanden: gruendlichkeit-ist-das-gebot.html
# [INFO] Datei schon vorhanden: share-dich-nach-spandau.html
# [INFO] Datei schon vorhanden: 2025-04-14-abschluss-reinigungsstreife.html
# [INFO] Datei schon vorhanden: u9-neu-verbunden.html
# [INFO] Datei schon vorhanden: hochkant-im-hk.html
# [INFO] Datei schon vorhanden: da-bolt-was-auf-uns-zu.html
# [INFO] Datei schon vorhanden: ohne-fleiss-kein-gleis-2.html
# [INFO] Datei schon vorhanden: steglitzeblank.html
# [INFO] Datei schon vorhanden: frische-gleise-fuer-die-prenzlauer-promenade.html
# [INFO] Datei schon vorhanden: gruen-hinter-den-gleisen.html
# [INFO] Datei schon vorhanden: von-amrum-nach-turin.html
# [INFO] Datei schon vorhanden: bunt-fuers-leben.html
# [INFO] Datei schon vorhanden: knorke-schuhe-guter-zweck.html
# [INFO] Datei schon vorhanden: voller-einsatz-fuer-die-fahrgaeste.html
# [INFO] Datei schon vorhanden: umleitungen-zum-marathon.html
# [INFO] Datei schon vorhanden: hohe-nachfrage-nach-dem-deutschlandticket-bei-der-bvg.html
# [INFO] Datei schon vorhanden: seitenwechsel-3.html
# [INFO] Datei schon vorhanden: bvg-bringt-mich-weiter.html
# [INFO] Datei schon vorhanden: statement-der-bvg-zur-attacke-gegen-eine-strassenbahn-der-linie-m10.html
# [INFO] Datei schon vorhanden: darauf-koennen-wir-uns-was-ausbilden.html
# [INFO] Datei schon vorhanden: drumherum-statt-mittendurch.html
# [INFO] Datei schon vorhanden: mehr-volt-fuer-alle-faelle.html
# [INFO] Datei schon vorhanden: das-laeuft.html
# [INFO] Datei schon vorhanden: gelb-noch-gruener-bvg-kriegt-solar-was-aufs-dach.html
# [INFO] Datei schon vorhanden: die-u2-legt-einen-kurzen-stopf-ein.html
# [INFO] Datei schon vorhanden: aufzug-oeffne-dich.html
# [INFO] Datei schon vorhanden: kommse-rin-koennse-e-busse-kieken.html
# [INFO] Datei schon vorhanden: donnanderstag.html
# [INFO] Datei schon vorhanden: bvg-raeumt-mit-vielfalt-ab.html
# [INFO] Datei schon vorhanden: naechte-der-auffrischung.html
# [INFO] Datei schon vorhanden: weiter-gehts-auf-der-landsberger-allee.html
# [INFO] Datei schon vorhanden: nachwuchs-bei-den-grossen-gelben.html
# [INFO] Datei schon vorhanden: hoch-die-trassen.html
# [INFO] Datei schon vorhanden: besser-vernetzter-oepnv-deutsche-bahn-und-berliner-verkehrsbetriebe-kooperieren-bei-app-entwicklung.html
# [INFO] Datei schon vorhanden: neue-busse-fuer-die-bvg.html
# [INFO] Datei schon vorhanden: sei-doch-mal-etwas-flexibel.html
# [INFO] Datei schon vorhanden: ausprobieren-und-informieren.html
# [INFO] Datei schon vorhanden: vorsicht-ist-besser-u2-am-alexanderplatz-nur-eingleisig-unterwegs.html
# [INFO] Datei schon vorhanden: grosse-nachfrage-nach-29-euro-abo.html
# [INFO] Datei schon vorhanden: berlin-bleibt-mobil.html
# [INFO] Datei schon vorhanden: letzte-post.html
# [INFO] Datei schon vorhanden: nachts-in-der-spichernstrasse.html
# [INFO] Datei schon vorhanden: der-kommt-ja-wie-gerufen.html
# [INFO] Datei schon vorhanden: zwei-auf-einen-schlag.html
# [INFO] Datei schon vorhanden: die-zukunft-im-tunnel.html
# [INFO] Datei schon vorhanden: oesterlicher-ei-nsatz.html
# [INFO] Datei schon vorhanden: inspektor-bvg-2.html
# [INFO] Datei schon vorhanden: exzellente-ausbildung-das-ist-besiegelt.html
# [INFO] Datei schon vorhanden: schnittchen-fuer-die-haeckelstrasse.html
# [INFO] Datei schon vorhanden: fruehling-und-von-der-bvg-gibts-ein-gleis.html
# [INFO] Datei schon vorhanden: bvg-bester-ausbilder-im-deutschen-oepnv.html
# [INFO] Datei schon vorhanden: drei-bauphasen-am-gleisdreieck.html
# [INFO] Datei schon vorhanden: licht-im-schacht.html
# [INFO] Datei schon vorhanden: leg-mal-ne-andere-platte-auf.html
# [INFO] Datei schon vorhanden: vorbereitungen-am-hochbahnviadukt.html
# [INFO] Datei schon vorhanden: tiefgruendig.html
# [INFO] Datei schon vorhanden: s-bahn-berlin-und-bvg-geben-17-000-fahrscheine-fuer-freiwillig-engagierte.html
# [INFO] Datei schon vorhanden: schneller-als-gedacht.html
# [INFO] Datei schon vorhanden: astreine-sache.html
# [INFO] Datei schon vorhanden: aktuelle-lage-bei-der-u-bahn.html
# [INFO] Datei schon vorhanden: auf-gehts.html
# [INFO] Datei schon vorhanden: seitenwechsel.html
# [INFO] Datei schon vorhanden: zahltag.html
# [INFO] Datei schon vorhanden: goldener-loewe-fuer-bvg-sneaker.html
# [INFO] Datei schon vorhanden: zehn-jahre-unter-dem-regenbogen.html
# [INFO] Datei schon vorhanden: 2025-03-28-faehr-geht-vor-.html
# [INFO] Datei schon vorhanden: platz-da-2.html
# [INFO] Datei schon vorhanden: bitte-mal-freimachen.html
# [INFO] Datei schon vorhanden: 2025-03-13-neuer-betriebshof.html
# [INFO] Datei schon vorhanden: danz-schoen-fleissig.html
# [INFO] Datei schon vorhanden: mitten-ins-getuemmel.html
# [INFO] Datei schon vorhanden: fix-zum-pieks.html
# [INFO] Datei schon vorhanden: wahre-schoenheit-kommt-von-innen.html
# [INFO] Datei schon vorhanden: bvg-geht-style.html
# [INFO] Datei schon vorhanden: bvg-stellt-stabilitaetskonzept-vor.html
# [INFO] Datei schon vorhanden: betriebsvorstand-rolf-erfurt-verlaesst-die-bvg-im-besten-gegenseitigen-einvernehmen.html
# [INFO] Datei schon vorhanden: zukunft-des-oepnv-gemeinsam-berlin-bewegen.html
# [INFO] Datei schon vorhanden: kleine-pause-fuer-die-marzahner-m8.html
# [INFO] Datei schon vorhanden: ziemlich-zusammengepuzzeltes-team.html
# [INFO] Datei schon vorhanden: erfolgreich-bewegt.html
# [INFO] Datei schon vorhanden: drahtseilakt-bei-nacht.html
# [INFO] Datei schon vorhanden: das-leisten-wir-nachts.html
# [INFO] Datei schon vorhanden: mehr-busangebot-fuer-berlin.html
# [INFO] Datei schon vorhanden: einwandfrei-bleibt-dabei.html
# [INFO] Datei schon vorhanden: jelbi-feld-auf.html
# [INFO] Datei schon vorhanden: ey-was-geht.html
# [INFO] Datei schon vorhanden: ach-du-jelbe-neune.html
# [INFO] Datei schon vorhanden: immer-schoen-aufm-boden-bleiben.html
# [INFO] Datei schon vorhanden: wieder-ein-blisschen-barrierefreier.html
# [INFO] Datei schon vorhanden: trainingsauftakt.html
# [INFO] Datei schon vorhanden: die-bvg-hat-den-bogen-raus-2.html
# [INFO] Datei schon vorhanden: ausgezeichnet.html
# [INFO] Datei schon vorhanden: stimme-der-fahrgaeste.html
# [INFO] Datei schon vorhanden: brueckenbau-im-fruehlingstau.html
# [INFO] Datei schon vorhanden: kompetenz-bleibt-in-berlin.html
# [INFO] Datei schon vorhanden: herzenssache.html
# [INFO] Datei schon vorhanden: mehr-verlaesslichkeit-bei-der-ubahn.html
# [INFO] Datei schon vorhanden: auch-mal-schnuppern.html
# [INFO] Datei schon vorhanden: geladen-zum-beladen.html
# [INFO] Datei schon vorhanden: hochleistung-in-der-leitstelle.html
# [INFO] Datei schon vorhanden: bvg-informiert-ueber-anpassungen-bei-den-bus-fahrplaenen.html
# [INFO] Datei schon vorhanden: hoer-mal-wer-da-nagelt-bvg-raeumt-erneut-beim-adc-wettbewerb-ab.html
# [INFO] Datei schon vorhanden: laenger-unter-strom.html
# [INFO] Datei schon vorhanden: feinschliff-fuer-umleitungen-in-koepenick.html
# [INFO] Datei schon vorhanden: doppelter-einsatz.html
# [INFO] Datei schon vorhanden: langeweile-nicht-mit-der-bvg.html
# [INFO] Datei schon vorhanden: bvg-setzt-auf-die-leitung.html
# [INFO] Datei schon vorhanden: fertig-umbau-und-neubau-der-kehranlage.html
# [INFO] Datei schon vorhanden: wochenende-nicht-fuer-die-bvg.html
# [INFO] Datei schon vorhanden: karriere-website-par-excellence.html
# [INFO] Datei schon vorhanden: das-beste-zum-abschluss.html
# [INFO] Datei schon vorhanden: jetzt-ist-schicht-in-der-nacht.html
# [INFO] Datei schon vorhanden: erste-bvg-kundenzentren-und-das-fundbuero-oeffnen-wieder.html
# [INFO] Datei schon vorhanden: zusammen-halt.html
# [INFO] Datei schon vorhanden: gelenkiger-ersatz.html
# [INFO] Datei schon vorhanden: da-ist-wieder-musike-drin.html
# [INFO] Datei schon vorhanden: laenger-unter-strom-3.html
# [INFO] Datei schon vorhanden: streik-voellig-unangemessen.html
# [INFO] Datei schon vorhanden: am-ruder.html
# [INFO] Datei schon vorhanden: alte-pracht-ueberm-u-bahn-schacht.html
# [INFO] Datei schon vorhanden: all-inklusiv.html
# [INFO] Datei schon vorhanden: platz-fuer-neue-gleise.html
# [INFO] Datei schon vorhanden: neue-aufzuege-fuer-die-u9.html
# [INFO] Datei schon vorhanden: regenbogen-unterm-alex.html
# [INFO] Datei schon vorhanden: wird-gleis-erledigt.html
# [INFO] Datei schon vorhanden: die-u1-macht-sich-schick-fuer-die-u3.html
# [INFO] Datei schon vorhanden: henrik-falk-als-bvg-chef-im-amt.html
# [INFO] Datei schon vorhanden: das-fuenfte-jelbiment.html
# [INFO] Datei schon vorhanden: sie-feiern-wir-fahren-2.html
# [INFO] Datei schon vorhanden: gleis-gehts-hin-und-her.html
# [INFO] Datei schon vorhanden: herzklopfen-bei-der-bvg.html
# [INFO] Datei schon vorhanden: das-ging-ja-fix.html
# [INFO] Datei schon vorhanden: u2-faehrt-wieder-auf-voller-laenge-morgendliche-arbeiten-am-karfreitag.html
# [INFO] Datei schon vorhanden: zwickauer-tamtam.html
# [INFO] Datei schon vorhanden: sperrung-der-elsenbruecke.html
# [INFO] Datei schon vorhanden: gruenau-schneidet-gut-ab.html
# [INFO] Datei schon vorhanden: drei-in-einem-zug.html
# [INFO] Datei schon vorhanden: geburtstagsfaehrtchen.html
# [INFO] Datei schon vorhanden: gute-ausbildung-starke-perspektive.html
# [INFO] Datei schon vorhanden: ran-ans-werk.html
# [INFO] Datei schon vorhanden: mobilitaetswenderinnen-von-morgen.html
# [INFO] Datei schon vorhanden: dichter-und-denker.html
# [INFO] Datei schon vorhanden: bvg-stellt-sich-ein.html
# [INFO] Datei schon vorhanden: das-werden-wir-schon-zusammen-stemmen.html
# [INFO] Datei schon vorhanden: grundstein-der-ausbildung.html
# [INFO] Datei schon vorhanden: bahnhof-geliftet.html
# [INFO] Datei schon vorhanden: cbtc-digitalisierung-fuer-eine-noch-leistungsfaehigere-u-bahn-in-berlin.html
# [INFO] Datei schon vorhanden: bvg-werkelt-auf-der-u7.html
# [INFO] Datei schon vorhanden: vorstand-personal-und-soziales-verlaesst-die-bvg.html
# [INFO] Datei schon vorhanden: a-wie-abschied.html
# [INFO] Datei schon vorhanden: schlesisches-tor-geliftet.html
# [INFO] Datei schon vorhanden: ahoi-ms-tempelhof.html
# [INFO] Datei schon vorhanden: o-du-fleissige.html
# [INFO] Datei schon vorhanden: berlkoenig-faehrt-weiterhin-kostenlos-fuer-das-gesundheitswesen.html
# [INFO] Datei schon vorhanden: nachts-am-sterndamm.html
# [INFO] Datei schon vorhanden: jetzt-schlaegts-13.html
# [INFO] Datei schon vorhanden: stille-nacht-fleissige-nacht.html
# [INFO] Datei schon vorhanden: husch-am-bau.html
# [INFO] Datei schon vorhanden: brandneu-ausgezeichnet.html
# [INFO] Datei schon vorhanden: das-sind-die-neuen-die-kommen-jetzt-oefter.html
# [INFO] Datei schon vorhanden: weissenseer-kreuzungen-werden-gleisbehandelt.html
# [INFO] Datei schon vorhanden: stufenlos-verbunden.html
# [INFO] Datei schon vorhanden: kurz-angebunden.html
# [INFO] Datei schon vorhanden: manteltarifverhandlungen-2024.html
# [INFO] Datei schon vorhanden: nah-am-ball.html
# [INFO] Datei schon vorhanden: bvg-spendet-zwoelf-strassenbahnen-in-die-ukraine.html
# [INFO] Datei schon vorhanden: naechste-phase-am-u-bismarckstrasse.html
# [INFO] Datei schon vorhanden: immer-schoen-flexibel-bleiben.html
# [INFO] Datei schon vorhanden: eine-liebe-mit-tram-tram.html
# [INFO] Datei schon vorhanden: schnittstelle.html
# [INFO] Datei schon vorhanden: ein-gleis-drei-bahnen.html
# [INFO] Datei schon vorhanden: alt-marzahn-neue-gleise.html
# [INFO] Datei schon vorhanden: kostenloser-impf-shuttle-in-tegel.html
# [INFO] Datei schon vorhanden: kommt-wie-gerufen.html
# [INFO] Datei schon vorhanden: bei-uns-piepts-wohl.html
# [INFO] Datei schon vorhanden: leise-fliesst-der-verkehr.html
# [INFO] Datei schon vorhanden: flugs-zum-flug.html
# [INFO] Datei schon vorhanden: generation-j.html
# [INFO] Datei schon vorhanden: homophobie-kriegt-eine-geklebt.html
# [INFO] Datei schon vorhanden: fuer-einen-stest-straffen-gleiskoerper.html
# [INFO] Datei schon vorhanden: da-geht-noch-was.html
# [INFO] Datei schon vorhanden: simply-the-best.html
# [INFO] Datei schon vorhanden: beschluss-des-bvg-aufsichtsrats.html
# [INFO] Datei schon vorhanden: das-sehen-wir-uns-gleis-mal-an.html
# [INFO] Datei schon vorhanden: gleis-ins-gruenaue.html
# [INFO] Datei schon vorhanden: immer-der-strasse-nach.html
# [INFO] Datei schon vorhanden: kurz-kein-halt-fuer-neuen-asphalt.html
# [INFO] Datei schon vorhanden: mit-draht-zur-tat.html
# [INFO] Datei schon vorhanden: arbeitgeber-bvg-macht-den-hattrick.html
# [INFO] Datei schon vorhanden: was-nicht-passt-wird-passend-gemacht.html
# [INFO] Datei schon vorhanden: das-doppelte-gleischen.html
# [INFO] Datei schon vorhanden: herzensangelegenheit.html
# [INFO] Datei schon vorhanden: mueggelseetram.html
# [INFO] Datei schon vorhanden: wedding-weekend.html
# [INFO] Datei schon vorhanden: gemacht-fuer-die-zukunft-stadler-und-die-bvg-geben-ersten-einblick-in-die-neue-u-bahn.html
# [INFO] Datei schon vorhanden: alle-jahre-wieder.html
# [INFO] Datei schon vorhanden: uni3-barrierefrei.html
# [INFO] Datei schon vorhanden: schoenheitskur-fuer-die-pankstrasse.html
# [INFO] Datei schon vorhanden: sommerferien-sanierungsarbeiten.html
# [INFO] Datei schon vorhanden: ecken-und-kanten.html
# [INFO] Datei schon vorhanden: hier-gibts-das-volle-protram.html
# [INFO] Datei schon vorhanden: haste-toene-klar.html
# [INFO] Datei schon vorhanden: klick-klick-job.html
# [INFO] Datei schon vorhanden: u3-mal-hoch.html
# [INFO] Datei schon vorhanden: spicherlich-ein-guter-anfang.html
# [INFO] Datei schon vorhanden: ein-lifting-fuer-die-prinzessin.html
# [INFO] Datei schon vorhanden: ganz-schoen-drahtig.html
# [INFO] Datei schon vorhanden: das-pendel-das-bewegt.html
# [INFO] Datei schon vorhanden: shop-your-job.html
# [INFO] Datei schon vorhanden: tauschgeschaeft.html
# [INFO] Datei schon vorhanden: kurz-getrennt.html
# [INFO] Datei schon vorhanden: wannsee-wannsee-wann-seh-ich-dich-endlich-wieder.html
# [INFO] Datei schon vorhanden: mit-dem-zweiten-faehrt-man-besser-2.html
# [INFO] Datei schon vorhanden: nach-dem-streik-sorgt-graffiti-fuer-weitere-ausfaelle.html
# [INFO] Datei schon vorhanden: drei-neue-fuer-die-u.html
# [INFO] Datei schon vorhanden: linie-21-nach-wasserrohrbruch-aufgeteilt.html
# [INFO] Datei schon vorhanden: meisterleistung.html
# [INFO] Datei schon vorhanden: high-five.html
# [INFO] Datei schon vorhanden: laeuft-in-berlin.html
# [INFO] Datei schon vorhanden: strom-weg-fuer-einen-guten-zweck.html
# [INFO] Datei schon vorhanden: bitte-hinten-einsteigen.html
# [INFO] Datei schon vorhanden: jetzt-mal-bewegung-2.html
# [INFO] Datei schon vorhanden: ganz-verlegen.html
# [INFO] Datei schon vorhanden: total-faehrscherzt.html
# [INFO] Datei schon vorhanden: a1-auf-u3.html
# [INFO] Datei schon vorhanden: aufgedeckt.html
# [INFO] Datei schon vorhanden: handle-with-kehr.html
# [INFO] Datei schon vorhanden: alles-neu-m8-der-maerz.html
# [INFO] Datei schon vorhanden: auf-los-gehts-los.html
# [INFO] Datei schon vorhanden: kurze-pause-auf-der-suedlichen-u7.html
# [INFO] Datei schon vorhanden: im-fruehling-oefter-mal-ein-bussi.html
# [INFO] Datei schon vorhanden: bundesdruckerei-und-bvg-bringen-es-beim-mobilitaetsbudget-auf-den-punkt.html
# [INFO] Datei schon vorhanden: die-bvg-geht-an-die-decke.html
# [INFO] Datei schon vorhanden: brueckensperrung-neue-routen-fuer-busse.html
# [INFO] Datei schon vorhanden: bvg-gewinnt-goldene-kamera-digital.html
# [INFO] Datei schon vorhanden: jelbi-ist-deutschlands-beliebteste-mobilitaets-app.html
# [INFO] Datei schon vorhanden: neu-verkabelt.html
# [INFO] Datei schon vorhanden: hier-kunst-du-die-zukunft-sehen.html
# [INFO] Datei schon vorhanden: wo-gesaegt-wird.html
# [INFO] Datei schon vorhanden: die-bvg-hat-sie-alle-zusammen.html
# [INFO] Datei schon vorhanden: von-kopf-bis-fuss.html
# [INFO] Datei schon vorhanden: jetzt-geht-es-aufwaerts.html
# [INFO] Datei schon vorhanden: gesucht-und-gefunden-bvg-und-s-bahn-berlin-eroeffnen-gemeinsames-fundbuero.html
# [INFO] Datei schon vorhanden: vielfalt-ist-auch-gefuehlssache.html
# [INFO] Datei schon vorhanden: bvg-zeigt-sich-von-ihrer-neuen-seite.html
# [INFO] Datei schon vorhanden: provisorium-ade.html
# [INFO] Datei schon vorhanden: mittendrin-stadt-nur-dabei.html
# [INFO] Datei schon vorhanden: schotter-her.html
# [INFO] Datei schon vorhanden: altstadttour-am-wochenende.html
# [INFO] Datei schon vorhanden: eva-kreienkamp-zur-neuen-vorstandsvorsitzenden-der-bvg-bestellt.html
# [INFO] Datei schon vorhanden: alles-auf-linie.html
# [INFO] Datei schon vorhanden: neue-strassenbahnen-fuer-berlin.html
# [INFO] Datei schon vorhanden: u5-steht-auf-neue-gleise.html
# [INFO] Datei schon vorhanden: schnipp-schnapp-aeste-ab.html
# [INFO] Datei schon vorhanden: tief-verbunden.html
# [INFO] Datei schon vorhanden: von-wegen-ferien.html
# [INFO] Datei schon vorhanden: makeover-fuer-deutsche-oper.html
# [INFO] Datei schon vorhanden: besserwissen-erlaubt.html
# [INFO] Datei schon vorhanden: bvg-muva-aufzugersatz-bald-an-noch-mehr-stationen-verfuegbar.html
# [INFO] Datei schon vorhanden: zurueck-in-die-zukunft-2.html
# [INFO] Datei schon vorhanden: tool-das-ist-ja-einfach.html
# [INFO] Datei schon vorhanden: alles-neu-in-britz-sued.html
# [INFO] Datei schon vorhanden: nachts-wird-gependelt.html
# [INFO] Datei schon vorhanden: gudrun-jetzt-mal-ehrlich.html
# [INFO] Datei schon vorhanden: fokus-frauenfoerderung.html
# [INFO] Datei schon vorhanden: sonderzug-nach-hoenow.html
# [INFO] Datei schon vorhanden: unser-team-fuer-berlin.html
# [INFO] Datei schon vorhanden: bvg-2-300-mobilitaetswenderinnen-gesucht.html
# [INFO] Datei schon vorhanden: auf-den-putz-gehauen.html
# [INFO] Datei schon vorhanden: mit-jelbi-wird-die-charite-zur-sharite.html
# [INFO] Datei schon vorhanden: gleiszeitig-barrierefrei.html
# [INFO] Datei schon vorhanden: hochleistung.html
# [INFO] Datei schon vorhanden: das-war-jetzt-echtzeit.html
# [INFO] Datei schon vorhanden: halbe-strecke-grosser-sport.html
# [INFO] Datei schon vorhanden: kurzer-stopp-fuer-die-sicherheit.html
# [INFO] Datei schon vorhanden: die-wollen-nur-ueben.html
# [INFO] Datei schon vorhanden: e-busse-erobern-pankow-und-lichtenberg.html
# [INFO] Datei schon vorhanden: scharfes-angebot.html
# [INFO] Datei schon vorhanden: check-am-knoten.html
# [INFO] Datei schon vorhanden: die-richtige-fuer-den-grossen-gelben.html
# [INFO] Datei schon vorhanden: wir-machen-dicht.html
# [INFO] Datei schon vorhanden: erst-oben-dann-unten.html
# [INFO] Datei schon vorhanden: alles-muss-man-gelber-machen.html
# [INFO] Datei schon vorhanden: nach-halem-anderen-nun-noch-der-boden.html
# [INFO] Datei schon vorhanden: zahl-um-zahl.html
# [INFO] Datei schon vorhanden: richtig-rauskommen.html
# [INFO] Datei schon vorhanden: mobilitaetstrainings-fallen-aus.html
# [INFO] Datei schon vorhanden: finale-fuers-kreuzberger-viadukt.html
# [INFO] Datei schon vorhanden: jelbi-treibt-es-rund.html
# [INFO] Datei schon vorhanden: es-geht-hoch-und-runter.html
# [INFO] Datei schon vorhanden: gleisarbeiten-bahnhofstrasse-koepenick.html
# [INFO] Datei schon vorhanden: in-kreuzberg-gehts-hoch-her.html
# [INFO] Datei schon vorhanden: mit-spannung-durch-berlin.html
# [INFO] Datei schon vorhanden: nur-ein-kleiner-einschnitt.html
# [INFO] Datei schon vorhanden: cio-des-jahres.html
# [INFO] Datei schon vorhanden: mit-der-bvg-impfs-zentrum.html
# [INFO] Datei schon vorhanden: gasag-gruppe-investiert-in-bvg-tickets-fuer-mitarbeitende.html
# [INFO] Datei schon vorhanden: sie-feiern-wir-fahren.html
# [INFO] Datei schon vorhanden: gleiswechsel.html
# [INFO] Datei schon vorhanden: vogelhochzeit.html
# [INFO] Datei schon vorhanden: au-dit-ist-richtig-jut.html
# [INFO] Datei schon vorhanden: ran-an-die-decke.html
# [INFO] Datei schon vorhanden: neu-fahrdrahtet.html
# [INFO] Datei schon vorhanden: duerfen-wir-da-noch-mal-ganz-kurz-ran.html
# [INFO] Datei schon vorhanden: oberschoenegleise.html
# [INFO] Datei schon vorhanden: beim-klabautermann.html
# [INFO] Datei schon vorhanden: kleiner-lenkanstoss-jetzt-fahrerin-werden.html
# [INFO] Datei schon vorhanden: wir-koennen-dichthalten.html
# [INFO] Datei schon vorhanden: fit-fuer-die-fahrt.html
# [INFO] Datei schon vorhanden: gebuendelte-power.html
# [INFO] Datei schon vorhanden: neuer-halt.html
# [INFO] Datei schon vorhanden: die-bvg-hat-den-bogen-raus-3.html
# [INFO] Datei schon vorhanden: jetzt-das-kostenlose-schuelerticket-berlin-online-beantragen.html
# [INFO] Datei schon vorhanden: fahrscheinlich-fragen-wir-besser-unsere-fahrgaeste.html
# [INFO] Datei schon vorhanden: das-wird-mal-schnell-gem8.html
# [INFO] Datei schon vorhanden: keine-mobiliaetaetstrainings-bis-ende-des-jahres.html
# [INFO] Datei schon vorhanden: die-bvg-hat-ein-rad-up.html
# [INFO] Datei schon vorhanden: schnell-erledigt.html
# [INFO] Datei schon vorhanden: jenny-zeller-neue-personalvorstaendin-der-bvg.html
# [INFO] Datei schon vorhanden: fahrcard-fahr-rad.html
# [INFO] Datei schon vorhanden: platz-da.html
# [INFO] Datei schon vorhanden: der-kommt-jetzt-oefter.html
# [INFO] Datei schon vorhanden: tri-tra-tramwochen.html
# [INFO] Datei schon vorhanden: fit-fuer-die-zukunft.html
# [INFO] Datei schon vorhanden: hoch-drei.html
# [INFO] Datei schon vorhanden: alles-in-bester-ordnung.html
# [INFO] Datei schon vorhanden: das-perfekte-duo.html
# [INFO] Datei schon vorhanden: gevolt-und-gekonnt.html
# [INFO] Datei schon vorhanden: jenny-zeller-wird-neue-bvg-vorstaendin-fuer-personal-und-soziales.html
# [INFO] Datei schon vorhanden: im-zuge-der-wissenschaft.html
# [INFO] Datei schon vorhanden: berlkoenig-bc-jetzt-auch-in-heiligensee.html
# [INFO] Datei schon vorhanden: abgeleitet.html
# [INFO] Datei schon vorhanden: bus-und-bahn-beruf-und-familie.html
# [INFO] Datei schon vorhanden: fahrleitungsarbeiten-in-friedrichshagen.html
# [INFO] Datei schon vorhanden: mit-spannung-geht-es-weiter.html
# [INFO] Datei schon vorhanden: rundum-gelungen.html
# [INFO] Datei schon vorhanden: mal-was-fuers-gemuet.html
# [INFO] Datei schon vorhanden: regenbogenbunt.html
# [INFO] Datei schon vorhanden: bahn-frei-fuer-klimaschutz.html
# [INFO] Datei schon vorhanden: ausgedacht-ausgelacht-ausgezeichnet.html
# [INFO] Datei schon vorhanden: sicherheit-geht-vor-e-tretroller-muessen-vorerst-draussen-bleiben.html
# [INFO] Datei schon vorhanden: auf-und-ab-in-der-spichernstrasse.html
# [INFO] Datei schon vorhanden: telefonica-deutschland-und-bvg-schliessen-vertrag-fuer-weiteren-lte-ausbau.html
# [INFO] Datei schon vorhanden: stufenlos-zur-weihnachtsfeier.html
# [INFO] Datei schon vorhanden: das-doppelte-draehtchen.html
# [INFO] Datei schon vorhanden: berlin-mit-bus-und-bahn-zum-bachelor.html
# [INFO] Datei schon vorhanden: 2025-04-28-bauauftakt-u3-verlaengerung.html
# [INFO] Datei schon vorhanden: jetzt-mal-bewegung.html
# [INFO] Datei schon vorhanden: bahnsteig-wechsle-dich.html
# [INFO] Datei schon vorhanden: jaehrliche-personalversammlung-der-zentrale.html
# [INFO] Datei schon vorhanden: henrik-falk-wird-neuer-vorstandsvorsitzender-der-bvg.html
# [INFO] Datei schon vorhanden: vordereinstieg-beim-bus-ab-3-mai-wieder-moeglich.html
# [INFO] Datei schon vorhanden: noch-mehr-gelb-fuer-die-hauptstadt.html
# [INFO] Datei schon vorhanden: wenns-bei-glaette-glatt-laeuft.html
# [INFO] Datei schon vorhanden: zwei-mobilitaetstrainings-entfallen.html
# [INFO] Datei schon vorhanden: tunnellifting.html
# [INFO] Datei schon vorhanden: mit-abstand-die-besten-zeiten.html
# [INFO] Datei schon vorhanden: bvg-macht-boden-gut-2.html
# [INFO] Datei schon vorhanden: stufenfrei-zur-u3.html
# [INFO] Datei schon vorhanden: wir-seen-uns-wieder.html
# [INFO] Datei schon vorhanden: mach-mal-ne-pause.html
# [INFO] Datei schon vorhanden: treptow-koepenick-waechst-mit.html
# [INFO] Datei schon vorhanden: frag-doch-mal-berti.html
# [INFO] Datei schon vorhanden: hier-gehts-raus.html
# [INFO] Datei schon vorhanden: operation-am-offenen-herzstueck.html
# [INFO] Datei schon vorhanden: gleislein-wechsle-dich.html
# [INFO] Datei schon vorhanden: unter-parchimer-allee.html
# [INFO] Datei schon vorhanden: 17-000-kostenlose-fahrscheine-s-bahn-berlin-und-bvg-unterstuetzen-ehrenamtliche.html
# [INFO] Datei schon vorhanden: halbe-million-voller-erfolg.html
# [INFO] Datei schon vorhanden: gleischen-wechsle-dich.html
# [INFO] Datei schon vorhanden: auf-gehts-2.html
# [INFO] Datei schon vorhanden: 2025-04-02-abschluss-kleidferspende.html
# [INFO] Datei schon vorhanden: doublemaker.html
# [INFO] Datei schon vorhanden: die-bvg-findet-immer-einen-weg.html
# [INFO] Datei schon vorhanden: buendnis-fuer-die-mobilitaet-von-morgen.html
# [INFO] Datei schon vorhanden: wasserschaden.html
# [INFO] Datei schon vorhanden: bau-mit-kran-statt-strassenbahn.html
# [INFO] Datei schon vorhanden: noch-kein-zuschlag-fuer-neue-u-bahn.html
# [INFO] Datei schon vorhanden: gleis-auf-die-bruecke.html
# [INFO] Datei schon vorhanden: kabelarbeiten-gehen-weiter.html
# [INFO] Datei schon vorhanden: kurz-vor-acht.html
# [INFO] Datei schon vorhanden: zahlen-bitte.html
# [INFO] Datei schon vorhanden: wir-machen-mal-einen-auf.html
# [INFO] Datei schon vorhanden: partner-fuer-umweltfreundliche-mobilitaet.html
# [INFO] Datei schon vorhanden: transparent-und-ganz-nah-dran.html
# [INFO] Datei schon vorhanden: jelbi-shared-aus.html
# [INFO] Datei schon vorhanden: voller-durchblick-in-berlins-untergrund.html
# [INFO] Datei schon vorhanden: jetzt-ist-aber-mal-schluss.html
# [INFO] Datei schon vorhanden: jelbi-faehrt-jetzt-auch-taxi.html
# [INFO] Datei schon vorhanden: pressemitteilung-mit-sicherheit-mobil.html
# [INFO] Datei schon vorhanden: die-besten-aufm-bock-bus-em-in-berlin.html
# [INFO] Datei schon vorhanden: neuer-bezirk-jelbes-prinzip.html
# [INFO] Datei schon vorhanden: auf-dem-richtigen-weg.html
# [INFO] Datei schon vorhanden: berlkoenig-faehrt-die-helden-des-gesundheitswesens.html
# [INFO] Datei schon vorhanden: alte-weichen-weichen.html
# [INFO] Datei schon vorhanden: kurze-pause-in-der-landsberger-allee.html
# [INFO] Datei schon vorhanden: sonnenklar-warum-gelb-so-gruen-ist.html
# [INFO] Datei schon vorhanden: mit-leichten-einschraenkungen-auch-nach-den-ferien-zuverlaessig-unterwegs.html
# [INFO] Datei schon vorhanden: doppelter-wechsel.html
# [INFO] Datei schon vorhanden: tramtram-fuer-die-wissenschaft.html
# [INFO] Datei schon vorhanden: inklusiv-mobil.html
# [INFO] Datei schon vorhanden: platz-fuer-neues.html
# [INFO] Datei schon vorhanden: kantenreich.html
# [INFO] Datei schon vorhanden: der-eqt-support-93-berlin-im-design-des-bvg-sitzmusters.html
# [INFO] Datei schon vorhanden: neue-gleise-fuer-allee.html
# [INFO] Datei schon vorhanden: die-drei-fragezeiten.html
# [INFO] Datei schon vorhanden: 2025-04-17-ankuendigung-moblitaetstrainings.html
# [INFO] Datei schon vorhanden: vielfalt-lebe-hoch.html
# [INFO] Datei schon vorhanden: alexanderpendel-bis-fraesfurter-allee.html
# [INFO] Datei schon vorhanden: schluss-mit-frustig.html
# [INFO] Datei schon vorhanden: baumschnitt-entlang-der-m4.html
# [INFO] Datei schon vorhanden: vir-chow-wieder.html
# [INFO] Datei schon vorhanden: mantelvertrag-fuer-den-verkehrsvertrag-unterzeichnet.html
# [INFO] Datei schon vorhanden: auf-neuen-wegen.html
# [INFO] Datei schon vorhanden: geh-ma-uff-seite.html
# [INFO] Datei schon vorhanden: ueber-zwickau-nach-rudow.html
# [INFO] Datei schon vorhanden: 2025-01-21-pm-tram-simulatoren.html
# [INFO] Datei schon vorhanden: fundige-neuigkeiten.html
# [INFO] Datei schon vorhanden: brueckenbauer.html
# [INFO] Datei schon vorhanden: bvg-liefert-app.html
# [INFO] Datei schon vorhanden: spannende-nacht.html
# [INFO] Datei schon vorhanden: gleisbauarbeiten-warschauer-strasse.html
# [INFO] Datei schon vorhanden: die-bvg-regelt-das-schon.html
# [INFO] Datei schon vorhanden: frisch-geliftet.html
# [INFO] Datei schon vorhanden: stecker-rein.html
# [INFO] Datei schon vorhanden: wer-wilmer-punkte.html
# [INFO] Datei schon vorhanden: naechtliches-checken-von-wand-und-decken.html
# [INFO] Datei schon vorhanden: neue-u-bahn-stadler-und-die-bvg-stellen-ers-tes-jk-fahrzeug-vor.html
# [INFO] Datei schon vorhanden: dauerhaft-schoen.html
# [INFO] Datei schon vorhanden: geht-gleis-weiter.html
# [INFO] Datei schon vorhanden: gelbe-weihnachten-und-tramtram-zu-silvester.html
# [INFO] Datei schon vorhanden: die-bvg-macht-am-bogen-gut.html
# [INFO] Datei schon vorhanden: wo-laufen-sie-denn.html
# [INFO] Datei schon vorhanden: fit-happens.html
# [INFO] Datei schon vorhanden: neu-im-netz.html
# [INFO] Datei schon vorhanden: guter-rad.html
# [INFO] Datei schon vorhanden: e-busse-machen-sich-in-berlin-breit.html
# [INFO] Datei schon vorhanden: einschraenkungen-wegen-bombenentschaerfung-im-bereich-hauptbahnhof.html
# [INFO] Datei schon vorhanden: fleissiges-wochenende.html
# [INFO] Datei schon vorhanden: 3-2-1-los.html
# [INFO] Datei schon vorhanden: alles-fuer-die-mobilitaet.html
# [INFO] Datei schon vorhanden: ach-gleis-drauf.html
# [INFO] Datei schon vorhanden: strom-an.html
# [INFO] Datei schon vorhanden: bvg-kann-u-bahn-auftrag-weiter-nicht-ausloesen.html
# [INFO] Datei schon vorhanden: trampenlicht.html
# [INFO] Datei schon vorhanden: bvg-das-hoert-man.html
# [INFO] Datei schon vorhanden: frische-gleise-sind-absolut-m1.html
# [INFO] Datei schon vorhanden: alle-wege-fuehren-nach-strom.html
# [INFO] Datei schon vorhanden: 2025-04-25-aenderung-nutzungsordnung.html
# [INFO] Datei schon vorhanden: auf-die-groesse-kommt-es-doch-an.html
# [INFO] Datei schon vorhanden: hoer-mal-wer-da-spricht.html
# [INFO] Datei schon vorhanden: 3g-im-nahverkehr-bvg-fuehrt-vertragsstrafe-ein.html
# [INFO] Datei schon vorhanden: jelbi-macht-auch-am-washington-platz.html
# [INFO] Datei schon vorhanden: das-9-euro-ticket-kommt-an.html
# [INFO] Datei schon vorhanden: gut-geschuetzt.html
# [INFO] Datei schon vorhanden: die-sind-ja-ganz-schoen-dicht.html
# [INFO] Datei schon vorhanden: bvg-gibt-sich-die-kante.html
# [INFO] Datei schon vorhanden: bvg-kann-weitere-e-busse-bestellen.html
# [INFO] Datei schon vorhanden: busse-statt-bahnen-am-wendenschloss.html
# [INFO] Datei schon vorhanden: sportlich-und-flexibel.html
# [INFO] Datei schon vorhanden: ohne-ueberraschungen-ans-ziel.html
# [INFO] Datei schon vorhanden: wissen-auf-raedern.html
# [INFO] Datei schon vorhanden: gelb-und-gelb-gesellt-sich-gern.html
# [INFO] Datei schon vorhanden: buch-endlich.html
# [INFO] Datei schon vorhanden: im-pilgerschritt-ab-unter-die-decke.html
# [INFO] Datei schon vorhanden: neue-luft-schnuppern.html
# [INFO] Datei schon vorhanden: mit-spannung-erwartet.html
# [INFO] Datei schon vorhanden: berlkoenig-faehrt-weiter.html
# [INFO] Datei schon vorhanden: beste-beratung-auf-unterem-niveau.html
# [INFO] Datei schon vorhanden: lieber-fremdfahren-als-fremdgehen.html
# [INFO] Datei schon vorhanden: 21-kurz-gekuerzt.html
# [INFO] Datei schon vorhanden: auf-den-ton-kommt-es-an.html
# [INFO] Datei schon vorhanden: mit-der-bvg-zweigleisig-unterwegs.html
# [INFO] Datei schon vorhanden: achtung-ohrwurmalarm.html
# [INFO] Datei schon vorhanden: 90-baeume-fuer-berlin.html
# [INFO] Datei schon vorhanden: in-schoeneweide-schoene-gleise.html
# [INFO] Datei schon vorhanden: endspurt-fuer-das-9-euro-ticket.html
# [INFO] Datei schon vorhanden: mach-mal-halb-lang.html
# [INFO] Datei schon vorhanden: fuer-so-viel-schotter-macht-die-u55-mal-pause.html
# [INFO] Datei schon vorhanden: letzte-baummassnahmen.html
# [INFO] Datei schon vorhanden: barrierefrei-in-den-mai.html
# [INFO] Datei schon vorhanden: wir-haben-den-bogen-raus.html
# [INFO] Datei schon vorhanden: spannender-sonntagsdienst.html
# [INFO] Datei schon vorhanden: sechszellenter-plan.html
# [INFO] Datei schon vorhanden: neue-partner-fuer-9-uhr-tickets.html
# [INFO] Datei schon vorhanden: auf-der-u2-ist-die-bvg-wieder-dabei.html
# [INFO] Datei schon vorhanden: mast-have-der-m1.html
# [INFO] Datei schon vorhanden: das-erste-frauenticket-im-oepnv.html
# [INFO] Datei schon vorhanden: vorbildliches-engagement.html
# [INFO] Datei schon vorhanden: mobilitaetshubs-nehmen-an-fahrt-auf.html
# [INFO] Datei schon vorhanden: das-will-gut-bedacht-sein.html
# [INFO] Datei schon vorhanden: siemens-und-bvg-einigen-sich.html
# [INFO] Datei schon vorhanden: die-unglaublichen-2.html
# [INFO] Datei schon vorhanden: mitten-auf-die-12.html
# [INFO] Datei schon vorhanden: zwei-baustellen-gleiszeitig.html
# [INFO] Datei schon vorhanden: laufen-lassen.html
# [INFO] Datei schon vorhanden: jetzt-kommt-mal-zum-punkt.html
# [INFO] Datei schon vorhanden: nimm-drei.html
# [INFO] Datei schon vorhanden: schnittstelle-2.html
# [INFO] Datei schon vorhanden: mit-bvg-und-s-bahn-zum-impfen.html
# [INFO] Datei schon vorhanden: von-wegen-drahtseilakt.html
# [INFO] Datei schon vorhanden: bindungsphase-auf-der-u6.html
# [INFO] Datei schon vorhanden: aufzug-in-arbeit.html
# [INFO] Datei schon vorhanden: tramfahrerin-von-jetzt-auf-gleis.html
# [INFO] Datei schon vorhanden: lola-rennt-und-guenni-und-franzi-und-deniz-und-jette-und-jack-und-kevin-und.html
# [INFO] Datei schon vorhanden: bis-hierher-und-weiter.html
# [INFO] Datei schon vorhanden: halb-und-halb.html
# [INFO] Datei schon vorhanden: nah-am-wasser-gebaut.html
# [INFO] Datei schon vorhanden: jelbe-zehne.html
# [INFO] Datei schon vorhanden: markenkommunikation-die-wirkt.html
# [INFO] Datei schon vorhanden: alle-jahre-wieder-2.html
# [INFO] Datei schon vorhanden: fuer-die-zukunft-sehe-ich-jelbi.html
# [INFO] Datei schon vorhanden: bvg-bestellt-neuen-vorstand-betrieb.html
# [INFO] Datei schon vorhanden: wir-gehen-an-die-decke-2.html
# [INFO] Datei schon vorhanden: konzentration-des-busverkehrs-am-terminal-5-des-ber-neuer-haltestellenbereich-nimmt-betrieb-auf.html
# [INFO] Datei schon vorhanden: von-baeumen-und-bruecken.html
# [INFO] Datei schon vorhanden: freie-fahrt-fuer-vielfalt-staatsministerin-alabali-radovan-und-charta-der-vielfalt-besuchen-die-bvg.html
# [INFO] Datei schon vorhanden: strassenkreuzer.html
# [INFO] Datei schon vorhanden: mehr-sicht.html
# [INFO] Datei schon vorhanden: da-kehrt-flexibilitaet-ein.html
# [INFO] Datei schon vorhanden: bau-der-neuen-tram-laeuft.html
# [INFO] Datei schon vorhanden: abo-hallo.html
# [INFO] Datei schon vorhanden: trenn-dich.html
# [INFO] Datei schon vorhanden: start-des-naechsten-bauabschnitts-am-s-bahnhof-karlshorst.html
# [INFO] Datei schon vorhanden: die-bvg-spendet-16-trafos-an-die-ukraine.html

# %%
# Alle Dateien im Ordner auflisten
html_files = [f for f in os.listdir(SAVE_FOLDER) if f.endswith(".html")]

# Ergebnis anzeigen
print(f"Anzahl gespeicherter html-Dateien: {len(html_files)}")

# Beispielhafte Dateinamen ausgeben
print("Beispieldateien:", html_files[:5])
# Out:
# Anzahl gespeicherter html-Dateien: 936
# Beispieldateien: ['10-uhr-karten-gelten-eine-stunde-frueher.html', '13-points-go-to.html', '140-jahre-unter-strom.html', '155-000-mal-5.html', '17-000-kostenlose-fahrscheine-s-bahn-berlin-und-bvg-unterstuetzen-ehrenamtliche.html']

# %% [markdown]
# #### 4. Extraktion von Veröffentlichungsdatum und Text

# %%
# Liste für die Daten
data = []

# Alle HTML-Dateien durchgehen
files = [f for f in os.listdir(SAVE_FOLDER) if f.endswith(".html")]

for file in files:
    file_path = os.path.join(SAVE_FOLDER, file)
    try:
        with open(file_path, "r", encoding="utf-8") as f:
            html = f.read()

        soup = BeautifulSoup(html, "html.parser") # Links mit BeautifulSoup parsen
        time_tag = soup.find("time") # Time-Element suchen

        if time_tag and time_tag.has_attr("datetime"): # Prüfen, ob Veröffentlichungsdatum vorhanden
            date_str = time_tag["datetime"][:10]  # Nur Datumsformat yyyy-mm-dd 
            year = int(date_str.split("-")[0]) # Jahr extrahieren

            # Pressemitteilungen 2021–2025 übernehmen
            if 2021 <= year <= 2025:
                data.append({
                    "filename": file,
                    "date": date_str,
                    "year": year
                })
            else:
                # Dateien aus anderen Jahren ignorieren
                print(f"Datei {file} aus Jahr {year}, wird ignoriert.")
        else:
            print(f"Kein Datum gefunden in {file}")

    except Exception as e:
        print(f"Fehler bei {file}: {e}")

# DataFrame erstellen
pm_df = pd.DataFrame(data)
# Out:
# Datei 10-uhr-karten-gelten-eine-stunde-frueher.html aus Jahr 2020, wird ignoriert.
# Datei 17-000-kostenlose-fahrscheine-s-bahn-berlin-und-bvg-unterstuetzen-ehrenamtliche.html aus Jahr 2018, wird ignoriert.
# Datei 21-geteilt-durch-zwei.html aus Jahr 2018, wird ignoriert.
# Datei 3-2-1-los.html aus Jahr 2018, wird ignoriert.
# Datei 90-baeume-fuer-berlin.html aus Jahr 2019, wird ignoriert.
# Datei a1-auf-u3.html aus Jahr 2018, wird ignoriert.
# Datei abgeleitet.html aus Jahr 2019, wird ignoriert.
# Datei ach-du-jelbe-neune.html aus Jahr 2020, wird ignoriert.
# Datei ach-gleis-drauf.html aus Jahr 2020, wird ignoriert.
# Datei aehm-2.html aus Jahr 2020, wird ignoriert.
# Datei ahoi-ms-tempelhof.html aus Jahr 2018, wird ignoriert.
# Datei alexanderpendel-bis-fraesfurter-allee.html aus Jahr 2018, wird ignoriert.
# Datei alle-jahre-wieder-2.html aus Jahr 2020, wird ignoriert.
# Datei alle-jahre-wieder.html aus Jahr 2018, wird ignoriert.
# Datei alle-wege-fuehren-nach-strom.html aus Jahr 2019, wird ignoriert.
# Datei aller-guten-dinge-sind-vier.html aus Jahr 2018, wird ignoriert.
# Datei alles-fuer-die-mobilitaet.html aus Jahr 2020, wird ignoriert.
# Datei alles-nach-plan-macht-der-mai.html aus Jahr 2020, wird ignoriert.
# Datei alles-neu-in-britz-sued.html aus Jahr 2020, wird ignoriert.
# Datei alles-neu-m8-der-maerz.html aus Jahr 2019, wird ignoriert.
# Datei alt-marzahn-neue-gleise.html aus Jahr 2018, wird ignoriert.
# Datei alte-pracht-ueberm-u-bahn-schacht.html aus Jahr 2020, wird ignoriert.
# Datei altstadttour-am-wochenende.html aus Jahr 2018, wird ignoriert.
# Datei am-ruder.html aus Jahr 2019, wird ignoriert.
# Datei an-oberster-stelle.html aus Jahr 2020, wird ignoriert.
# Datei appy-birthday.html aus Jahr 2020, wird ignoriert.
# Datei arbeitgeber-bvg-macht-den-hattrick.html aus Jahr 2019, wird ignoriert.
# Datei astreine-arbeiten.html aus Jahr 2018, wird ignoriert.
# Datei astreine-sache.html aus Jahr 2020, wird ignoriert.
# Datei auch-schon-mal-zweigleisig-gefahren.html aus Jahr 2019, wird ignoriert.
# Datei auf-dem-richtigen-weg.html aus Jahr 2019, wird ignoriert.
# Datei auf-der-u2-ist-die-bvg-wieder-dabei.html aus Jahr 2020, wird ignoriert.
# Datei auf-die-gleise-fertig-los.html aus Jahr 2018, wird ignoriert.
# Datei auf-die-groesse-kommt-es-doch-an.html aus Jahr 2019, wird ignoriert.
# Datei auf-ein-letztes-mal.html aus Jahr 2018, wird ignoriert.
# Datei auf-gehts.html aus Jahr 2018, wird ignoriert.
# Datei auf-neuen-wegen.html aus Jahr 2019, wird ignoriert.
# Datei auf-und-ab-in-der-spichernstrasse.html aus Jahr 2018, wird ignoriert.
# Datei aufzuege-von-v-bis-z.html aus Jahr 2020, wird ignoriert.
# Datei aufzug-in-arbeit.html aus Jahr 2018, wird ignoriert.
# Datei aufzug-oeffne-dich.html aus Jahr 2020, wird ignoriert.
# Datei ausbildungsplaetze-fertig-los.html aus Jahr 2018, wird ignoriert.
# Datei ausgedacht-ausgelacht-ausgezeichnet.html aus Jahr 2018, wird ignoriert.
# Datei ausgezeichnet.html aus Jahr 2019, wird ignoriert.
# Datei ausprobieren-und-informieren.html aus Jahr 2019, wird ignoriert.
# Datei aussenrum.html aus Jahr 2018, wird ignoriert.
# Datei autofrei-wir-sind-dabei.html aus Jahr 2019, wird ignoriert.
# Datei bahnbruecke-ueber-karl-liebknecht-strasse-bekommt-neuen-witterungsschutz.html aus Jahr 2019, wird ignoriert.
# Datei bahnhof-geliftet.html aus Jahr 2018, wird ignoriert.
# Datei barrierefrei-zur-u3.html aus Jahr 2018, wird ignoriert.
# Datei bau-an-bruecke-sorgt-fuer-luecke.html aus Jahr 2019, wird ignoriert.
# Datei bau-mit-kran-statt-strassenbahn.html aus Jahr 2018, wird ignoriert.
# Datei bauarbeiten-bei-der-s-bahn-u5-faehrt-den-ganzen-tag-im-dichten-takt.html aus Jahr 2019, wird ignoriert.
# Datei bauleitung.html aus Jahr 2018, wird ignoriert.
# Datei bei-uns-piepts-wohl.html aus Jahr 2018, wird ignoriert.
# Datei beim-klabautermann.html aus Jahr 2018, wird ignoriert.
# Datei berlin-im-quadrat.html aus Jahr 2018, wird ignoriert.
# Datei berlin-mit-bus-und-bahn-zum-bachelor.html aus Jahr 2018, wird ignoriert.
# Datei berlin-tief-verbunden-die-neue-u5-ist-eroeffnet.html aus Jahr 2020, wird ignoriert.
# Datei berlin-tief-verbunden-u5-faehrt-bald-durch.html aus Jahr 2020, wird ignoriert.
# Datei berliner-verkehrsbetriebe-bvg-vergeben-vertrag-fuer-fahrgastunterstaende-exklusiv-an-die-wall-gmbh.html aus Jahr 2018, wird ignoriert.
# Datei berlkoenig-bc-jetzt-auch-in-heiligensee.html aus Jahr 2020, wird ignoriert.
# Datei berlkoenig-faehrt-die-helden-des-gesundheitswesens.html aus Jahr 2020, wird ignoriert.
# Datei berlkoenig-faehrt-weiter.html aus Jahr 2020, wird ignoriert.
# Datei berlkoenig-faehrt-weiterhin-kostenlos-fuer-das-gesundheitswesen.html aus Jahr 2020, wird ignoriert.
# Datei berlkoenig-faehrt-wieder-regulaer.html aus Jahr 2020, wird ignoriert.
# Datei berlkoenig-sonderfahrten-fuer-das-gesundheitswesen-bediengebiet-erneut-ausgeweitet-betriebszeiten-verlaengert.html aus Jahr 2020, wird ignoriert.
# Datei besser-laenger-haeufiger.html aus Jahr 2020, wird ignoriert.
# Datei besser-planen-koennen.html aus Jahr 2019, wird ignoriert.
# Datei besser-vernetzter-oepnv-deutsche-bahn-und-berliner-verkehrsbetriebe-kooperieren-bei-app-entwicklung.html aus Jahr 2018, wird ignoriert.
# Datei bitte-hinten-einsteigen.html aus Jahr 2020, wird ignoriert.
# Datei bitte-jetzt-wenden.html aus Jahr 2018, wird ignoriert.
# Datei bitte-nicht-moeckern.html aus Jahr 2020, wird ignoriert.
# Datei bitte-recht-fahrradfreundlich.html aus Jahr 2020, wird ignoriert.
# Datei brandneu-ausgezeichnet.html aus Jahr 2020, wird ignoriert.
# Datei brueckenbau-im-fruehlingstau.html aus Jahr 2019, wird ignoriert.
# Datei brueckenbauer.html aus Jahr 2018, wird ignoriert.
# Datei brueckensperrung-neue-routen-fuer-busse.html aus Jahr 2019, wird ignoriert.
# Datei buendnis-fuer-die-mobilitaet-von-morgen.html aus Jahr 2019, wird ignoriert.
# Datei bus-und-bahn-beruf-und-familie.html aus Jahr 2018, wird ignoriert.
# Datei busse-statt-bahnen-am-wendenschloss.html aus Jahr 2019, wird ignoriert.
# Datei bvg-bestellt-neuen-vorstand-betrieb.html aus Jahr 2019, wird ignoriert.
# Datei bvg-bester-ausbilder-im-deutschen-oepnv.html aus Jahr 2020, wird ignoriert.
# Datei bvg-bringt-mich-weiter.html aus Jahr 2020, wird ignoriert.
# Datei bvg-erneuert-die-fahrleitungen.html aus Jahr 2020, wird ignoriert.
# Datei bvg-gewinnt-goldene-kamera-digital.html aus Jahr 2018, wird ignoriert.
# Datei bvg-gibt-sich-die-kante.html aus Jahr 2019, wird ignoriert.
# Datei bvg-haelt-berlin-weiterhin-mobil.html aus Jahr 2020, wird ignoriert.
# Datei bvg-kann-u-bahn-auftrag-weiter-nicht-ausloesen.html aus Jahr 2019, wird ignoriert.
# Datei bvg-kontrolliert-einhaltung-der-maskenpflicht.html aus Jahr 2020, wird ignoriert.
# Datei bvg-macht-boden-gut.html aus Jahr 2020, wird ignoriert.
# Datei bvg-macht-sich-keine-platte.html aus Jahr 2020, wird ignoriert.
# Datei bvg-machts-nachts.html aus Jahr 2020, wird ignoriert.
# Datei bvg-nimmt-aufzug-am-nauener-platz-in-betrieb.html aus Jahr 2020, wird ignoriert.
# Datei bvg-ruestet-auf.html aus Jahr 2020, wird ignoriert.
# Datei bvg-schliesst-servicestuetzpunkt.html aus Jahr 2020, wird ignoriert.
# Datei bvg-setzt-auf-die-leitung.html aus Jahr 2019, wird ignoriert.
# Datei bvg-spendet-preisgeld.html aus Jahr 2018, wird ignoriert.
# Datei bvg-stellt-sich-ein.html aus Jahr 2020, wird ignoriert.
# Datei bvg-tauscht-aus.html aus Jahr 2020, wird ignoriert.
# Datei bvg-und-stadler-stellen-vor-die-zugkunft-der-berliner-u-bahn.html aus Jahr 2020, wird ignoriert.
# Datei countdown-fuer-die-autonomen-minibusse.html aus Jahr 2018, wird ignoriert.
# Datei da-kehrt-flexibilitaet-ein.html aus Jahr 2018, wird ignoriert.
# Datei da-muessen-wir-mal-schnell-ran.html aus Jahr 2018, wird ignoriert.
# Datei damm-entnehmen-wir-mal-proben.html aus Jahr 2019, wird ignoriert.
# Datei darauf-koennen-wir-uns-was-ausbilden.html aus Jahr 2020, wird ignoriert.
# Datei das-beste-zum-abschluss.html aus Jahr 2019, wird ignoriert.
# Datei das-dasein-hat-auch-noch-gute-seiten.html aus Jahr 2020, wird ignoriert.
# Datei das-erste-frauenticket-im-oepnv.html aus Jahr 2019, wird ignoriert.
# Datei das-fuenfte-jelbiment.html aus Jahr 2020, wird ignoriert.
# Datei das-ging-ja-fix.html aus Jahr 2020, wird ignoriert.
# Datei das-leisten-wir-nachts.html aus Jahr 2020, wird ignoriert.
# Datei das-pendelt-sich-ein.html aus Jahr 2018, wird ignoriert.
# Datei das-perfekte-duo.html aus Jahr 2020, wird ignoriert.
# Datei das-sehen-wir-uns-gleis-mal-an.html aus Jahr 2020, wird ignoriert.
# Datei das-sind-die-neuen-die-kommen-jetzt-oefter.html aus Jahr 2018, wird ignoriert.
# Datei das-war-jetzt-echtzeit.html aus Jahr 2020, wird ignoriert.
# Datei das-will-gut-bedacht-sein.html aus Jahr 2019, wird ignoriert.
# Datei das-wird-ein-kappes-ding.html aus Jahr 2019, wird ignoriert.
# Datei das-wird-mal-schnell-gem8.html aus Jahr 2019, wird ignoriert.
# Datei das-zauberwort-gegen-die-krise-kommunikation.html aus Jahr 2020, wird ignoriert.
# Datei deckenarbeiten-am-kaiserdamm.html aus Jahr 2019, wird ignoriert.
# Datei demo-fuer-verkehrswende-in-weissensee-stoppt-auch-den-oepnv.html aus Jahr 2019, wird ignoriert.
# Datei den-kutschi-umkurven.html aus Jahr 2019, wird ignoriert.
# Datei der-anschluss-wird-erreicht.html aus Jahr 2018, wird ignoriert.
# Datei der-berlkoenig-rollt-durch-berlin.html aus Jahr 2018, wird ignoriert.
# Datei der-eqt-support-93-berlin-im-design-des-bvg-sitzmusters.html aus Jahr 2018, wird ignoriert.
# Datei der-kommt-ja-wie-gerufen.html aus Jahr 2019, wird ignoriert.
# Datei der-kommt-jetzt-oefter.html aus Jahr 2018, wird ignoriert.
# Datei der-strom-kommt-kurz-vor-schluss.html aus Jahr 2020, wird ignoriert.
# Datei deutsche-bahn-und-berliner-verkehrsbetriebe-kooperieren-im-bereich-autonomes-fahren.html aus Jahr 2018, wird ignoriert.
# Datei die-bauweiche-muss-weichen.html aus Jahr 2019, wird ignoriert.
# Datei die-besten-aufm-bock-bus-em-in-berlin.html aus Jahr 2018, wird ignoriert.
# Datei die-bvg-feiert-90-geburtstag.html aus Jahr 2018, wird ignoriert.
# Datei die-bvg-findet-immer-einen-weg.html aus Jahr 2019, wird ignoriert.
# Datei die-bvg-geht-an-die-decke.html aus Jahr 2019, wird ignoriert.
# Datei die-bvg-hat-den-bogen-raus.html aus Jahr 2020, wird ignoriert.
# Datei die-bvg-legt-immer-die-gleiche-platte-auf.html aus Jahr 2020, wird ignoriert.
# Datei die-bvg-macht-am-bogen-gut.html aus Jahr 2019, wird ignoriert.
# Datei die-bvg-macht-nachts-ordentlich-schotter.html aus Jahr 2019, wird ignoriert.
# Datei die-bvg-regelt-das-schon.html aus Jahr 2020, wird ignoriert.
# Datei die-naechste-bitte.html aus Jahr 2020, wird ignoriert.
# Datei die-u1-macht-sich-schick-fuer-die-u3.html aus Jahr 2018, wird ignoriert.
# Datei die-u2-legt-einen-kurzen-stopf-ein.html aus Jahr 2020, wird ignoriert.
# Datei die-wollen-nur-ueben.html aus Jahr 2018, wird ignoriert.
# Datei donnanderstag.html aus Jahr 2020, wird ignoriert.
# Datei doppeltes-liftchen.html aus Jahr 2020, wird ignoriert.
# Datei drahtzieher.html aus Jahr 2019, wird ignoriert.
# Datei drei-in-einem-zug.html aus Jahr 2019, wird ignoriert.
# Datei drei-neue-fuer-die-u.html aus Jahr 2018, wird ignoriert.
# Datei duerfen-wir-da-noch-mal-ganz-kurz-ran.html aus Jahr 2019, wird ignoriert.
# Datei e-busse-erobern-pankow-und-lichtenberg.html aus Jahr 2020, wird ignoriert.
# Datei edison-stell-den-strom-ab.html aus Jahr 2018, wird ignoriert.
# Datei ein-gleis-drei-bahnen.html aus Jahr 2018, wird ignoriert.
# Datei ein-gleis-im-doerpfeld.html aus Jahr 2018, wird ignoriert.
# Datei ein-lifting-fuer-die-prinzessin.html aus Jahr 2020, wird ignoriert.
# Datei ein-schotte-verstaerkt-die-flotte.html aus Jahr 2020, wird ignoriert.
# Datei ein-stiefel-voller-busse-und-bahnen.html aus Jahr 2019, wird ignoriert.
# Datei einbahnstrasse.html aus Jahr 2018, wird ignoriert.
# Datei eine-runde-bitte.html aus Jahr 2018, wird ignoriert.
# Datei einigung-in-den-bvg-tarifverhandlungen.html aus Jahr 2019, wird ignoriert.
# Datei einmal-mit-allem.html aus Jahr 2018, wird ignoriert.
# Datei eins-zwei-barrierefrei.html aus Jahr 2020, wird ignoriert.
# Datei einschraenkungen-wegen-bombenentschaerfung-im-bereich-hauptbahnhof.html aus Jahr 2018, wird ignoriert.
# Datei elektrobusse-intelligent-laden-forschungscampus-mobility2grid-nimmt-innovative-ladestation-in-betrieb.html aus Jahr 2018, wird ignoriert.
# Datei elsenbruecke-teilweise-gesperrt.html aus Jahr 2018, wird ignoriert.
# Datei erst-oben-dann-unten.html aus Jahr 2020, wird ignoriert.
# Datei erste-bvg-kundenzentren-und-das-fundbuero-oeffnen-wieder.html aus Jahr 2020, wird ignoriert.
# Datei es-geht-aufwaerts.html aus Jahr 2019, wird ignoriert.
# Datei eva-kreienkamp-zur-neuen-vorstandsvorsitzenden-der-bvg-bestellt.html aus Jahr 2020, wird ignoriert.
# Datei exzellente-ausbildung-das-ist-besiegelt.html aus Jahr 2018, wird ignoriert.
# Datei fahrcard-fahr-rad.html aus Jahr 2018, wird ignoriert.
# Datei fahrleitungsarbeiten-in-friedrichshagen.html aus Jahr 2020, wird ignoriert.
# Datei fahrscheinlich-fragen-wir-besser-unsere-fahrgaeste.html aus Jahr 2020, wird ignoriert.
# Datei feinschliff-fuer-umleitungen-in-koepenick.html aus Jahr 2019, wird ignoriert.
# Datei fertig-umbau-und-neubau-der-kehranlage.html aus Jahr 2019, wird ignoriert.
# Datei fit-fuer-die-zukunft.html aus Jahr 2018, wird ignoriert.
# Datei flugs-in-die-schule.html aus Jahr 2020, wird ignoriert.
# Datei flugs-zum-flug.html aus Jahr 2020, wird ignoriert.
# Datei fokus-frauenfoerderung.html aus Jahr 2018, wird ignoriert.
# Datei frag-doch-mal-berti.html aus Jahr 2019, wird ignoriert.
# Datei freiertag-in-berlin.html aus Jahr 2020, wird ignoriert.
# Datei friedrichsfelde-nicht-zu-stoppen.html aus Jahr 2018, wird ignoriert.
# Datei frisch-geliftet.html aus Jahr 2019, wird ignoriert.
# Datei frische-gleise-fuer-die-prenzlauer-promenade.html aus Jahr 2018, wird ignoriert.
# Datei frische-gleise-sind-absolut-m1.html aus Jahr 2020, wird ignoriert.
# Datei fuer-die-zukunft-sehe-ich-jelbi.html aus Jahr 2019, wird ignoriert.
# Datei fuer-so-viel-schotter-macht-die-u55-mal-pause.html aus Jahr 2018, wird ignoriert.
# Datei fuersorge-fuer-gleise.html aus Jahr 2018, wird ignoriert.
# Datei fundige-neuigkeiten.html aus Jahr 2018, wird ignoriert.
# Datei geburtstagsfaehrtchen.html aus Jahr 2019, wird ignoriert.
# Datei geh-ma-uff-seite.html aus Jahr 2020, wird ignoriert.
# Datei geladen-zum-beladen.html aus Jahr 2019, wird ignoriert.
# Datei gelbe-weihnachten-und-tramtram-zu-silvester.html aus Jahr 2019, wird ignoriert.
# Datei gelbwerter-vorteil.html aus Jahr 2020, wird ignoriert.
# Datei gelenkiger-ersatz.html aus Jahr 2018, wird ignoriert.
# Datei gesucht-und-gefunden-bvg-und-s-bahn-berlin-eroeffnen-gemeinsames-fundbuero.html aus Jahr 2018, wird ignoriert.
# Datei geteilte-freude.html aus Jahr 2019, wird ignoriert.
# Datei gevolt-und-gekonnt.html aus Jahr 2020, wird ignoriert.
# Datei gewobag-und-bvg-eroeffnen-ersten-mobilitaetshub-berlins.html aus Jahr 2019, wird ignoriert.
# Datei gib-8.html aus Jahr 2018, wird ignoriert.
# Datei gleis-an-gleis.html aus Jahr 2018, wird ignoriert.
# Datei gleis-auf-die-bruecke.html aus Jahr 2019, wird ignoriert.
# Datei gleis-gehts-ins-all.html aus Jahr 2020, wird ignoriert.
# Datei gleis-gehts-los.html aus Jahr 2019, wird ignoriert.
# Datei gleis-gehts-weiter.html aus Jahr 2020, wird ignoriert.
# Datei gleis-ins-gruenaue.html aus Jahr 2020, wird ignoriert.
# Datei gleis-raus-gleis-rein.html aus Jahr 2020, wird ignoriert.
# Datei gleis-und-gleis-gesellt-sich-gern.html aus Jahr 2019, wird ignoriert.
# Datei gleis-wirds-wieder-besser.html aus Jahr 2019, wird ignoriert.
# Datei gleisarbeiten-bahnhofstrasse-koepenick.html aus Jahr 2018, wird ignoriert.
# Datei gleisbau-in-marzahn.html aus Jahr 2019, wird ignoriert.
# Datei gleisbauarbeiten-warschauer-strasse.html aus Jahr 2019, wird ignoriert.
# Datei gleislein-wechsle-dich.html aus Jahr 2020, wird ignoriert.
# Datei gleiswechsel.html aus Jahr 2018, wird ignoriert.
# Datei gleiszeitig-barrierefrei.html aus Jahr 2020, wird ignoriert.
# Datei goldener-loewe-fuer-bvg-sneaker.html aus Jahr 2018, wird ignoriert.
# Datei grosser-bahnhof-fuer-glinka.html aus Jahr 2020, wird ignoriert.
# Datei gruen-hinter-den-gleisen.html aus Jahr 2018, wird ignoriert.
# Datei gruenau-schneidet-gut-ab.html aus Jahr 2020, wird ignoriert.
# Datei gudrun-jetzt-mal-ehrlich.html aus Jahr 2018, wird ignoriert.
# Datei gut-geschuetzt.html aus Jahr 2018, wird ignoriert.
# Datei gute-nacht.html aus Jahr 2018, wird ignoriert.
# Datei guter-rad.html aus Jahr 2018, wird ignoriert.
# Datei halb-und-halb.html aus Jahr 2018, wird ignoriert.
# Datei halbe-million-voller-erfolg.html aus Jahr 2018, wird ignoriert.
# Datei halbe-strecke-grosser-sport.html aus Jahr 2018, wird ignoriert.
# Datei halt-mal.html aus Jahr 2018, wird ignoriert.
# Datei hier-gehts-lang.html aus Jahr 2018, wird ignoriert.
# Datei hier-gibts-das-volle-protram.html aus Jahr 2019, wird ignoriert.
# Datei hin-und-her.html aus Jahr 2018, wird ignoriert.
# Datei hintereinanderweg.html aus Jahr 2020, wird ignoriert.
# Datei hip-hip-jelbi.html aus Jahr 2019, wird ignoriert.
# Datei hoch-die-trassen.html aus Jahr 2020, wird ignoriert.
# Datei hoch-drei.html aus Jahr 2018, wird ignoriert.
# Datei hochleistung-in-der-leitstelle.html aus Jahr 2019, wird ignoriert.
# Datei hochleistung.html aus Jahr 2018, wird ignoriert.
# Datei hoer-mal-wer-da-nagelt-bvg-raeumt-erneut-beim-adc-wettbewerb-ab.html aus Jahr 2018, wird ignoriert.
# Datei hoer-mal-wer-da-spricht.html aus Jahr 2018, wird ignoriert.
# Datei hundert-seiten-liebe.html aus Jahr 2019, wird ignoriert.
# Datei im-fruehling-oefter-mal-ein-bussi.html aus Jahr 2018, wird ignoriert.
# Datei im-pilgerschritt-ab-unter-die-decke.html aus Jahr 2020, wird ignoriert.
# Datei im-zeichen-des-regenbogens.html aus Jahr 2019, wird ignoriert.
# Datei im-zuge-der-wissenschaft.html aus Jahr 2020, wird ignoriert.
# Datei immer-schoen-aufm-boden-bleiben.html aus Jahr 2020, wird ignoriert.
# Datei in-bus-und-bahn-nicht-oben-ohne.html aus Jahr 2020, wird ignoriert.
# Datei in-diesem-aufzug-kann-man-sich-sehen-lassen.html aus Jahr 2020, wird ignoriert.
# Datei in-kreuzberg-gehts-hoch-her.html aus Jahr 2020, wird ignoriert.
# Datei inklusionspreis-fuer-den-berlkoenig.html aus Jahr 2019, wird ignoriert.
# Datei inklusiv-mobil.html aus Jahr 2019, wird ignoriert.
# Datei intermodal-royal-berlkoenig-jetzt-mit-integrierten-reiseketten.html aus Jahr 2020, wird ignoriert.
# Datei ja-mai.html aus Jahr 2018, wird ignoriert.
# Datei jaehrliche-personalversammlung-der-zentrale.html aus Jahr 2019, wird ignoriert.
# Datei jede-menge-tram-tram.html aus Jahr 2019, wird ignoriert.
# Datei jelbi-birthday.html aus Jahr 2020, wird ignoriert.
# Datei jelbi-faehrt-jetzt-auch-taxi.html aus Jahr 2020, wird ignoriert.
# Datei jetzt-das-kostenlose-schuelerticket-berlin-online-beantragen.html aus Jahr 2019, wird ignoriert.
# Datei jetzt-ist-schicht-in-der-nacht.html aus Jahr 2020, wird ignoriert.
# Datei jetzt-mal-bewegung-2.html aus Jahr 2020, wird ignoriert.
# Datei jetzt-mal-bewegung.html aus Jahr 2018, wird ignoriert.
# Datei juchei-eiii.html aus Jahr 2019, wird ignoriert.
# Datei kabelarbeiten-gehen-weiter.html aus Jahr 2018, wird ignoriert.
# Datei karriere-website-par-excellence.html aus Jahr 2019, wird ignoriert.
# Datei keine-mobiliaetaetstrainings-bis-ende-des-jahres.html aus Jahr 2020, wird ignoriert.
# Datei kleine-massnahme-grosse-wirkung.html aus Jahr 2019, wird ignoriert.
# Datei kleine-wochenend-kuren-fuer-die-strassenbahn.html aus Jahr 2019, wird ignoriert.
# Datei kleiner-gelber-faehrt-sich-selber.html aus Jahr 2019, wird ignoriert.
# Datei klick-klick-job.html aus Jahr 2019, wird ignoriert.
# Datei knorke-schuhe-guter-zweck.html aus Jahr 2018, wird ignoriert.
# Datei komm-se-rin-koenn-se-rausfahren.html aus Jahr 2018, wird ignoriert.
# Datei kompetenz-bleibt-in-berlin.html aus Jahr 2019, wird ignoriert.
# Datei kultfaehrdaechtig.html aus Jahr 2018, wird ignoriert.
# Datei kurz-kein-halt-fuer-neuen-asphalt.html aus Jahr 2020, wird ignoriert.
# Datei kurze-pause-auf-der-suedlichen-u7.html aus Jahr 2019, wird ignoriert.
# Datei kurze-pause-in-der-landsberger-allee.html aus Jahr 2019, wird ignoriert.
# Datei kurze-pendelei-im-westen-der-u2.html aus Jahr 2020, wird ignoriert.
# Datei kurze-unterbrechung-auf-der-suedlichen-u7.html aus Jahr 2019, wird ignoriert.
# Datei kurze-unterbrechung.html aus Jahr 2018, wird ignoriert.
# Datei kurzer-stopp-fuer-die-sicherheit.html aus Jahr 2020, wird ignoriert.
# Datei laenger-unter-strom-2.html aus Jahr 2020, wird ignoriert.
# Datei laenger-unter-strom-3.html aus Jahr 2020, wird ignoriert.
# Datei laenger-unter-strom.html aus Jahr 2019, wird ignoriert.
# Datei langeweile-nicht-mit-der-bvg.html aus Jahr 2019, wird ignoriert.
# Datei laufen-lassen.html aus Jahr 2018, wird ignoriert.
# Datei leg-mal-ne-andere-platte-auf.html aus Jahr 2019, wird ignoriert.
# Datei letzte-baummassnahmen.html aus Jahr 2018, wird ignoriert.
# Datei letzte-post.html aus Jahr 2019, wird ignoriert.
# Datei linie-21-nach-wasserrohrbruch-aufgeteilt.html aus Jahr 2019, wird ignoriert.
# Datei mach-mal-halb-lang.html aus Jahr 2020, wird ignoriert.
# Datei mach-mal-ne-pause.html aus Jahr 2020, wird ignoriert.
# Datei machen-wir-den-friedrich-wilhelm-drunter.html aus Jahr 2019, wird ignoriert.
# Datei mal-wieder-gerade-machen.html aus Jahr 2019, wird ignoriert.
# Datei manchmal-kann-man-nichts-machen-ausser-weiter.html aus Jahr 2019, wird ignoriert.
# Datei mantelvertrag-fuer-den-verkehrsvertrag-unterzeichnet.html aus Jahr 2020, wird ignoriert.
# Datei maske-auf-film-ab.html aus Jahr 2020, wird ignoriert.
# Datei mehr-sicht.html aus Jahr 2018, wird ignoriert.
# Datei meisterhaft.html aus Jahr 2018, wird ignoriert.
# Datei mieten-auf-einen-streich.html aus Jahr 2020, wird ignoriert.
# Datei mit-abstand-die-beste-verbindung.html aus Jahr 2020, wird ignoriert.
# Datei mit-dem-zweiten-faehrt-man-besser.html aus Jahr 2020, wird ignoriert.
# Datei mit-der-oeffis-bande-in-die-arche.html aus Jahr 2020, wird ignoriert.
# Datei mitten-auf-die-12.html aus Jahr 2020, wird ignoriert.
# Datei mittendrin-stadt-nur-dabei.html aus Jahr 2019, wird ignoriert.
# Datei mobilitaetshubs-nehmen-an-fahrt-auf.html aus Jahr 2019, wird ignoriert.
# Datei mueggelseetram-2.html aus Jahr 2018, wird ignoriert.
# Datei mueggelseetram.html aus Jahr 2018, wird ignoriert.
# Datei my-way.html aus Jahr 2018, wird ignoriert.
# Datei nach-dem-streik-sorgt-graffiti-fuer-weitere-ausfaelle.html aus Jahr 2019, wird ignoriert.
# Datei nach-halem-anderen-nun-noch-der-boden.html aus Jahr 2020, wird ignoriert.
# Datei nachts-am-sterndamm.html aus Jahr 2018, wird ignoriert.
# Datei nachts-in-der-spichernstrasse.html aus Jahr 2019, wird ignoriert.
# Datei nachts-in-neukoelln.html aus Jahr 2018, wird ignoriert.
# Datei nachtschicht-unterm-adenauerplatz.html aus Jahr 2019, wird ignoriert.
# Datei nachtschichten-auf-der-u6.html aus Jahr 2018, wird ignoriert.
# Datei nachwuchs-bei-den-grossen-gelben.html aus Jahr 2018, wird ignoriert.
# Datei naechster-halt-weltkulturerbe__trashed.html aus Jahr 2019, wird ignoriert.
# Datei naechtliche-pendelei-auf-der-u6.html aus Jahr 2019, wird ignoriert.
# Datei neu-fahrdrahtet.html aus Jahr 2019, wird ignoriert.
# Datei neu-gestimmt.html aus Jahr 2020, wird ignoriert.
# Datei neu-verkabelt.html aus Jahr 2018, wird ignoriert.
# Datei neue-aufzuege-fuer-die-u9.html aus Jahr 2019, wird ignoriert.
# Datei neue-busse-fuer-die-bvg.html aus Jahr 2018, wird ignoriert.
# Datei neue-gleise-fuer-allee.html aus Jahr 2020, wird ignoriert.
# Datei neue-gleise-fuer-alt-koepenick.html aus Jahr 2019, wird ignoriert.
# Datei neue-gleise-fuer-die-m6-und-die-18.html aus Jahr 2019, wird ignoriert.
# Datei neue-partner-fuer-9-uhr-tickets.html aus Jahr 2020, wird ignoriert.
# Datei neue-schien-fuer-treskow-und-rhin.html aus Jahr 2019, wird ignoriert.
# Datei neue-strassenbahnen-fuer-berlin.html aus Jahr 2020, wird ignoriert.
# Datei neue-wege-gehen.html aus Jahr 2018, wird ignoriert.
# Datei neuer-bezirk-jelbes-prinzip.html aus Jahr 2020, wird ignoriert.
# Datei neuer-stahl-fuer-johannisthal.html aus Jahr 2019, wird ignoriert.
# Datei neues-jahr-neue-bahnsteige.html aus Jahr 2020, wird ignoriert.
# Datei noch-ein-wechsel-bei-der-bvg.html aus Jahr 2019, wird ignoriert.
# Datei noch-kein-zuschlag-fuer-neue-u-bahn.html aus Jahr 2019, wird ignoriert.
# Datei noch-mehr-gelb-fuer-die-hauptstadt.html aus Jahr 2020, wird ignoriert.
# Datei nur-ein-kleiner-einschnitt.html aus Jahr 2019, wird ignoriert.
# Datei oberschoenegleise.html aus Jahr 2018, wird ignoriert.
# Datei ohne-fleiss-kein-gleis-2.html aus Jahr 2020, wird ignoriert.
# Datei ohne-fleiss-kein-gleis.html aus Jahr 2020, wird ignoriert.
# Datei ohne-ueberraschungen-ans-ziel.html aus Jahr 2020, wird ignoriert.
# Datei onkel-toms-huette-u3-nach-brand-in-benachbarter-ladenpassage-weiter-unterbrochen.html aus Jahr 2020, wird ignoriert.
# Datei operation-am-offenen-herzstueck.html aus Jahr 2019, wird ignoriert.
# Datei packen-wirs-an.html aus Jahr 2020, wird ignoriert.
# Datei partner-fuer-umweltfreundliche-mobilitaet.html aus Jahr 2019, wird ignoriert.
# Datei platz-da-2.html aus Jahr 2019, wird ignoriert.
# Datei platz-da.html aus Jahr 2018, wird ignoriert.
# Datei platz-fuer-neue-bahnsteige.html aus Jahr 2020, wird ignoriert.
# Datei platz-fuer-neues-2.html aus Jahr 2020, wird ignoriert.
# Datei platz-fuer-neues.html aus Jahr 2019, wird ignoriert.
# Datei ran-ans-werk.html aus Jahr 2020, wird ignoriert.
# Datei regenbogenbunt.html aus Jahr 2018, wird ignoriert.
# Datei restarbeiten.html aus Jahr 2018, wird ignoriert.
# Datei rhinjehoben.html aus Jahr 2020, wird ignoriert.
# Datei richtig-rauskommen.html aus Jahr 2018, wird ignoriert.
# Datei royaler-gesundheitscheck.html aus Jahr 2019, wird ignoriert.
# Datei ruh-bahn.html aus Jahr 2018, wird ignoriert.
# Datei s-bahn-berlin-und-bvg-geben-17-000-fahrscheine-fuer-freiwillig-engagierte.html aus Jahr 2020, wird ignoriert.
# Datei scharfes-angebot.html aus Jahr 2018, wird ignoriert.
# Datei scheibenkleister.html aus Jahr 2018, wird ignoriert.
# Datei schienenfleissarbeiten.html aus Jahr 2018, wird ignoriert.
# Datei schmoll-doch-nicht.html aus Jahr 2018, wird ignoriert.
# Datei schnell-erledigt.html aus Jahr 2018, wird ignoriert.
# Datei schnelle-arbeit-u1-und-u3-fahren-bald-wieder.html aus Jahr 2019, wird ignoriert.
# Datei schneller-als-gedacht.html aus Jahr 2019, wird ignoriert.
# Datei schnipp-schnapp-aeste-ab.html aus Jahr 2018, wird ignoriert.
# Datei schnitt.html aus Jahr 2018, wird ignoriert.
# Datei schnittchen-fuer-die-haeckelstrasse.html aus Jahr 2019, wird ignoriert.
# Datei schnittgerecht.html aus Jahr 2019, wird ignoriert.
# Datei schnittstelle.html aus Jahr 2019, wird ignoriert.
# Datei schotte-rockt-die-linie-100.html aus Jahr 2020, wird ignoriert.
# Datei schwarz-weiss-schoen.html aus Jahr 2018, wird ignoriert.
# Datei sechsstellig-auf-bestellung.html aus Jahr 2018, wird ignoriert.
# Datei sei-doch-mal-etwas-flexibel.html aus Jahr 2018, wird ignoriert.
# Datei seitenwechsel.html aus Jahr 2019, wird ignoriert.
# Datei sicher-ist-sicher.html aus Jahr 2018, wird ignoriert.
# Datei sie-feiern-wir-fahren-2.html aus Jahr 2019, wird ignoriert.
# Datei sie-feiern-wir-fahren.html aus Jahr 2018, wird ignoriert.
# Datei siemens-und-bvg-einigen-sich.html aus Jahr 2018, wird ignoriert.
# Datei simply-the-best.html aus Jahr 2018, wird ignoriert.
# Datei so-ists-gleis-viel-besser.html aus Jahr 2020, wird ignoriert.
# Datei sommer-comeback-fuer-die-u12.html aus Jahr 2020, wird ignoriert.
# Datei sommerferien-sanierungsarbeiten.html aus Jahr 2018, wird ignoriert.
# Datei sonderzug-nach-hoenow.html aus Jahr 2019, wird ignoriert.
# Datei sonntagnacht-ecke-eberswalde.html aus Jahr 2018, wird ignoriert.
# Datei sonntagsausflug-mit-historischer-u-bahn.html aus Jahr 2019, wird ignoriert.
# Datei sperr-die-loeffel-ab.html aus Jahr 2019, wird ignoriert.
# Datei sperrung-elsenbruecke-drei-buslinien-betroffen.html aus Jahr 2020, wird ignoriert.
# Datei spicherlich-ein-guter-anfang.html aus Jahr 2020, wird ignoriert.
# Datei spieglein-spieglein-in-der-hand.html aus Jahr 2019, wird ignoriert.
# Datei sportlich-und-flexibel.html aus Jahr 2018, wird ignoriert.
# Datei start-des-naechsten-bauabschnitts-am-s-bahnhof-karlshorst.html aus Jahr 2019, wird ignoriert.
# Datei stecker-rein.html aus Jahr 2018, wird ignoriert.
# Datei stimme-der-fahrgaeste.html aus Jahr 2018, wird ignoriert.
# Datei strassenkreuzer.html aus Jahr 2018, wird ignoriert.
# Datei streik-beendet-busse-und-bahnen-der-bvg-kommen-wieder-in-den-gewohnten-takt.html aus Jahr 2020, wird ignoriert.
# Datei streik-voellig-unangemessen.html aus Jahr 2019, wird ignoriert.
# Datei strom-an.html aus Jahr 2020, wird ignoriert.
# Datei stufenfrei-zur-u3.html aus Jahr 2019, wird ignoriert.
# Datei stufenlos-zur-weihnachtsfeier.html aus Jahr 2018, wird ignoriert.
# Datei tauschrausch.html aus Jahr 2020, wird ignoriert.
# Datei telefonica-deutschland-telekom-und-vodafone-schalten-gemeinsam-lte-auf-ersten-u-bahn-linien-in-berlin-ein.html aus Jahr 2019, wird ignoriert.
# Datei telefonica-deutschland-und-bvg-schliessen-vertrag-fuer-weiteren-lte-ausbau.html aus Jahr 2019, wird ignoriert.
# Datei titel-verteidigt.html aus Jahr 2018, wird ignoriert.
# Datei trainingsauftakt.html aus Jahr 2018, wird ignoriert.
# Datei tramfahrerin-von-jetzt-auf-gleis.html aus Jahr 2019, wird ignoriert.
# Datei trenn-dich.html aus Jahr 2020, wird ignoriert.
# Datei triple-fuer-die-bvg.html aus Jahr 2020, wird ignoriert.
# Datei tueren-auf.html aus Jahr 2018, wird ignoriert.
# Datei tunnelpflege-und-weichenteilaustausch.html aus Jahr 2019, wird ignoriert.
# Datei u1-und-u3-nach-boeschungsbrand-weiterhin-unterbrochen.html aus Jahr 2019, wird ignoriert.
# Datei u1-zum-zweiten-u3.html aus Jahr 2018, wird ignoriert.
# Datei u2-faehrt-wieder-auf-voller-laenge-morgendliche-arbeiten-am-karfreitag.html aus Jahr 2019, wird ignoriert.
# Datei u3-mal-hoch.html aus Jahr 2018, wird ignoriert.
# Datei u5-pendelt-sich-ein.html aus Jahr 2019, wird ignoriert.
# Datei u55-pausiert.html aus Jahr 2019, wird ignoriert.
# Datei ueber-zwickau-nach-rudow.html aus Jahr 2019, wird ignoriert.
# Datei um-den-alex-rum.html aus Jahr 2018, wird ignoriert.
# Datei und-hier-die-gewinnzahlen-zum-wochenende-46-47-42-195.html aus Jahr 2019, wird ignoriert.
# Datei ungekehrt.html aus Jahr 2018, wird ignoriert.
# Datei uni3-barrierefrei.html aus Jahr 2018, wird ignoriert.
# Datei unser-team-fuer-berlin.html aus Jahr 2018, wird ignoriert.
# Datei unter-parchimer-allee.html aus Jahr 2018, wird ignoriert.
# Datei unterwegs-im-netz.html aus Jahr 2018, wird ignoriert.
# Datei verlaengerung-auf-der-see-meile.html aus Jahr 2019, wird ignoriert.
# Datei verlaengerung-in-der-eldenaer.html aus Jahr 2018, wird ignoriert.
# Datei verlaengerung-zwischen-b-und-c.html aus Jahr 2020, wird ignoriert.
# Datei viel-gleis-und-etwas-fahrleitung.html aus Jahr 2019, wird ignoriert.
# Datei vier-gewinnt.html aus Jahr 2020, wird ignoriert.
# Datei vitejte.html aus Jahr 2018, wird ignoriert.
# Datei voll-im-training-2.html aus Jahr 2020, wird ignoriert.
# Datei voll-im-training.html aus Jahr 2019, wird ignoriert.
# Datei voller-durchblick-in-berlins-untergrund.html aus Jahr 2019, wird ignoriert.
# Datei von-amrum-nach-turin.html aus Jahr 2018, wird ignoriert.
# Datei von-audit-bis-zertifiziert.html aus Jahr 2019, wird ignoriert.
# Datei von-baeumen-und-bruecken.html aus Jahr 2018, wird ignoriert.
# Datei von-kopf-bis-fuss.html aus Jahr 2020, wird ignoriert.
# Datei von-langer-hans-geplant.html aus Jahr 2019, wird ignoriert.
# Datei von-wegen-drahtseilakt.html aus Jahr 2019, wird ignoriert.
# Datei von-wegen-ferien.html aus Jahr 2019, wird ignoriert.
# Datei vorbereitungen-am-hochbahnviadukt.html aus Jahr 2020, wird ignoriert.
# Datei vorbildliches-engagement.html aus Jahr 2018, wird ignoriert.
# Datei wahre-schoenheit-kommt-von-innen.html aus Jahr 2020, wird ignoriert.
# Datei wannsee-wannsee-wann-seh-ich-dich-endlich-wieder.html aus Jahr 2019, wird ignoriert.
# Datei was-nicht-passt-wird-passend-gemacht.html aus Jahr 2020, wird ignoriert.
# Datei wasserschaden.html aus Jahr 2018, wird ignoriert.
# Datei weichen-muessen-weichen.html aus Jahr 2020, wird ignoriert.
# Datei weichenmacher.html aus Jahr 2019, wird ignoriert.
# Datei weissenseer-kreuzungen-werden-gleisbehandelt.html aus Jahr 2019, wird ignoriert.
# Datei weiter-gehts-auf-der-landsberger-allee.html aus Jahr 2019, wird ignoriert.
# Datei weiterarbeiten.html aus Jahr 2018, wird ignoriert.
# Datei weitere-e-busse-fuer-die-bvg.html aus Jahr 2019, wird ignoriert.
# Datei welcome-to-berlin.html aus Jahr 2018, wird ignoriert.
# Datei wieder-ein-blisschen-barrierefreier.html aus Jahr 2018, wird ignoriert.
# Datei wieder-im-takt.html aus Jahr 2020, wird ignoriert.
# Datei wir-bauen-auf-ausbildung.html aus Jahr 2020, wird ignoriert.
# Datei wir-haben-den-bogen-raus.html aus Jahr 2018, wird ignoriert.
# Datei wir-koennen-dichthalten.html aus Jahr 2018, wird ignoriert.
# Datei wir-lassen-keinen-fahren.html aus Jahr 2018, wird ignoriert.
# Datei wir-machen-dicht.html aus Jahr 2018, wird ignoriert.
# Datei wir-uebernehmen-die-leitung.html aus Jahr 2018, wird ignoriert.
# Datei wo-gesaegt-wird.html aus Jahr 2018, wird ignoriert.
# Datei wo-laufen-sie-denn.html aus Jahr 2018, wird ignoriert.
# Datei wochenende-nicht-fuer-die-bvg.html aus Jahr 2019, wird ignoriert.
# Datei x36er-wieder-an-bord.html aus Jahr 2020, wird ignoriert.
# Datei zahltag.html aus Jahr 2018, wird ignoriert.
# Datei ziemlich-zusammengepuzzeltes-team.html aus Jahr 2020, wird ignoriert.
# Datei zusaetzliche-einschraenkung-fuer-den-txl.html aus Jahr 2018, wird ignoriert.
# Datei zwei-mobilitaetstrainings-entfallen.html aus Jahr 2020, wird ignoriert.
# Datei zwei-mobilitaetstrainings-finden-nicht-statt.html aus Jahr 2020, wird ignoriert.
# Datei zweimal-anders-einmal-neu.html aus Jahr 2019, wird ignoriert.
# Datei zwickauer-tamtam.html aus Jahr 2018, wird ignoriert.

# %% [markdown]
# #### 5. Speicherung der Metadaten (CSV & SQLite)

# %%
# Metadaten als CSV-Datei speichern
csv_path = os.path.join(OUTPUT_FOLDER, "pm_bvg_valid.csv")
pm_df.to_csv(csv_path, index=False)
print(f"CSV gespeichert unter {csv_path}")
# Out:
# CSV gespeichert unter output\pm_bvg_valid.csv

# %%
# Metadaten als SQL speichern
SQL_PATH = os.path.join(OUTPUT_FOLDER, "dwh_pm_bvg.sqlite3")
conn = sqlite3.connect(SQL_PATH)
pm_df.to_sql("pm_bvg_valid", conn, if_exists="replace", index=False)
conn.close()
print(f"SQL gespeichert unter {SQL_PATH}")
# Out:
# SQL gespeichert unter output\dwh_pm_bvg.sqlite3

# %% [markdown]
# #### 6. Definition der Verarbeitungsfunktionen

# %%
# Pressemitteilung verarbeiten
def process_press_release(press_release):
    # Nur Dateinamen rausholen
    filename = os.path.basename(press_release["filename"])
    full_path = os.path.join(SAVE_FOLDER, filename)

    # HTML laden mit ausgelagerter Funktion
    html = read_html_file(full_path)

    # Text bereinigen mit ausgelagerter Funktion
    items = process_html(html, stopwords_list)

    # Häufigkeit jedes Wortes zählen
    count = pd.Series(items).value_counts()

    # Als DataFrame formatieren mit Spalten Wort, Medium, Datum
    count_df = count.to_frame()
    count_df.columns = ["count"]
    count_df["word"] = count_df.index
    count_df["source"] = "bvg_pm"  # Quelle festlegen 
    count_df["date"] = press_release["date"]

    return count_df

# %%
# Liste für die Ergebnisse-Sammlung 
collection = []

# %%
# Funktion: Funktion process_press_release anwenden, in der Variable collection speichern und Erfolg oder Fehler ausgeben
def process_wrapper(press_release):
    filename = press_release["filename"]
    try:
        count = process_press_release(press_release)
        print(f"[INFO] Verarbeitung erfolgreich: {filename}")
        collection.append(count)
    except Exception as e:
        print(f"[ERROR] Fehler bei {filename}: {e}")

# %% [markdown]
# #### 7. Anwendung der Verarbeitungsfunktionen auf die Pressemitteilungen

# %%
# Verarbeitung aller Pressemitteilungen
pm_df.apply(process_wrapper, axis=1)

# Alle Ergebnisse in einer Tabelle zusammenführen
data = pd.concat(collection, axis=0)
print("Data shape:", data.shape)
# Out:
# [INFO] Verarbeitung erfolgreich: 13-points-go-to.html
# [INFO] Verarbeitung erfolgreich: 140-jahre-unter-strom.html
# [INFO] Verarbeitung erfolgreich: 155-000-mal-5.html
# [INFO] Verarbeitung erfolgreich: 2025-01-03-pm-kleidersammelaktion0.html
# [INFO] Verarbeitung erfolgreich: 2025-01-08-pm-zahlen-2024.html
# [INFO] Verarbeitung erfolgreich: 2025-01-13-pm-neuer-e-gelenkbus.html
# [INFO] Verarbeitung erfolgreich: 2025-01-15-tarif-2025.html
# [INFO] Verarbeitung erfolgreich: 2025-01-21-pm-tram-simulatoren.html
# [INFO] Verarbeitung erfolgreich: 2025-01-29-pm-bvg-muva-barrierefrei-ab-maerz-berlinweit.html
# [INFO] Verarbeitung erfolgreich: 2025-02-04-ideen-die-berlin-bewegen.html
# [INFO] Verarbeitung erfolgreich: 2025-02-19-aufsichtsrat-beschliesst-neuaufstellung-des-bvg-vorstands.html
# [INFO] Verarbeitung erfolgreich: 2025-03-10-update-stabilitaet-der-bvg0.html
# [INFO] Verarbeitung erfolgreich: 2025-03-13-neuer-betriebshof.html
# [INFO] Verarbeitung erfolgreich: 2025-03-28-faehr-geht-vor-.html
# [INFO] Verarbeitung erfolgreich: 2025-04-02-abschluss-kleidferspende.html
# [INFO] Verarbeitung erfolgreich: 2025-04-14-abschluss-reinigungsstreife.html
# [INFO] Verarbeitung erfolgreich: 2025-04-16-neue-linie-215.html
# [INFO] Verarbeitung erfolgreich: 2025-04-17-ankuendigung-moblitaetstrainings.html
# [INFO] Verarbeitung erfolgreich: 2025-04-25-aenderung-nutzungsordnung.html
# [INFO] Verarbeitung erfolgreich: 2025-04-28-bauauftakt-u3-verlaengerung.html
# [INFO] Verarbeitung erfolgreich: 2025-05-02-muva-zwischenbilanz.html
# [INFO] Verarbeitung erfolgreich: 21-kurz-gekuerzt.html
# [INFO] Verarbeitung erfolgreich: 25-jahre-strassenbahn-auf-dem-alex.html
# [INFO] Verarbeitung erfolgreich: 3g-im-nahverkehr-bvg-fuehrt-vertragsstrafe-ein.html
# [INFO] Verarbeitung erfolgreich: a-wie-abschied.html
# [INFO] Verarbeitung erfolgreich: abo-hallo.html
# [INFO] Verarbeitung erfolgreich: achtung-ohrwurmalarm.html
# [INFO] Verarbeitung erfolgreich: ahoi-paule-iii.html
# [INFO] Verarbeitung erfolgreich: aktuelle-lage-bei-der-u-bahn.html
# [INFO] Verarbeitung erfolgreich: all-inklusiv.html
# [INFO] Verarbeitung erfolgreich: allee-an-bord.html
# [INFO] Verarbeitung erfolgreich: alles-auf-linie.html
# [INFO] Verarbeitung erfolgreich: alles-in-bester-ordnung.html
# [INFO] Verarbeitung erfolgreich: alles-muss-man-gelber-machen.html
# [INFO] Verarbeitung erfolgreich: alles-nach-plan.html
# [INFO] Verarbeitung erfolgreich: alte-weichen-weichen.html
# [INFO] Verarbeitung erfolgreich: am-automaten-kann-mans-auch-guthaben.html
# [INFO] Verarbeitung erfolgreich: an-die-riemen.html
# [INFO] Verarbeitung erfolgreich: au-dit-ist-richtig-jut.html
# [INFO] Verarbeitung erfolgreich: auch-mal-schnuppern.html
# [INFO] Verarbeitung erfolgreich: auf-den-putz-gehauen.html
# [INFO] Verarbeitung erfolgreich: auf-den-ton-kommt-es-an.html
# [INFO] Verarbeitung erfolgreich: auf-ein-neues.html
# [INFO] Verarbeitung erfolgreich: auf-einen-pieks-zur-bvg.html
# [INFO] Verarbeitung erfolgreich: auf-gehts-2.html
# [INFO] Verarbeitung erfolgreich: auf-los-gehts-los.html
# [INFO] Verarbeitung erfolgreich: aufgedeckt.html
# [INFO] Verarbeitung erfolgreich: aus-zwei-mach-zweihundert.html
# [INFO] Verarbeitung erfolgreich: ausgezeichnet-ausgebildet.html
# [INFO] Verarbeitung erfolgreich: ausgezeichnete-kommunikation.html
# [INFO] Verarbeitung erfolgreich: ausgezeichneter-klang.html
# [INFO] Verarbeitung erfolgreich: bahn-frei-fuer-klimaschutz.html
# [INFO] Verarbeitung erfolgreich: bahnsteig-wechsle-dich.html
# [INFO] Verarbeitung erfolgreich: bargeldlos-im-bus.html
# [INFO] Verarbeitung erfolgreich: barrierefrei-in-den-mai.html
# [INFO] Verarbeitung erfolgreich: bau-der-neuen-tram-laeuft.html
# [INFO] Verarbeitung erfolgreich: baumschnitt-entlang-der-m4.html
# [INFO] Verarbeitung erfolgreich: bayern-gehoert-jetzt-zu-berlin.html
# [INFO] Verarbeitung erfolgreich: bei-der-bvg-kann-mans-richtig-guthaben.html
# [INFO] Verarbeitung erfolgreich: berlin-bleibt-mobil.html
# [INFO] Verarbeitung erfolgreich: berliner-wasserbetriebe-buddeln-der-tram-den-weg-frei.html
# [INFO] Verarbeitung erfolgreich: berlins-aelteste-untergrundbewegung.html
# [INFO] Verarbeitung erfolgreich: berlkoenig-geht-neue-angebote-kommen.html
# [INFO] Verarbeitung erfolgreich: beschluss-des-bvg-aufsichtsrats.html
# [INFO] Verarbeitung erfolgreich: besserwissen-erlaubt.html
# [INFO] Verarbeitung erfolgreich: beste-beratung-auf-unterem-niveau.html
# [INFO] Verarbeitung erfolgreich: betriebsvorstand-rolf-erfurt-verlaesst-die-bvg-im-besten-gegenseitigen-einvernehmen.html
# [INFO] Verarbeitung erfolgreich: bindungsphase-auf-der-u6.html
# [INFO] Verarbeitung erfolgreich: bis-hierher-und-weiter.html
# [INFO] Verarbeitung erfolgreich: bitte-mal-freimachen.html
# [INFO] Verarbeitung erfolgreich: buch-endlich.html
# [INFO] Verarbeitung erfolgreich: bund-fuer-bunt.html
# [INFO] Verarbeitung erfolgreich: bundesdruckerei-und-bvg-bringen-es-beim-mobilitaetsbudget-auf-den-punkt.html
# [INFO] Verarbeitung erfolgreich: bundeskanzler-scholz-besucht-die-bvg.html
# [INFO] Verarbeitung erfolgreich: bunt-fuers-leben.html
# [INFO] Verarbeitung erfolgreich: bus-jetzt-auch-mal-sein.html
# [INFO] Verarbeitung erfolgreich: busse-und-bahnen-der-bvg-sind-am-27-maerz-wie-gewohnt-unterwegs.html
# [INFO] Verarbeitung erfolgreich: bvg-2-300-mobilitaetswenderinnen-gesucht.html
# [INFO] Verarbeitung erfolgreich: bvg-beginnt-mit-gleiseinbau-in-moabit.html
# [INFO] Verarbeitung erfolgreich: bvg-bindet-sich.html
# [INFO] Verarbeitung erfolgreich: bvg-bleibt-am-ball.html
# [INFO] Verarbeitung erfolgreich: bvg-das-hoert-man.html
# [INFO] Verarbeitung erfolgreich: bvg-faehrt-jetzt-auf-der-wissenschaftsschiene.html
# [INFO] Verarbeitung erfolgreich: bvg-geht-style.html
# [INFO] Verarbeitung erfolgreich: bvg-hat-den-richtigen-draht-nach-oben.html
# [INFO] Verarbeitung erfolgreich: bvg-hebt-das-niveau.html
# [INFO] Verarbeitung erfolgreich: bvg-hilft-gefluechteten.html
# [INFO] Verarbeitung erfolgreich: bvg-informiert-ueber-anpassungen-bei-den-bus-fahrplaenen.html
# [INFO] Verarbeitung erfolgreich: bvg-ist-auf-draht.html
# [INFO] Verarbeitung erfolgreich: bvg-kann-weitere-e-busse-bestellen.html
# [INFO] Verarbeitung erfolgreich: bvg-kontrolliert-3g.html
# [INFO] Verarbeitung erfolgreich: bvg-laesst-ausrichten.html
# [INFO] Verarbeitung erfolgreich: bvg-liefert-app.html
# [INFO] Verarbeitung erfolgreich: bvg-macht-boden-gut-2.html
# [INFO] Verarbeitung erfolgreich: bvg-muva-aufzugersatz-bald-an-noch-mehr-stationen-verfuegbar.html
# [INFO] Verarbeitung erfolgreich: bvg-parkts-an.html
# [INFO] Verarbeitung erfolgreich: bvg-raeumt-mit-vielfalt-ab.html
# [INFO] Verarbeitung erfolgreich: bvg-spendet-zwoelf-strassenbahnen-in-die-ukraine.html
# [INFO] Verarbeitung erfolgreich: bvg-stellt-stabilitaetskonzept-vor.html
# [INFO] Verarbeitung erfolgreich: bvg-tragbar.html
# [INFO] Verarbeitung erfolgreich: bvg-uebernimmt-die-leitung.html
# [INFO] Verarbeitung erfolgreich: bvg-unter-dem-regenbogen.html
# [INFO] Verarbeitung erfolgreich: bvg-unterstuetzt-kleiderspende-aktion.html
# [INFO] Verarbeitung erfolgreich: bvg-werkelt-auf-der-u7.html
# [INFO] Verarbeitung erfolgreich: bvg-zeigt-sich-von-ihrer-neuen-seite.html
# [INFO] Verarbeitung erfolgreich: cbtc-digitalisierung-fuer-eine-noch-leistungsfaehigere-u-bahn-in-berlin.html
# [INFO] Verarbeitung erfolgreich: check-am-knoten.html
# [INFO] Verarbeitung erfolgreich: cio-des-jahres.html
# [INFO] Verarbeitung erfolgreich: da-bolt-was-auf-uns-zu.html
# [INFO] Verarbeitung erfolgreich: da-geht-noch-was.html
# [INFO] Verarbeitung erfolgreich: da-ist-wieder-musike-drin.html
# [INFO] Verarbeitung erfolgreich: da-muessen-wir-ran.html
# [INFO] Verarbeitung erfolgreich: danz-schoen-fleissig.html
# [INFO] Verarbeitung erfolgreich: das-9-euro-ticket-kommt-an.html
# [INFO] Verarbeitung erfolgreich: das-doppelte-draehtchen.html
# [INFO] Verarbeitung erfolgreich: das-doppelte-gleischen.html
# [INFO] Verarbeitung erfolgreich: das-geheimnis-wird-geliftet.html
# [INFO] Verarbeitung erfolgreich: das-laeuft.html
# [INFO] Verarbeitung erfolgreich: das-machen-wir-gleis-richtig.html
# [INFO] Verarbeitung erfolgreich: das-pendel-das-bewegt.html
# [INFO] Verarbeitung erfolgreich: das-werden-wir-schon-zusammen-stemmen.html
# [INFO] Verarbeitung erfolgreich: das-wird-eine-runde-sache.html
# [INFO] Verarbeitung erfolgreich: dauerhaft-schoen.html
# [INFO] Verarbeitung erfolgreich: dein-anschluss-unter-dieser-nummer.html
# [INFO] Verarbeitung erfolgreich: dichter-und-denker.html
# [INFO] Verarbeitung erfolgreich: dickes-b-trifft-auf-ganz-d.html
# [INFO] Verarbeitung erfolgreich: die-busse-und-bahnen-der-bvg-fahren-am-21-april-wie-gewohnt.html
# [INFO] Verarbeitung erfolgreich: die-busse-und-bahnen-der-bvg-werden-nicht-bestreikt.html
# [INFO] Verarbeitung erfolgreich: die-bvg-hat-den-bogen-raus-2.html
# [INFO] Verarbeitung erfolgreich: die-bvg-hat-den-bogen-raus-3.html
# [INFO] Verarbeitung erfolgreich: die-bvg-hat-ein-rad-up.html
# [INFO] Verarbeitung erfolgreich: die-bvg-hat-sie-alle-zusammen.html
# [INFO] Verarbeitung erfolgreich: die-bvg-spendet-16-trafos-an-die-ukraine.html
# [INFO] Verarbeitung erfolgreich: die-bvg-stellt-ein.html
# [INFO] Verarbeitung erfolgreich: die-bvg-verbindet.html
# [INFO] Verarbeitung erfolgreich: die-drei-fragezeiten.html
# [INFO] Verarbeitung erfolgreich: die-richtige-fuer-den-grossen-gelben.html
# [INFO] Verarbeitung erfolgreich: die-sind-ja-ganz-schoen-dicht.html
# [INFO] Verarbeitung erfolgreich: die-unglaublichen-2.html
# [INFO] Verarbeitung erfolgreich: die-zukunft-im-tunnel.html
# [INFO] Verarbeitung erfolgreich: doppelter-einsatz.html
# [INFO] Verarbeitung erfolgreich: doppelter-wechsel.html
# [INFO] Verarbeitung erfolgreich: dorotheenstrasse-neu-vergleist.html
# [INFO] Verarbeitung erfolgreich: dort-unten-leuchten-die-sterne.html
# [INFO] Verarbeitung erfolgreich: doublemaker.html
# [INFO] Verarbeitung erfolgreich: drahtige-angelegenheit.html
# [INFO] Verarbeitung erfolgreich: drahtseilakt-bei-nacht.html
# [INFO] Verarbeitung erfolgreich: drei-auf-einen-streich.html
# [INFO] Verarbeitung erfolgreich: drei-bauphasen-am-gleisdreieck.html
# [INFO] Verarbeitung erfolgreich: drum-pruefe.html
# [INFO] Verarbeitung erfolgreich: drumherum-statt-mittendurch.html
# [INFO] Verarbeitung erfolgreich: e-busse-machen-sich-in-berlin-breit.html
# [INFO] Verarbeitung erfolgreich: e-schlenkis-erobern-berlin.html
# [INFO] Verarbeitung erfolgreich: ecken-und-kanten.html
# [INFO] Verarbeitung erfolgreich: ein-bussi-fuer-den-csd.html
# [INFO] Verarbeitung erfolgreich: ein-modell-fuer-die-zukunft.html
# [INFO] Verarbeitung erfolgreich: ein-muster-das-bewegt.html
# [INFO] Verarbeitung erfolgreich: eine-liebe-mit-tram-tram.html
# [INFO] Verarbeitung erfolgreich: eine-neue-bindung-eingehen.html
# [INFO] Verarbeitung erfolgreich: einige-anpassungen-fuer-viel-zuverlaessigkeit.html
# [INFO] Verarbeitung erfolgreich: einsteigen-in-die-zukunft-bitte.html
# [INFO] Verarbeitung erfolgreich: einwandfrei-bleibt-dabei.html
# [INFO] Verarbeitung erfolgreich: endspurt-fuer-das-9-euro-ticket.html
# [INFO] Verarbeitung erfolgreich: erfolgreich-bewegt.html
# [INFO] Verarbeitung erfolgreich: es-geht-aufwaerts-2.html
# [INFO] Verarbeitung erfolgreich: es-geht-hoch-und-runter.html
# [INFO] Verarbeitung erfolgreich: ey-was-geht.html
# [INFO] Verarbeitung erfolgreich: faehrmann-erhol-lieber.html
# [INFO] Verarbeitung erfolgreich: fahrgastinformation-bei-der-ubahn-verbessert.html
# [INFO] Verarbeitung erfolgreich: fahrstreifen-auf-dem-tempelhofer-damm-gesperrt.html
# [INFO] Verarbeitung erfolgreich: fast-fertig.html
# [INFO] Verarbeitung erfolgreich: finale-fuers-kreuzberger-viadukt.html
# [INFO] Verarbeitung erfolgreich: fit-fuer-die-fahrt-2.html
# [INFO] Verarbeitung erfolgreich: fit-fuer-die-fahrt.html
# [INFO] Verarbeitung erfolgreich: fit-happens.html
# [INFO] Verarbeitung erfolgreich: fix-zum-pieks.html
# [INFO] Verarbeitung erfolgreich: fleissiges-wochenende.html
# [INFO] Verarbeitung erfolgreich: frauen-erobert-das-gelb.html
# [INFO] Verarbeitung erfolgreich: freie-fahrt-fuer-vielfalt-staatsministerin-alabali-radovan-und-charta-der-vielfalt-besuchen-die-bvg.html
# [INFO] Verarbeitung erfolgreich: frischzellenkur-fuer-tegeler-u6.html
# [INFO] Verarbeitung erfolgreich: fruehling-und-von-der-bvg-gibts-ein-gleis.html
# [INFO] Verarbeitung erfolgreich: fuer-einen-stest-straffen-gleiskoerper.html
# [INFO] Verarbeitung erfolgreich: fuer-stabilitaet-und-verlaesslichkeit.html
# [INFO] Verarbeitung erfolgreich: fundige-schnaeppchen.html
# [INFO] Verarbeitung erfolgreich: ganz-schoen-drahtig.html
# [INFO] Verarbeitung erfolgreich: ganz-verlegen.html
# [INFO] Verarbeitung erfolgreich: gasag-gruppe-investiert-in-bvg-tickets-fuer-mitarbeitende.html
# [INFO] Verarbeitung erfolgreich: gebuendelte-power.html
# [INFO] Verarbeitung erfolgreich: geht-gleis-weiter.html
# [INFO] Verarbeitung erfolgreich: gelb-galaktisch-gut.html
# [INFO] Verarbeitung erfolgreich: gelb-noch-gruener-bvg-kriegt-solar-was-aufs-dach.html
# [INFO] Verarbeitung erfolgreich: gelb-und-gelb-gesellt-sich-gern.html
# [INFO] Verarbeitung erfolgreich: gelbe-perspektiven.html
# [INFO] Verarbeitung erfolgreich: gelbe-seiten.html
# [INFO] Verarbeitung erfolgreich: gemacht-fuer-die-zukunft-stadler-und-die-bvg-geben-ersten-einblick-in-die-neue-u-bahn.html
# [INFO] Verarbeitung erfolgreich: gemeinsam-fuer-die-mobilitaetswende.html
# [INFO] Verarbeitung erfolgreich: gemeinsam-fuer-sicherheit.html
# [INFO] Verarbeitung erfolgreich: gemeinsamer-einsatz-geht-weiter.html
# [INFO] Verarbeitung erfolgreich: generation-j.html
# [INFO] Verarbeitung erfolgreich: gepoolt-wie-gerufen.html
# [INFO] Verarbeitung erfolgreich: geschmeidiger-uebergang.html
# [INFO] Verarbeitung erfolgreich: gib-fuenf.html
# [INFO] Verarbeitung erfolgreich: glattgezogen.html
# [INFO] Verarbeitung erfolgreich: gleis-gehts-hin-und-her.html
# [INFO] Verarbeitung erfolgreich: gleisberechtigung-fuer-die-u5.html
# [INFO] Verarbeitung erfolgreich: gleischen-wechsle-dich.html
# [INFO] Verarbeitung erfolgreich: gleise-glaetten.html
# [INFO] Verarbeitung erfolgreich: grenzenlos-vernetzt.html
# [INFO] Verarbeitung erfolgreich: grosse-nachfrage-nach-29-euro-abo.html
# [INFO] Verarbeitung erfolgreich: grossprojekt-erfolgreich-beendet-highspeed-mobilfunk-fuer-alle-in-der-berliner-u-bahn.html
# [INFO] Verarbeitung erfolgreich: gruen-und-drahtig.html
# [INFO] Verarbeitung erfolgreich: gruendlichkeit-ist-das-gebot.html
# [INFO] Verarbeitung erfolgreich: grundstein-der-ausbildung.html
# [INFO] Verarbeitung erfolgreich: gut-gedaemmt.html
# [INFO] Verarbeitung erfolgreich: gute-ausbildung-starke-perspektive.html
# [INFO] Verarbeitung erfolgreich: gute-luft-in-bus-und-bahn.html
# [INFO] Verarbeitung erfolgreich: handle-with-kehr.html
# [INFO] Verarbeitung erfolgreich: hasta-la-wista.html
# [INFO] Verarbeitung erfolgreich: haste-toene-klar.html
# [INFO] Verarbeitung erfolgreich: henrik-falk-als-bvg-chef-im-amt.html
# [INFO] Verarbeitung erfolgreich: henrik-falk-wird-neuer-vorstandsvorsitzender-der-bvg.html
# [INFO] Verarbeitung erfolgreich: herzensangelegenheit.html
# [INFO] Verarbeitung erfolgreich: herzenssache.html
# [INFO] Verarbeitung erfolgreich: herzklopfen-bei-der-bvg.html
# [INFO] Verarbeitung erfolgreich: herzschmerz.html
# [INFO] Verarbeitung erfolgreich: hier-gehts-raus.html
# [INFO] Verarbeitung erfolgreich: hier-kunst-du-die-zukunft-sehen.html
# [INFO] Verarbeitung erfolgreich: high-five.html
# [INFO] Verarbeitung erfolgreich: hochkant-im-hk.html
# [INFO] Verarbeitung erfolgreich: hoer-mal-wer-da-spricht-2.html
# [INFO] Verarbeitung erfolgreich: hohe-nachfrage-nach-dem-deutschlandticket-bei-der-bvg.html
# [INFO] Verarbeitung erfolgreich: homophobie-kriegt-eine-geklebt.html
# [INFO] Verarbeitung erfolgreich: husch-am-bau.html
# [INFO] Verarbeitung erfolgreich: immer-auf-draht.html
# [INFO] Verarbeitung erfolgreich: immer-der-strasse-nach.html
# [INFO] Verarbeitung erfolgreich: immer-schoen-flexibel-bleiben.html
# [INFO] Verarbeitung erfolgreich: in-schoeneweide-schoene-gleise.html
# [INFO] Verarbeitung erfolgreich: insgesummt-lecker.html
# [INFO] Verarbeitung erfolgreich: inspektor-bvg-2.html
# [INFO] Verarbeitung erfolgreich: inspektor-bvg.html
# [INFO] Verarbeitung erfolgreich: ja-wo-laufen-sie-denn.html
# [INFO] Verarbeitung erfolgreich: jahresbilanz-2023-mehr-von-allem.html
# [INFO] Verarbeitung erfolgreich: janz-schoen-liftig-hier.html
# [INFO] Verarbeitung erfolgreich: jede-karte-ein-treffer.html
# [INFO] Verarbeitung erfolgreich: jelbe-zehne.html
# [INFO] Verarbeitung erfolgreich: jelbi-app-bietet-jetzt-noch-mehr-mobileeeetaet.html
# [INFO] Verarbeitung erfolgreich: jelbi-feld-auf.html
# [INFO] Verarbeitung erfolgreich: jelbi-geht-bis-an-die-grenze.html
# [INFO] Verarbeitung erfolgreich: jelbi-hat-den-sixten-sinn.html
# [INFO] Verarbeitung erfolgreich: jelbi-ist-deutschlands-beliebteste-mobilitaets-app.html
# [INFO] Verarbeitung erfolgreich: jelbi-macht-auch-am-washington-platz.html
# [INFO] Verarbeitung erfolgreich: jelbi-shared-aus.html
# [INFO] Verarbeitung erfolgreich: jelbi-treibt-es-rund.html
# [INFO] Verarbeitung erfolgreich: jenny-zeller-neue-personalvorstaendin-der-bvg.html
# [INFO] Verarbeitung erfolgreich: jenny-zeller-wird-neue-bvg-vorstaendin-fuer-personal-und-soziales.html
# [INFO] Verarbeitung erfolgreich: jetzt-geht-es-aufwaerts.html
# [INFO] Verarbeitung erfolgreich: jetzt-ist-aber-mal-schluss.html
# [INFO] Verarbeitung erfolgreich: jetzt-kommt-mal-zum-punkt.html
# [INFO] Verarbeitung erfolgreich: jetzt-schlaegts-13.html
# [INFO] Verarbeitung erfolgreich: job-store-on-tour.html
# [INFO] Verarbeitung erfolgreich: kaeptn-bvg-ab-auf-die-see.html
# [INFO] Verarbeitung erfolgreich: kantenreich.html
# [INFO] Verarbeitung erfolgreich: kiek-ma-die-neue.html
# [INFO] Verarbeitung erfolgreich: klangvoll-im-untergrund.html
# [INFO] Verarbeitung erfolgreich: kleine-pause-fuer-die-marzahner-m8.html
# [INFO] Verarbeitung erfolgreich: kleiner-lenkanstoss-jetzt-fahrerin-werden.html
# [INFO] Verarbeitung erfolgreich: knifflige-reparatur-auf-engstem-raum.html
# [INFO] Verarbeitung erfolgreich: komm-mal-zum-punkt.html
# [INFO] Verarbeitung erfolgreich: kommse-rin-koennse-e-busse-kieken.html
# [INFO] Verarbeitung erfolgreich: kommt-wie-gerufen.html
# [INFO] Verarbeitung erfolgreich: kommt-zeit-kommt-draht.html
# [INFO] Verarbeitung erfolgreich: kontrolle-ist-besser.html
# [INFO] Verarbeitung erfolgreich: konzentration-des-busverkehrs-am-terminal-5-des-ber-neuer-haltestellenbereich-nimmt-betrieb-auf.html
# [INFO] Verarbeitung erfolgreich: kosmische-gleisarbeiten.html
# [INFO] Verarbeitung erfolgreich: kostenloser-impf-shuttle-in-tegel.html
# [INFO] Verarbeitung erfolgreich: kreuz-und-quer.html
# [INFO] Verarbeitung erfolgreich: kreuzberg-und-friedrichshain-wieder-vereint.html
# [INFO] Verarbeitung erfolgreich: kroenchen-richten.html
# [INFO] Verarbeitung erfolgreich: kurz-angebunden.html
# [INFO] Verarbeitung erfolgreich: kurz-getrennt.html
# [INFO] Verarbeitung erfolgreich: kurz-vor-acht.html
# [INFO] Verarbeitung erfolgreich: laeuft-in-berlin.html
# [INFO] Verarbeitung erfolgreich: laeuft.html
# [INFO] Verarbeitung erfolgreich: leise-fliesst-der-verkehr.html
# [INFO] Verarbeitung erfolgreich: letzter-schliff-fuer-die-u2-am-alexanderplatz.html
# [INFO] Verarbeitung erfolgreich: licht-im-schacht.html
# [INFO] Verarbeitung erfolgreich: lieber-fremdfahren-als-fremdgehen.html
# [INFO] Verarbeitung erfolgreich: lieber-mal-gleich-richten.html
# [INFO] Verarbeitung erfolgreich: limeted-edition.html
# [INFO] Verarbeitung erfolgreich: lola-rennt-und-guenni-und-franzi-und-deniz-und-jette-und-jack-und-kevin-und.html
# [INFO] Verarbeitung erfolgreich: luft-nach-oben.html
# [INFO] Verarbeitung erfolgreich: machs-fuers-gelb.html
# [INFO] Verarbeitung erfolgreich: makeover-fuer-deutsche-oper.html
# [INFO] Verarbeitung erfolgreich: mal-ganz-ohne-gag-innehalten-mitmachen.html
# [INFO] Verarbeitung erfolgreich: mal-ordentlich-die-meinung-sagen.html
# [INFO] Verarbeitung erfolgreich: mal-was-fuers-gemuet.html
# [INFO] Verarbeitung erfolgreich: manteltarifverhandlungen-2024.html
# [INFO] Verarbeitung erfolgreich: markenkommunikation-die-wirkt.html
# [INFO] Verarbeitung erfolgreich: mast-be.html
# [INFO] Verarbeitung erfolgreich: mast-have-der-m1.html
# [INFO] Verarbeitung erfolgreich: mausgezeichnete-zukunftsperspektiven.html
# [INFO] Verarbeitung erfolgreich: mehr-bitte.html
# [INFO] Verarbeitung erfolgreich: mehr-busangebot-fuer-berlin.html
# [INFO] Verarbeitung erfolgreich: mehr-ordnung-in-mitte-na-bitte.html
# [INFO] Verarbeitung erfolgreich: mehr-verlaesslichkeit-bei-der-ubahn.html
# [INFO] Verarbeitung erfolgreich: mehr-volt-fuer-alle-faelle.html
# [INFO] Verarbeitung erfolgreich: meisterleistung.html
# [INFO] Verarbeitung erfolgreich: mit-abstand-die-besten-zeiten.html
# [INFO] Verarbeitung erfolgreich: mit-bus-und-bahn-zu-den-em-spielen-vbb-bvg-und-s-bahn-ziehen-positive-bilanz.html
# [INFO] Verarbeitung erfolgreich: mit-bvg-und-s-bahn-zum-impfen.html
# [INFO] Verarbeitung erfolgreich: mit-dem-zweiten-faehrt-man-besser-2.html
# [INFO] Verarbeitung erfolgreich: mit-der-bvg-impfs-zentrum.html
# [INFO] Verarbeitung erfolgreich: mit-der-bvg-zweigleisig-unterwegs.html
# [INFO] Verarbeitung erfolgreich: mit-draht-zur-tat.html
# [INFO] Verarbeitung erfolgreich: mit-jelbi-wird-die-charite-zur-sharite.html
# [INFO] Verarbeitung erfolgreich: mit-leichten-einschraenkungen-auch-nach-den-ferien-zuverlaessig-unterwegs.html
# [INFO] Verarbeitung erfolgreich: mit-netz-in-der-tram.html
# [INFO] Verarbeitung erfolgreich: mit-sicherheit-gut-ausgestattet.html
# [INFO] Verarbeitung erfolgreich: mit-spannung-durch-berlin.html
# [INFO] Verarbeitung erfolgreich: mit-spannung-erwartet.html
# [INFO] Verarbeitung erfolgreich: mit-spannung-geht-es-weiter.html
# [INFO] Verarbeitung erfolgreich: mitten-ins-getuemmel.html
# [INFO] Verarbeitung erfolgreich: moabit-im-trampenlicht.html
# [INFO] Verarbeitung erfolgreich: mobilitaetstrainings-fallen-aus.html
# [INFO] Verarbeitung erfolgreich: mobilitaetstrainings-finden-wieder-statt.html
# [INFO] Verarbeitung erfolgreich: mobilitaetswenderinnen-von-morgen.html
# [INFO] Verarbeitung erfolgreich: musterhafte-einigung.html
# [INFO] Verarbeitung erfolgreich: mut-zur-bruecke.html
# [INFO] Verarbeitung erfolgreich: nachts-im-u-bahnhof-museumsinsel.html
# [INFO] Verarbeitung erfolgreich: nachts-wird-gependelt.html
# [INFO] Verarbeitung erfolgreich: nachtschwermer.html
# [INFO] Verarbeitung erfolgreich: naechste-phase-am-u-bismarckstrasse.html
# [INFO] Verarbeitung erfolgreich: naechte-der-auffrischung.html
# [INFO] Verarbeitung erfolgreich: naechtliches-checken-von-wand-und-decken.html
# [INFO] Verarbeitung erfolgreich: nah-am-ball.html
# [INFO] Verarbeitung erfolgreich: nah-am-wasser-gebaut.html
# [INFO] Verarbeitung erfolgreich: neu-im-netz.html
# [INFO] Verarbeitung erfolgreich: neue-luft-schnuppern.html
# [INFO] Verarbeitung erfolgreich: neue-u-bahn-stadler-und-die-bvg-stellen-ers-tes-jk-fahrzeug-vor.html
# [INFO] Verarbeitung erfolgreich: neuer-halt.html
# [INFO] Verarbeitung erfolgreich: neues-gleis-im-koepenicker-kreis.html
# [INFO] Verarbeitung erfolgreich: niedrigerer-preis-hoehere-qualitaet.html
# [INFO] Verarbeitung erfolgreich: nimm-drei.html
# [INFO] Verarbeitung erfolgreich: o-du-fleissige.html
# [INFO] Verarbeitung erfolgreich: oesterlicher-ei-nsatz.html
# [INFO] Verarbeitung erfolgreich: orientierung-zum-tasten.html
# [INFO] Verarbeitung erfolgreich: panktastische-bahnsteige.html
# [INFO] Verarbeitung erfolgreich: passgenauer-einsatz.html
# [INFO] Verarbeitung erfolgreich: planung-zur-verlaengerung-der-u8-nimmt-fahrt-auf.html
# [INFO] Verarbeitung erfolgreich: platz-fuer-neue-gleise.html
# [INFO] Verarbeitung erfolgreich: praktische-anzeigen-gegen-hektisches-umsteigen.html
# [INFO] Verarbeitung erfolgreich: pressemitteilung-mit-sicherheit-mobil.html
# [INFO] Verarbeitung erfolgreich: pride-month-berlin-bvg-ohne-mundhaltestelle.html
# [INFO] Verarbeitung erfolgreich: provisorium-ade.html
# [INFO] Verarbeitung erfolgreich: rampenbau.html
# [INFO] Verarbeitung erfolgreich: ran-an-die-decke.html
# [INFO] Verarbeitung erfolgreich: regenbogen-unterm-alex.html
# [INFO] Verarbeitung erfolgreich: relais-ade.html
# [INFO] Verarbeitung erfolgreich: rundum-gelungen.html
# [INFO] Verarbeitung erfolgreich: s-bahn-berlin-und-bvg-geben-17-000-fahrscheine-fuer-freiwillig-engagierte-2.html
# [INFO] Verarbeitung erfolgreich: sauber-gemacht.html
# [INFO] Verarbeitung erfolgreich: sauber-sicher-jetzt-auf-ganzer-linie.html
# [INFO] Verarbeitung erfolgreich: schienenfleissig-in-friedrichshain.html
# [INFO] Verarbeitung erfolgreich: schlesisches-tor-geliftet.html
# [INFO] Verarbeitung erfolgreich: schluss-mit-frustig.html
# [INFO] Verarbeitung erfolgreich: schnittstelle-2.html
# [INFO] Verarbeitung erfolgreich: schoen-sie-rennenzulernen.html
# [INFO] Verarbeitung erfolgreich: schoenheitskur-fuer-die-pankstrasse.html
# [INFO] Verarbeitung erfolgreich: schotter-her.html
# [INFO] Verarbeitung erfolgreich: sechszellent.html
# [INFO] Verarbeitung erfolgreich: sechszellenter-plan.html
# [INFO] Verarbeitung erfolgreich: sei-ein-fuchs-fuer-dich-und-die-umwelt.html
# [INFO] Verarbeitung erfolgreich: seitenwechsel-2.html
# [INFO] Verarbeitung erfolgreich: seitenwechsel-3.html
# [INFO] Verarbeitung erfolgreich: seitenwechsel-4.html
# [INFO] Verarbeitung erfolgreich: senat-zu-besuch-bei-der-bvg-berlin-2035-mobilitaet-im-zeitalter-von-ki.html
# [INFO] Verarbeitung erfolgreich: share-dich-nach-spandau.html
# [INFO] Verarbeitung erfolgreich: shop-your-job.html
# [INFO] Verarbeitung erfolgreich: sicherheit-geht-vor-e-tretroller-muessen-vorerst-draussen-bleiben.html
# [INFO] Verarbeitung erfolgreich: siegfried-und-neu.html
# [INFO] Verarbeitung erfolgreich: simply-the-west.html
# [INFO] Verarbeitung erfolgreich: sonnenklar-warum-gelb-so-gruen-ist.html
# [INFO] Verarbeitung erfolgreich: soziale-verantwortung-bei-der-e-bus-beschaffung.html
# [INFO] Verarbeitung erfolgreich: spannende-nacht.html
# [INFO] Verarbeitung erfolgreich: spannender-sonntagsdienst.html
# [INFO] Verarbeitung erfolgreich: sperrung-der-bahnbruecke-in-marienfelde.html
# [INFO] Verarbeitung erfolgreich: sperrung-der-elsenbruecke.html
# [INFO] Verarbeitung erfolgreich: start-corporate-influencer-programm.html
# [INFO] Verarbeitung erfolgreich: statement-der-bvg-zur-attacke-gegen-eine-strassenbahn-der-linie-m10.html
# [INFO] Verarbeitung erfolgreich: steglitzeblank.html
# [INFO] Verarbeitung erfolgreich: stille-nacht-fleissige-nacht.html
# [INFO] Verarbeitung erfolgreich: streik-bei-der-db-busse-und-bahnen-der-bvg-fahren-zum-wochenstart-planmaessig.html
# [INFO] Verarbeitung erfolgreich: strom-fuer-allee.html
# [INFO] Verarbeitung erfolgreich: strom-weg-fuer-einen-guten-zweck.html
# [INFO] Verarbeitung erfolgreich: stufenlos-verbunden.html
# [INFO] Verarbeitung erfolgreich: stufenlose-u4.html
# [INFO] Verarbeitung erfolgreich: tauschgeschaeft.html
# [INFO] Verarbeitung erfolgreich: thats-it.html
# [INFO] Verarbeitung erfolgreich: tief-verbunden.html
# [INFO] Verarbeitung erfolgreich: tiefgruendig.html
# [INFO] Verarbeitung erfolgreich: tool-das-ist-ja-einfach.html
# [INFO] Verarbeitung erfolgreich: total-faehrscherzt.html
# [INFO] Verarbeitung erfolgreich: tour-de-berlin.html
# [INFO] Verarbeitung erfolgreich: tramhafte-aussichten-fuer-moabit-2.html
# [INFO] Verarbeitung erfolgreich: tramhafte-aussichten-fuer-moabit.html
# [INFO] Verarbeitung erfolgreich: trampenlicht.html
# [INFO] Verarbeitung erfolgreich: tramtram-fuer-die-wissenschaft.html
# [INFO] Verarbeitung erfolgreich: transparent-und-ganz-nah-dran.html
# [INFO] Verarbeitung erfolgreich: treptow-koepenick-waechst-mit.html
# [INFO] Verarbeitung erfolgreich: tri-tra-tramwochen.html
# [INFO] Verarbeitung erfolgreich: tunnellifting.html
# [INFO] Verarbeitung erfolgreich: u-bahn-sportliche-leistung-in-herausfordernden-zeiten.html
# [INFO] Verarbeitung erfolgreich: u5-steht-auf-neue-gleise.html
# [INFO] Verarbeitung erfolgreich: u9-neu-verbunden.html
# [INFO] Verarbeitung erfolgreich: umleitungen-zum-marathon.html
# [INFO] Verarbeitung erfolgreich: unterwegs-auf-der-zeitschiene.html
# [INFO] Verarbeitung erfolgreich: urbanliner-ganz-laaaaanger-fahrspass.html
# [INFO] Verarbeitung erfolgreich: verflixt-und-zugemuellt.html
# [INFO] Verarbeitung erfolgreich: verkehrssicherheit-fuer-alle.html
# [INFO] Verarbeitung erfolgreich: verlaengerung-fuer-u2-hertha-sonderverkehr.html
# [INFO] Verarbeitung erfolgreich: verschweisst-und-zugedeckelt.html
# [INFO] Verarbeitung erfolgreich: verstaerkung-ahoi.html
# [INFO] Verarbeitung erfolgreich: vielfalt-auf-ganzer-linie.html
# [INFO] Verarbeitung erfolgreich: vielfalt-ist-auch-gefuehlssache.html
# [INFO] Verarbeitung erfolgreich: vielfalt-lebe-hoch.html
# [INFO] Verarbeitung erfolgreich: vier-grosse-gelbe-und-tram-teile-fuer-die-ukraine.html
# [INFO] Verarbeitung erfolgreich: vir-chow-wieder.html
# [INFO] Verarbeitung erfolgreich: vogelhochzeit.html
# [INFO] Verarbeitung erfolgreich: volle-info-diggi.html
# [INFO] Verarbeitung erfolgreich: voller-einsatz-fuer-die-fahrgaeste.html
# [INFO] Verarbeitung erfolgreich: voller-tatendrang.html
# [INFO] Verarbeitung erfolgreich: von-der-notloesung-zum-klassiker.html
# [INFO] Verarbeitung erfolgreich: vordereinstieg-beim-bus-ab-3-mai-wieder-moeglich.html
# [INFO] Verarbeitung erfolgreich: vordereinstieg-beim-bus-startet-wieder.html
# [INFO] Verarbeitung erfolgreich: vorsicht-ist-besser-u2-am-alexanderplatz-nur-eingleisig-unterwegs.html
# [INFO] Verarbeitung erfolgreich: vorstand-personal-und-soziales-verlaesst-die-bvg.html
# [INFO] Verarbeitung erfolgreich: was-bvgeht-im-sommer-fuenf-coole-tipps-zur-ferienzeit.html
# [INFO] Verarbeitung erfolgreich: was-ist-denn-jetzt-phase.html
# [INFO] Verarbeitung erfolgreich: we-love-to-share-you-to-fu.html
# [INFO] Verarbeitung erfolgreich: wedding-weekend.html
# [INFO] Verarbeitung erfolgreich: weiter-zuverlaessig-unterwegs.html
# [INFO] Verarbeitung erfolgreich: welkom-in-berlijn.html
# [INFO] Verarbeitung erfolgreich: wendemanoever.html
# [INFO] Verarbeitung erfolgreich: wenns-bei-glaette-glatt-laeuft.html
# [INFO] Verarbeitung erfolgreich: wer-wilmer-punkte.html
# [INFO] Verarbeitung erfolgreich: wer-wird-denn-gleich-an-die-decke-gehen.html
# [INFO] Verarbeitung erfolgreich: wettervorhersage-meist-gleisig.html
# [INFO] Verarbeitung erfolgreich: winter-laesst-uns-kalt.html
# [INFO] Verarbeitung erfolgreich: wir-bauen-auf-ausbildung-2.html
# [INFO] Verarbeitung erfolgreich: wir-gehen-an-die-decke-2.html
# [INFO] Verarbeitung erfolgreich: wir-machen-mal-einen-auf.html
# [INFO] Verarbeitung erfolgreich: wir-seen-uns-wieder.html
# [INFO] Verarbeitung erfolgreich: wird-gleis-erledigt.html
# [INFO] Verarbeitung erfolgreich: wissen-auf-raedern.html
# [INFO] Verarbeitung erfolgreich: zahl-um-zahl.html
# [INFO] Verarbeitung erfolgreich: zahlen-bitte.html
# [INFO] Verarbeitung erfolgreich: zauberhafte-reise-fuer-gross-und-klein.html
# [INFO] Verarbeitung erfolgreich: zehn-jahre-unter-dem-regenbogen.html
# [INFO] Verarbeitung erfolgreich: ziemlich-beste-freunde.html
# [INFO] Verarbeitung erfolgreich: zukunft-des-oepnv-gemeinsam-berlin-bewegen.html
# [INFO] Verarbeitung erfolgreich: zurueck-in-die-zukunft-2.html
# [INFO] Verarbeitung erfolgreich: zusammen-halt.html
# [INFO] Verarbeitung erfolgreich: zwei-auf-einen-schlag.html
# [INFO] Verarbeitung erfolgreich: zwei-baustellen-gleiszeitig.html
# [INFO] Verarbeitung erfolgreich: zweifache-nachtschicht.html
# Data shape: (143198, 4)

# %% [markdown]
# #### 8. Speicherung der Ergebnisse (Wortfrequenzen)

# %%
# Wortzählung als CSV speichern
# Zielpfad für CSV definieren
csv_path = os.path.join(OUTPUT_FOLDER, "pm_bvg_wordcount.csv")

# Speichern
data.to_csv(csv_path, index=False)
print(f"[INFO] CSV gespeichert unter: {csv_path}")
# Out:
# [INFO] CSV gespeichert unter: output\pm_bvg_wordcount.csv

# %%
# Wortzählung als SQL speichern
# Verbindung zur Datenbank aufbauen 
conn = sqlite3.connect(SQL_PATH)

# Wortzählung speichern 
data.to_sql("wordcount_pm", conn, if_exists="replace", index=False)

# Verbindung schließen
conn.close()
print(f"SQL gespeichert unter {SQL_PATH}")
# Out:
# SQL gespeichert unter output\dwh_pm_bvg.sqlite3

# %%
# Prüfung Tabellen in Datenbank
# Verbindung zur Datenbank aufbauen
conn = sqlite3.connect(os.path.join(OUTPUT_FOLDER, "dwh_pm_bvg.sqlite3"))

# Cursor-Objekt erstellen
cursor = conn.cursor()

# Abfrage: Alle Tabellennamen aus der Datenbank holen
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")

# Ergebnis holen
tables = cursor.fetchall()

# Tabellen ausgeben
print("Tabellen in der Datenbank:")
for table in tables:
    print(table[0])

# Verbindung schließen
conn.close()
# Out:
# Tabellen in der Datenbank:
# pm_bvg_valid
# wordcount_pm
