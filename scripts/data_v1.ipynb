# %%
from bs4 import BeautifulSoup

# Absoluter Pfad zur HTML-Datei
file_path = r'C:\Users\Marta\Documents\Marta\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\input\raw\data-lake\2025-02-01-berliner.html'

# Datei einlesen und parsen
with open(file_path, 'r', encoding='utf-8') as file:
    soup = BeautifulSoup(file, 'html.parser')

# Head-Teil anzeigen
print(soup.head)
# Out:
# <head><meta charset="utf-8"/><link as="font" crossorigin="anonymous" href="https://fonts.gstatic.com/s/merriweather/v30/u-4n0qyriQwlOrhSvowK_l52xwNZWMf6hPvhPQ.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" href="https://fonts.gstatic.com/s/roboto/v30/KFOlCnqEu92Fr1MmWUlfBBc4AMP6lQ.woff2" rel="preload" type="font/woff2"/><style>@font-face {font-family:Merriweather;font-style:normal;font-display:optional;font-weight:700;unicode-range:U+0000-00FF,U+0131,U+0152-0153,U+02BB-02BC,U+02C6,U+02DA,U+02DC,U+0304,U+0308,U+0329,U+2000-206F,U+2074,U+20AC,U+2122,U+2191,U+2193,U+2212,U+2215,U+FEFF,U+FFFD;src:url(https://fonts.gstatic.com/s/merriweather/v30/u-4n0qyriQwlOrhSvowK_l52xwNZWMf6hPvhPQ.woff2) format('woff2')}
# ...
