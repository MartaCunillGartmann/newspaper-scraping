# %% [markdown]
# ### main.ipynb – Datenaufbereitung
#
# Dieses Notebook bereitet Textdaten aus Presseartikeln systematisch auf, um sie für die spätere Analyse nutzbar zu machen.
#
# Die wichtigsten Schritte:
# - tar.gz-Archive entpacken und .html- sowie .csv-Dateien extrahieren
# - HTML-Inhalte bereinigen, in Wörter aufspalten und Stoppwörter entfernen
# - Wortfrequenzen je Medium und Datum zählen
# - Ergebnisse in einer SQLite-Datenbank sowie als CSV-Dateien speichern
# - Log-Informationen und Fehlerliste zur Nachvollziehbarkeit erstellen

# %% [markdown]
# ##### 1. Import der benötigten Pakete

# %%
# Standard
import os # Dateipfaden
import pandas as pd # Tabellenverarbeitung (DataFrames)
import sys  # Systemfunktionen 

# Einlesen & entpacken Archivdateien
from glob import glob # Mehrere Dateien suchen
import tarfile # .tar.gz Dateien entpacken

# Bearbeiten von html-Dateien
from bs4 import BeautifulSoup  # HTML auslesen und bereinigen
import requests # HTTP-Anfragen

# Speicherung
from datetime import datetime # Datumsangaben
import sqlite3 # SQL-Datenbank

# Eigene Funktionen (ausgelagert)
sys.path.append("../scripts") # Pfad zu den Funktionen
# Funktionen aus datenaufbereitung.py importieren
from datenaufbereitung import (
    load_stopwords,
    read_html_file,
    process_html
)
# Stoppwörter laden
stopwords_list = load_stopwords()

# Logging-Variablen
log_list = []
failing_list = []

# %%
# Pfade 

# Projektverzeichnis 
PROJECT_ROOT = os.getcwd()

# Input-Pfade
INPUT_PATH = os.path.join(PROJECT_ROOT, "..", "input", "raw")
DATA_LAKE_PATH = os.path.join(INPUT_PATH, "data-lake")         # HTML- und CSV-Dateien
ZIP_PATH = os.path.join(INPUT_PATH, "downloaded_zips")         # ZIP-Dateien

# Output-Pfade
OUTPUT_PATH = os.path.join(PROJECT_ROOT, "..", "output")
STORAGE_PATH = os.path.join("..", "input", "raw", "data-lake")
SQL_PATH = os.path.join(OUTPUT_PATH, "dwh.sqlite3")               # SQLite-Datenbank
CSV_PATH = os.path.join(OUTPUT_PATH, "wordcount_news.csv")        # Exportierte CSV

# %% [markdown]
# #### 2. Archiv entpacken und Dateien speichern

# %%
# Funktion: Mit tarfile Rohdaten (Format .tar.gz) einlesen, extrahieren & entpacken
def extract_tar_file(ZIP_PATH, DATA_LAKE_PATH): 
    with tarfile.open(ZIP_PATH, "r:gz") as tar:
        for member in tar.getmembers():
            # Zielpfad für jede Datei 
            filename = os.path.basename(member.name)
            
            # HTML- und CSV-Dateien extrahieren
            if filename.endswith(".html") or filename.endswith(".csv"):
                target_path = os.path.join(DATA_LAKE_PATH, filename)
                
                # Skippen, wenn Datei schon existiert
                if os.path.exists(target_path):
                    continue
                
                # Entpacken in HTML-Datei
                with open(target_path, "wb") as f:
                    f.write(tar.extractfile(member).read())
                
                print(f"Entpackt: {filename}")

# %%
# Funktion extract_tar_file anwenden: .tar.gz-Dateien im ZIP-Ordner durchlaufen
print("[INFO] Entpackung gestartet...")
for zip_file in os.listdir(ZIP_PATH):
    if zip_file.endswith(".tar.gz"):
        zip_path = os.path.join(ZIP_PATH, zip_file)
        print(f"[INFO] Entpacke Archiv: {zip_path}")
        # Für jede Datei die Funktion extract_tar_file() aufrufen
        extract_tar_file(zip_path, DATA_LAKE_PATH)
# Out:
# [INFO] Entpackung gestartet...
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2021-04.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2021-05.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2021-06.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2021-07.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2021-08.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2021-09.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2021-10.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2021-11.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2021-12.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2022-01.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2022-02.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2022-03.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2022-04.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2022-05.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2022-06.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2022-07.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2022-08.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2022-09.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2022-10.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2022-11.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2022-12.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2023-01.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2023-02.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2023-03.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2023-04.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2023-05.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2023-06.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2023-07.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2023-08.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2023-09.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2023-10.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2023-11.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2023-12.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2024-01.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2024-02.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2024-03.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2024-04.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2024-05.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2024-06.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2024-07.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2024-08.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2024-09.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2024-10.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2024-11.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2024-12.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2025-01.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2025-02.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2025-03.tar.gz
# [INFO] Entpacke Archiv: d:\DBU\ADSC11 ADS-01\Studienarbeit\newspaper-scraping\notebooks\..\input\raw\downloaded_zips\2025-04.tar.gz

# %%
# Prüfung, ob CSV- & HTML-Dateien geladen wurden
# Anzahl HTML- und CSV-Dateien im data-lake
html_files = [f for f in os.listdir(DATA_LAKE_PATH) if f.endswith(".html")]
csv_files = [f for f in os.listdir(DATA_LAKE_PATH) if f.endswith(".csv") and not f.startswith("~")]

print("Anzahl CSV-Dateien:", len(csv_files))
print("Anzahl HTML-Dateien:", len(html_files))
print("Beispielhafte HTML-Dateien:", html_files[:3])
# Out:
# Anzahl CSV-Dateien: 1490
# Anzahl HTML-Dateien: 83557
# Beispielhafte HTML-Dateien: ['2021-04-01-54books.html', '2021-04-01-abendblatt.html', '2021-04-01-anwaltsverein.html']

# %% [markdown]
# #### 3. Funktionen zur Verarbeitung definieren

# %%
# Funktion: HTML und Metadaten zusammenführen und Wörter zählen 
def process_newspaper(newspaper):
    filename = os.path.basename(newspaper["file_name"])  
    full_path = os.path.join(DATA_LAKE_PATH, filename)   

    # Encoding einlesen
    encoding = newspaper["encoding"].lower()
    
    # HTML-Datei laden & bereinigen mit ausgelagerter Funktion
    html = read_html_file(full_path, encoding)
    # Text bereinigen mit ausgelagerter Funktion
    items = process_html(html, stopwords_list)

   # Häufigkeit jedes Wortes zählen
    count = pd.Series(items).value_counts()

    # Als DataFrame formatieren mit:
    count_df = count.to_frame()
    count_df.columns = ["count"] # Wortfrequenz
    count_df["word"] = count_df.index # Wort
    count_df["source"] = newspaper["name"] # Medium
    count_df["date"] = newspaper["date"] #Veröffentlichungsdatum
    count_df["filename"] = filename # Ursprungsdatei zur späteren Rückverfolgung bei Fehlern

    # Prüfung, ob count funktioniert    
    if count_df.empty:
        print(f"[WARNUNG] Leeres Ergebnis für: {filename} ({newspaper['name']})")
    
    # Logging ausführen 
    log_entry = {
        "filename": filename,
        "source": newspaper["name"],
        "date": newspaper["date"],
        "num_words": len(count_df)
    }
    log_list.append(log_entry)

    return count_df

# %%
# Funktion: Funktion process_newspaper anwenden, in der Variable collection speichern und Erfolg oder Fehler ausgeben
def process_wrapper(newspaper):
    name = newspaper["name"]
    try:
        count = process_newspaper(newspaper)       
        print(f"[INFO] Verarbeitung erfolgreich: {name}")
        # Ergebnisse in collection zwischenspeichern
        collection.append(count)
    except Exception as e:
        # Ausgeben, wenn ein Fehler auftritt
        print(f"[ERROR] Fehler bei {name} ({newspaper['file_name']}): {e}")
        # Fehlerdetails für spätere Analyse in Fehlerliste speichern
        failing_list.append({
            "filename": newspaper["file_name"],
            "source": name,
            "error": str(e)
        })

# %%
# Funktion: Verarbeitet ein Medien-Cluster und speichert die Wortfrequenzen in einer CSV-Datei
def verarbeite_cluster(cluster_name, zielmedien, output_csv):
    # Listen zurücksetzen, damit bei jedem Cluster neu gearbeitet wird
    global collection, log_list, failing_list
    collection = []
    log_list = []
    failing_list = []

    # Vorherige Ergebnisdatei (falls vorhanden) löschen
    if os.path.exists(output_csv):
        os.remove(output_csv)

    # Alle Metadaten-Dateien im STORAGE_PATH durchlaufen
    for file in sorted(os.listdir(STORAGE_PATH)):
        if file.endswith(".csv"):
            filepath = os.path.join(STORAGE_PATH, file)
            try:
                # Metadaten einlesen
                df = pd.read_csv(filepath)

                # Nur die Zeitungsartikel auswählen, die zu den Zielmedien gehören
                df = df[df["name"].isin(zielmedien)]

                if not df.empty:
                    print(f"[INFO] {cluster_name} – Datei: {file}")

                    # Für jede Zeile/Artikel im DataFrame die Verarbeitung ausführen
                    df.apply(process_wrapper, axis=1)

                    # Ergebnisse aus collection in die Cluster-CSV schreiben
                    for chunk in collection:
                        chunk.to_csv(output_csv, mode="a", index=False, header=not os.path.exists(output_csv))

                    # Zwischenspeicher leeren für nächste Datei
                    collection = []

            except Exception as e:
                print(f"[ERROR] Fehler bei Datei {file} ({cluster_name}): {e}")

    # Wenn alle Dateien verarbeitet sind, Ergebnisdatei nochmal prüfen und Log-Dateien erstellen
    try:
        # Ergebnis einlesen
        df_result = pd.read_csv(output_csv)
        print(f"[INFO] Cluster {cluster_name} – Ergebnisform: {df_result.shape}")
        
        # Warnung, falls word-Spalte in manchen Zeilen leer ist
        fehlende_woerter = df_result[df_result["word"].isnull()]
        if not fehlende_woerter.empty:
            print(f"[WARNUNG] {cluster_name} enthält {fehlende_woerter.shape[0]} Zeilen ohne 'word'")
            print(fehlende_woerter["filename"].value_counts().head())

        # Prüfung
        print(df_result.sample(3, random_state=1))

        # Logging-Informationen speichern
        log_df = pd.DataFrame(log_list)
        fail_df = pd.DataFrame(failing_list)

        # Log-Dateien benennen
        log_output_path = output_csv.replace(".csv", "_log.csv")
        fail_output_path = output_csv.replace(".csv", "_failures.csv")

        # Log-Dateien speichern
        log_df.to_csv(log_output_path, index=False)
        fail_df.to_csv(fail_output_path, index=False)

        print(f"[INFO] Log gespeichert unter: {log_output_path}")
        print(f"[INFO] Fehlerhafte Dateien gespeichert unter: {fail_output_path}")

    except Exception as e:
        print(f"[ERROR] Fehler beim Laden von {output_csv}: {e}")

# %% [markdown]
# #### 4. Iteratives Anwenden der Verarbeitungsfunktionen auf die Medien

# %%
# Zwischensammlung 
collection = []

# %%
# Zielmedien definieren
zielmedien_or = {"dlf", "tagesschau"}  # Öffentlich-rechtlich
zielmedien_wm = {"handelsblatt", "wiwo", "mm", "boerse"}  # Wirtschaftsmedien
zielmedien_gm = {"sz", "zeit", "faz", "taz", "welt", "spiegel", "stern"}  # Große Medien
zielmedien_rm = {"abendblatt", "berliner", "tagesspiegel"}  # Regionale Medien
zielmedien_di = {"ntv", "pioneer", "dw-de"}  # digitale Nachrichtenportale
zielmedien_tech = {"heise", "golem", "netzpolitik", "t3n"}  # Technologie

# %%
# Cluster einzeln verarbeiten
verarbeite_cluster("Öffentlich-rechtlich", zielmedien_or, "output/cluster_oeffentlich.csv")
verarbeite_cluster("Wirtschaftsmedien", zielmedien_wm, "output/cluster_wirtschaft.csv")
verarbeite_cluster("Große Medien", zielmedien_gm, "output/cluster_grossemedien.csv")
verarbeite_cluster("Regionale Medien", zielmedien_rm, "output/cluster_regiomedien.csv")
verarbeite_cluster("Digitale Nachrichtsportale", zielmedien_di, "output/cluster_digital.csv")
verarbeite_cluster("Technologie", zielmedien_tech, "output/cluster_tech.csv")
# Out:
# [INFO] Öffentlich-rechtlich – Datei: 2021-04-01.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-04-02.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-04-03.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-04-04.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-04-05.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-04-06.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-04-07.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-04-08.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-04-09.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-04-10.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-04-11.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-04-12.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-04-13.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-04-14.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-04-15.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-04-16.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-04-17.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-04-18.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-04-19.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-04-20.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-04-21.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-04-22.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-04-23.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-04-24.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-04-25.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-04-26.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-04-27.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-04-28.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-04-29.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-04-30.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-05-01.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-05-02.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-05-03.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-05-04.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-05-05.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-05-06.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-05-07.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-05-08.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-05-09.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-05-10.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-05-11.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-05-12.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-05-13.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-05-14.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-05-15.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-05-16.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-05-17.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-05-18.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-05-19.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-05-20.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-05-21.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-05-22.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-05-23.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-05-24.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-05-25.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-05-26.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-05-27.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-05-28.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-05-29.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-05-30.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-05-31.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-06-01.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-06-02.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [ERROR] Fehler bei Datei 2021-06-03.csv (Öffentlich-rechtlich): No columns to parse from file
# [INFO] Öffentlich-rechtlich – Datei: 2021-06-04.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-06-05.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-06-06.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-06-07.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-06-08.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-06-09.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-06-10.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-06-11.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-06-12.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-06-13.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-06-14.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-06-15.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-06-16.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-06-17.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-06-18.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-06-19.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-06-20.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-06-21.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-06-22.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-06-23.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-06-24.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-06-25.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-06-26.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-06-27.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-06-28.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-06-29.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-06-30.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-07-01.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-07-02.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-07-03.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-07-04.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-07-05.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-07-06.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-07-07.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-07-08.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-07-09.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-07-10.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-07-11.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-07-12.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-07-13.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-07-14.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-07-15.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-07-16.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-07-17.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-07-18.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-07-19.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-07-20.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-07-21.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-07-22.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-07-23.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-07-24.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-07-25.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-07-26.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-07-27.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-07-28.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-07-29.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-07-30.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-07-31.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-08-01.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-08-02.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-08-03.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-08-04.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-08-05.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-08-06.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-08-07.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-08-08.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-08-09.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-08-10.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-08-11.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-08-12.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-08-13.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-08-14.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-08-15.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-08-16.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-08-17.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-08-18.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-08-19.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-08-20.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-08-21.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-08-22.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-08-23.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-08-24.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-08-25.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-08-26.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-08-27.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-08-28.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-08-29.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-08-30.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-08-31.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-09-01.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-09-02.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-09-03.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-09-04.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-09-05.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-09-06.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-09-07.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-09-08.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-09-09.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-09-10.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-09-11.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-09-12.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-09-13.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-09-14.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-09-15.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-09-16.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-09-17.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-09-18.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-09-19.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-09-20.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-09-21.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-09-22.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-09-23.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-09-24.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-09-25.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-09-26.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-09-27.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-09-28.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-09-29.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-09-30.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-10-01.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-10-02.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-10-03.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-10-04.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-10-05.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-10-06.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-10-07.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-10-08.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-10-09.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-10-10.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-10-11.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-10-12.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-10-13.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-10-14.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-10-15.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-10-16.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-10-17.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-10-18.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-10-19.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-10-20.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-10-21.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-10-22.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-10-23.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-10-24.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-10-25.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-10-26.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-10-27.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-10-28.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-10-29.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-10-30.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-10-31.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-11-01.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-11-02.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-11-03.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-11-04.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-11-05.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-11-06.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-11-07.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-11-08.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-11-09.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-11-10.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-11-11.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-11-12.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-11-13.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-11-14.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-11-15.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-11-16.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-11-17.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-11-18.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-11-19.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-11-20.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-11-21.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-11-22.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-11-23.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-11-24.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-11-25.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-11-26.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-11-27.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-11-28.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-11-29.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-11-30.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-12-01.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-12-02.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-12-03.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-12-04.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-12-05.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-12-06.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-12-07.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-12-08.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-12-09.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-12-10.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-12-11.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-12-12.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-12-13.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-12-14.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-12-15.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-12-16.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-12-17.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-12-18.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-12-19.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-12-20.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-12-21.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-12-22.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-12-23.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-12-24.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-12-25.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-12-26.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-12-27.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-12-28.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-12-29.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-12-30.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2021-12-31.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-01-01.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-01-02.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-01-03.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-01-04.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-01-05.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-01-06.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-01-07.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-01-08.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-01-09.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-01-10.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-01-11.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-01-12.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-01-13.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-01-14.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-01-15.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-01-16.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-01-17.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-01-18.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-01-19.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-01-20.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-01-21.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-01-22.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-01-23.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-01-24.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-01-25.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-01-26.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-01-27.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-01-28.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-01-29.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-01-30.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-01-31.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-02-01.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-02-02.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-02-03.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-02-04.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-02-05.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-02-06.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-02-07.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-02-08.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-02-09.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-02-10.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-02-11.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-02-12.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-02-13.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-02-14.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-02-15.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-02-16.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-02-17.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-02-18.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-02-19.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-02-20.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-02-21.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-02-22.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-02-23.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-02-24.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-02-25.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-02-26.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-02-27.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-02-28.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-03-01.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-03-02.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-03-03.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-03-04.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-03-05.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-03-06.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-03-07.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-03-08.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-03-09.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-03-10.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-03-11.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-03-12.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-03-13.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-03-14.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-03-15.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-03-16.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-03-17.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-03-18.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-03-19.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-03-20.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-03-21.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-03-22.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-03-23.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-03-24.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-03-25.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-03-26.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# [INFO] Öffentlich-rechtlich – Datei: 2022-03-27.csv
# [INFO] Verarbeitung erfolgreich: dlf
# [INFO] Verarbeitung erfolgreich: tagesschau
# ...
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-02-15.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-02-16.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-02-17.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-02-18.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-02-19.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-02-20.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-02-21.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-02-22.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-02-23.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-02-24.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-02-25.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-02-26.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-02-27.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-02-28.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-03-01.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-03-02.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-03-03.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-03-04.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-03-05.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-03-06.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-03-07.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-03-08.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-03-09.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-03-10.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-03-11.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-03-12.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-03-13.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-03-14.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-03-15.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-03-16.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-03-17.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-03-18.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-03-19.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-03-20.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-03-21.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-03-22.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-03-23.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-03-24.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-03-25.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-03-26.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-03-27.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-03-28.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-03-29.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-03-30.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-03-31.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-04-01.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-04-02.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-04-03.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-04-04.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-04-05.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-04-06.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-04-07.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-04-08.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-04-09.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-04-10.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-04-11.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-04-12.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-04-13.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-04-14.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-04-15.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-04-16.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-04-17.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-04-18.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-04-19.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-04-20.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-04-21.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-04-22.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-04-23.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-04-24.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-04-25.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-04-26.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-04-27.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-04-28.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-04-29.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Technologie – Datei: 2025-04-30.csv
# [INFO] Verarbeitung erfolgreich: heise
# [INFO] Verarbeitung erfolgreich: golem
# [INFO] Verarbeitung erfolgreich: t3n
# [INFO] Verarbeitung erfolgreich: netzpolitik
# [INFO] Cluster Technologie – Ergebnisform: (5461011, 5)
# [WARNUNG] Technologie enthält 192 Zeilen ohne 'word'
# filename
# 2021-05-13-heise.html    1
# 2021-09-21-heise.html    1
# 2021-10-08-heise.html    1
# 2021-11-01-heise.html    1
# 2021-11-03-heise.html    1
# Name: count, dtype: int64
#          count            word source        date               filename
# 545430       1       nationale    t3n  2021-09-02    2021-09-02-t3n.html
# 3443929      1  heise-magazine  heise  2023-11-27  2023-11-27-heise.html
# 2421285      1          tests“  heise  2023-03-18  2023-03-18-heise.html
# [INFO] Log gespeichert unter: output/cluster_tech_log.csv
# [INFO] Fehlerhafte Dateien gespeichert unter: output/cluster_tech_failures.csv

# %% [markdown]
# #### 5. Speicherung der Ergebnisse

# %%
# Einzelne Cluster laden
df_or = pd.read_csv("output/cluster_oeffentlich.csv")
df_wm = pd.read_csv("output/cluster_wirtschaft.csv")
df_gm = pd.read_csv("output/cluster_grossemedien.csv")
df_rm = pd.read_csv("output/cluster_regiomedien.csv")
df_di = pd.read_csv("output/cluster_digital.csv")
df_tech = pd.read_csv("output/cluster_tech.csv")

# %%
# Cluster-Dateien zusammenführen
df_medien = pd.concat([df_or, df_wm, df_gm, df_rm, df_di, df_tech], axis=0, ignore_index=True)
print("[INFO] Gesamt-Daten zusammengeführt.")
print("[INFO] Zeilenanzahl:", len(df_medien))
# Out:
# [INFO] Gesamt-Daten zusammengeführt.
# [INFO] Zeilenanzahl: 48097645

# %%
# In SQLite-Datenbank speichern
# Verbindung SQLite-Datenbank
conn = sqlite3.connect("output/dwh.sqlite3")
# chunk: Große Tabellen in Blöcken speichern, um Speicher zu schonen
df_medien.to_sql("wordcount", conn, if_exists="replace", index=False, chunksize=100_000)

# Verbindung schließen, Ressource freigeben
conn.close()
print("[INFO] In Datenbank gespeichert unter Tabelle 'wordcount'.")
# Out:
# [INFO] In Datenbank gespeichert unter Tabelle 'wordcount'.

# %%
# DataFrame auch als zentrale CSV speichern
df_medien.to_csv("output/df_medien.csv", index=False)
print("[INFO] Als zentrale CSV gespeichert.")
# Out:
# [INFO] Als zentrale CSV gespeichert.
