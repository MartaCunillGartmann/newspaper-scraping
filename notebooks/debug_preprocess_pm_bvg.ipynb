# %% [markdown]
# ### preprocess_pm.ipynb – Datenaufbereitung für die Frequenzanalyse
#
# Dieses Notebook bereitet die Inhalte der BVG-Pressemitteilungen strukturiert auf.
# Der Fokus liegt auf der Extraktion des eigentlichen Pressetexts und der anschließenden Bereinigung.
# Die Ergebnisse (Wortfrequenzen) dienen als Grundlage für nachgelagerte Analysen.

# %% [markdown]
# #### 1. Import benötigte Pakete

# %%
# Standard
import os
import pandas as pd # Datenanalyse
import sqlite3  # Speicherung in SQLite-Datenbanken
import sys  # Systemfunktionen 

# Bearbeiten von HTML-Dateien
from bs4 import BeautifulSoup  # HTML auslesen und bereinigen
from collections import Counter

# Eigene Funktionen (ausgelagert)
sys.path.append("../scripts") # Pfad zu den Funktionen
# Funktionen aus datenaufbereitung.py importieren
from datenaufbereitung import (
    load_stopwords,
    read_html_file,
    extract_date_from_html,
)
stopwords_list = load_stopwords()

# %%
# Pfade
INPUT_FOLDER = os.path.join("..", "input", "pm_bvg_raw")
OUTPUT_FOLDER = os.path.join("..", "output")

# %%
# CSV Datei Wortzählung einlesen
df = pd.read_csv("output/pm_bvg_wordcount.csv")

# %%
# Top 10 Wörter BVG-Webseite
top10 = df.groupby("word")["count"].sum().sort_values(ascending=False).head(10)
print(top10)
# Out:
# word
# bvg                     6693
# berliner                1497
# service                 1424
# startseite              1397
# pressemitteilungen      1395
# cookie-einstellungen    1395
# werden.                 1191
# informationen           1020
# 2025                     992
# tickets                  946
# Name: count, dtype: int64

# %%
# DEBUG Wird der bereinigte DataFrame wirklich gespeichert?
print(df.head(10))
# Out:
#    count                  word  source        date
# 0     12                   bvg  bvg_pm  2021-08-06
# 1      8              biesdorf  bvg_pm  2021-08-06
# 2      6              berliner  bvg_pm  2021-08-06
# 3      4                berlin  bvg_pm  2021-08-06
# 4      4                    13  bvg_pm  2021-08-06
# 5      3               werden.  bvg_pm  2021-08-06
# 6      3                points  bvg_pm  2021-08-06
# 7      3               service  bvg_pm  2021-08-06
# 8      3  cookie-einstellungen  bvg_pm  2021-08-06
# 9      3                    go  bvg_pm  2021-08-06

# %% [markdown]
# #### 2. Definition der Verarbeitungsfunktionen (Extraktion & Bereinigung)

# %%
# Eigentlicher Pressetext in Wörter umwandeln, Stoppwörter entfernen
def clean_and_split_text(text, stopwords_list):
    # Text in Kleinbuchstaben + Zeilenumbrüche raus
    text = text.lower().replace("\n", " ")

    # In Tokens aufteilen
    tokens = text.split()

    # Stoppwörter und kurze Wörter raus
    return [w for w in tokens if len(w) > 1 and w not in stopwords_list]

# %%
def extract_press_text(html):
    soup = BeautifulSoup(html, "html.parser")

    # Aktuelle Pressemitteilungen (mit <p>-Tags)
    paragraphs = soup.find_all("p")
    if paragraphs:
        return " ".join(p.get_text() for p in paragraphs)

    # Ältere Pressemitteilungen (RichText-Klasse)
    richtext_divs = soup.find_all("div", class_="RichText_RichText__F_qRr")
    if richtext_divs:
        return " ".join(div.get_text() for div in richtext_divs)

    # 3. Fallback
    return soup.get_text(separator=" ")

# %% [markdown]
# #### 3. Anwendung der Verarbeitungsfunktionen auf die Pressemitteilungen

# %%
# Ergebnisse sammeln
collection = []

# Pressemitteilungen (HTML-Dateien) zur Verarbeitung laden
files = [f for f in os.listdir(INPUT_FOLDER) if f.endswith(".html")]

for file in files:
    file_path = os.path.join(INPUT_FOLDER, file)
    try:
        # HTML laden mit ausgelagerter Funktion
        html = read_html_file(file_path)

        # Datum extrahieren mit ausgelagerter Funktion
        date_str, year = extract_date_from_html(html)

        # Nur Pressetext extrahieren
        text = extract_press_text(html)

        # Text bereinigen und in Wörter umwandeln
        words = clean_and_split_text(text, stopwords_list)

        # Häufigkeit jedes Wortes zählen mit Counter
        word_counts = Counter(words)

        # Als DataFrame formatieren mit Spalten Wort, Medium, Datum
        count_df = pd.DataFrame(word_counts.items(), columns=["word", "count"])
        count_df["source"] = "bvg_pm"
        count_df["date"] = date_str

        # Ergebnis speichern
        collection.append(count_df)

    except Exception as e:
        print(f"Fehler bei Datei {file}: {e}")

# %%
# Alle Ergebnis speichern, in DataFrame umwandeln
df_all = pd.concat(collection, ignore_index=True)

# %%
# Ausgewählte Jahre filtern

# Datum als Datetime
df_all["date"] = pd.to_datetime(df_all["date"])

# Nur Daten von 2021 bis 2025 behalten
df_all = df_all[df_all["date"].dt.year.between(2021, 2025)]

# Jahrsspalte hinzufügen
df_all["year"] = df_all["date"].dt.year

# %%
df_all["year"].value_counts().sort_index()
# Out:
# year
# 2021    13934
# 2022    15172
# 2023    10863
# 2024     9257
# 2025     2806
# Name: count, dtype: int64

# %%
# DEBUG  1. Wurden Stoppwörter überhaupt geladen?
print("Beispiel-Stoppwörter:", stopwords_list[:10])
print("Anzahl Stoppwörter:", len(stopwords_list))
# Out:
# Beispiel-Stoppwörter: ['ab', 'aber', 'abermaliges', 'abermals', 'abgerufen', 'abgerufene', 'abgerufener', 'abgerufenes', 'abgesehen', 'acht']
# Anzahl Stoppwörter: 1854

# %%
# DEBUG 2. Wird clean_and_split_text() überhaupt aufgerufen?
print("[DEBUG] Originaltext (100 Zeichen):", text[:100])
print("[DEBUG] Erste 10 Tokens vor Bereinigung:", text.lower().replace("\n", " ").split()[:10])
print("[DEBUG] Erste 10 Wörter nach Bereinigung:", words[:10])
# Out:
# [DEBUG] Originaltext (100 Zeichen): Pressemitteilung, 26.07.2018. Am U-Bahnhof Zwickauer Damm wird in den kommenden Monaten einiges los
# [DEBUG] Erste 10 Tokens vor Bereinigung: ['pressemitteilung,', '26.07.2018.', 'am', 'u-bahnhof', 'zwickauer', 'damm', 'wird', 'in', 'den', 'kommenden']
# [DEBUG] Erste 10 Wörter nach Bereinigung: ['pressemitteilung,', '26.07.2018.', 'u-bahnhof', 'zwickauer', 'damm', 'kommenden', 'monaten', 'los', 'sorgen', 'ausnahmsweise']

# %%
# DEBUG 3. Wird der bereinigte DataFrame wirklich gespeichert?
print(df_all.head(10))
# Out:
#                       word  count  source       date  year
# 108  …marzahn-hellersdorf!      1  bvg_pm 2021-08-06  2021
# 109                 punkte      1  bvg_pm 2021-08-06  2021
# 110         berliner*innen      1  bvg_pm 2021-08-06  2021
# 111                 bezirk      2  bvg_pm 2021-08-06  2021
# 112           musikalische      1  bvg_pm 2021-08-06  2021
# 113            darbietung,      1  bvg_pm 2021-08-06  2021
# 114               modernes      1  bvg_pm 2021-08-06  2021
# 115     mobilitätsangebot.      1  bvg_pm 2021-08-06  2021
# 116               freitag,      1  bvg_pm 2021-08-06  2021
# 117                     6.      1  bvg_pm 2021-08-06  2021

# %%
print("[DEBUG] Spaltennamen:", df_all.columns)
print("[DEBUG] Beispiel-Wörter:", df_all["word"].unique()[:10])
# Out:
# [DEBUG] Spaltennamen: Index(['word', 'count', 'source', 'date', 'year'], dtype='object')
# [DEBUG] Beispiel-Wörter: ['…marzahn-hellersdorf!' 'punkte' 'berliner*innen' 'bezirk' 'musikalische'
#  'darbietung,' 'modernes' 'mobilitätsangebot.' 'freitag,' '6.']

# %%
# Prüfung
print(df_all.shape)
print(f"Verarbeitet: {len(files)} Dateien")
print(f"Gesamtzahl Wörter: {len(df)}")
# Out:
# (52032, 5)
# Verarbeitet: 910 Dateien
# Gesamtzahl Wörter: 143198

# %%
# Prüfung
print(df_all.shape)
print(f"Verarbeitet: {len(files)} Dateien")
print(f"Gesamtzahl Wörter: {len(df)}")
# Out:
# (52032, 5)
# Verarbeitet: 910 Dateien
# Gesamtzahl Wörter: 143198

# %%
# Nur Pressetext extrahieren
text = extract_press_text(html)

# Text bereinigen
words = clean_and_split_text(text, stopwords_list)
print(f"[DEBUG] Erste 10 Wörter im Originaltext: {text.lower().split()[:10]}")
print(f"[DEBUG] Erste 10 Wörter nach Bereinigung: {words[:10]}")
# Out:
# [DEBUG] Erste 10 Wörter im Originaltext: ['pressemitteilung,', '26.07.2018.', 'am', 'u-bahnhof', 'zwickauer', 'damm', 'wird', 'in', 'den', 'kommenden']
# [DEBUG] Erste 10 Wörter nach Bereinigung: ['pressemitteilung,', '26.07.2018.', 'u-bahnhof', 'zwickauer', 'damm', 'kommenden', 'monaten', 'los', 'sorgen', 'ausnahmsweise']

# %% [markdown]
# #### 5. Speicherung der Ergebnisse (Wortfrequenzen)

# %%
# Als csv speichern
CSV_CLEAN_PATH = os.path.join(OUTPUT_FOLDER, "wordcount_pm_clean.csv")
df_all.to_csv(CSV_CLEAN_PATH, index=False)

print(f"Bereinigte Wortzählung als CSV gespeichert unter: {CSV_CLEAN_PATH}")
# Out:
# Bereinigte Wortzählung als CSV gespeichert unter: ..\output\wordcount_pm_clean.csv

# %%
# Prüfung: Vergleich alte und neue CSV-Datei
# Alte Datei
df_old = pd.read_csv("output/pm_bvg_wordcount.csv")  

# Neue bereinigte Datei
df_new = pd.read_csv("output/wordcount_pm_clean.csv")

# %%
# Wortfrequenz berechnen (gesamt)
top_old = df_old.groupby("word")["count"].sum().sort_values(ascending=False)
top_new = df_new.groupby("word")["count"].sum().sort_values(ascending=False)

# %%
set(top_old.index) - set(top_new.index)
# Out:
# {'05.05.2022',
#  '…war',
#  'einvernehmen',
#  'bvg-warnstreik',
#  'tri,',
#  'fahrgäste.“',
#  '6x',
#  'dach-region.',
#  'ordnungsämter.“',
#  'zukommt.“',
#  'ableger',
#  'auguste-viktoria-krankenhauses.',
#  'ansteigen.',
#  'modetestgruppe',
#  '05.04.2023',
#  '448',
#  'streich',
#  'bahnen!',
#  '50-meter-straßenbahnen',
#  'u-bahnfahrzeuge.',
#  '16.07.2021',
#  'www.jelbi.de/lindenhof',
#  'profitiert,',
#  'konnten.“',
#  'marschall',
#  'tauschgeschäft',
#  'denker',
#  '„bronze“.',
#  'ohrwurmalarm!',
#  'viertels',
#  'ausüben.',
#  '21.000',
#  'idealfall',
#  'vor-ab',
#  'belastung.',
#  'tickets.',
#  'wirtschaftlicher',
#  'impf-shuttle',
#  'marzahn-hellersdorf.',
#  '05.12.2022',
#  'zuschläge.',
#  'recruiting-kampagne,',
#  'recruiting“).',
#  '15.10.2021',
#  'gebaut…',
#  'www.jelbi.de/biesdorf',
#  'krankmeldungen.',
#  'gleisberechtigung',
#  'haltestellen.”',
#  'ingenieurwesen,',
#  '\t\xa0',
#  'fragezeiten',
#  'fahrer*innen.\xa0',
#  'emmaus-kirchengemeinde',
#  '16.03.2021',
#  'was!',
#  'stillgelegten',
#  'wäre.“',
#  'bedingten,',
#  'ort.“',
#  'übernahme',
#  'zurechtfinden.',
#  'with',
#  'schlafsäcke',
#  'da!',
#  '“sinnvollen”',
#  'umfassendere',
#  'drahtig',
#  'alle(e)',
#  'entgeltumwandlung',
#  'berliner?',
#  'abgestellt.',
#  'mendelssohn-bartholdy-park“.',
#  'freimachen',
#  'veralteten',
#  'werden!',
#  'konzentration',
#  'neufahrzeuge,',
#  'kommse',
#  'spiekermann,',
#  'tramwochen',
#  'straffen.',
#  'essenziell,',
#  'beseitigung',
#  'unterzieht,',
#  'einzureichen',
#  'untersagt',
#  'verewigt,',
#  'aufgaben.“',
#  'zulagenthemen',
#  'öpnv:',
#  'that’s',
#  'on',
#  'wirkung.',
#  'neuheit:',
#  'interimistisch',
#  '19.01.2022',
#  'engstem',
#  'kleinmachnow',
#  'spielort.“',
#  'betriebsressorts',
#  'pilotprojekts.',
#  'verbringen.“',
#  'frey',
#  'beantwortet.',
#  'sofort:',
#  'simulatoren',
#  'verkehrspolitisch',
#  'alternative.“',
#  'tram-tram',
#  '06.03.2024',
#  'diagramme',
#  'https://www.bvg.de/de/service-und-kontakt/fundbuero',
#  'maßnahmenbündel',
#  'klangvoll',
#  'verdoppeln.',
#  'flottengröße.',
#  'einzubinden,',
#  'umfeld.“',
#  '08.02.2022',
#  'fährmann,',
#  'krankstand.',
#  '.\xa0',
#  '(transport',
#  'eu-weiten',
#  'erobert',
#  'bedauere',
#  '28.07.2023',
#  'binden,',
#  'eckardt',
#  'fakten:',
#  'west.',
#  'cicerostraße.',
#  'bvg-archivleiter',
#  '3700',
#  'fahrzeugbestand',
#  '06.10.2023',
#  'begrenzt.\xa0daher',
#  '21.06.2022',
#  'an!',
#  'wilmer',
#  'begehrt,',
#  'aufzugschächte.\xa0',
#  '&\xa0antworten“\xa0informieren.',
#  'auswirken',
#  '08.07.2021',
#  '28.11.2023',
#  'zitate:',
#  'bereitstellen.',
#  'bedarfs.',
#  '07.03.2024',
#  'städteübergreifende',
#  'anwohnenden',
#  'darzustellen“,',
#  'hört',
#  'www.jelbi.de/charite',
#  'aufgaben.',
#  'https://www.bvg.de/de/service/service-fuer-unterwegs/mobilitaetshilfen',
#  'vergleist',
#  'besuchen',
#  'presse.',
#  'baumgardt',
#  'benutzen.',
#  '07.10.2022',
#  'ausbildungsstandort.',
#  'einwilligung',
#  'weiterbau',
#  'auslieferungstermin',
#  'gelenkbus-generation',
#  'schärfung',
#  'betrachten.',
#  'stabileren',
#  'jut',
#  'presseinformation:',
#  'bereitstellen',
#  'baugeräten.',
#  'vollzogen',
#  '„menschen,',
#  'seiten,',
#  'nicht-notwendige',
#  'man!',
#  'modedesigner.',
#  'planetary',
#  'gleischen',
#  'langweilig',
#  'aykal',
#  'kleidungsstück',
#  'voran.”',
#  'männerkleidung',
#  'automaten.',
#  'unterm',
#  'erfolgsmodell:',
#  'zehlendorfer',
#  'urlaubsansprüche',
#  'abb.',
#  '23.06.2022',
#  'binden.',
#  'straßenebene.',
#  'bvg“\xa0',
#  'inklusiv',
#  'bvg-fahrzeugexpert*innen',
#  'network_berlin“.',
#  'freue.“',
#  'klimawandelfolgen',
#  'innehalten!',
#  'qualifizieren',
#  'beton.“',
#  'originalgetreuen',
#  'und…',
#  'zweck,',
#  '16.08.2022',
#  'jahresende:',
#  'hürde',
#  'wesener',
#  '8.100',
#  'ziehen“,',
#  'www.bvg.de/cabrio',
#  'begeistern.“',
#  'https://www.youtube.com/watch?v=vw0rr-u5ism',
#  'wähle',
#  '21.05.2021',
#  'pausenregelungen',
#  '14.11.2024',
#  '210-grad-sichtfeld',
#  'termine.',
#  'dokument,',
#  'paradebespiel',
#  'baumschnitt',
#  'nahtlosen',
#  'anwohnendenveranstaltung\xa0und',
#  'dienstkleidungsträger*innen',
#  'musike',
#  'stellt.',
#  'stromschienen-schmierzug.',
#  '10.08.2021',
#  'aufzugs.',
#  'simuliert.',
#  'geben.\xa0die',
#  'mühe',
#  'mobilitätswender*innen',
#  '30.03.2021',
#  'erscheint,',
#  '24.09.2024',
#  'bvg.de/job-bus',
#  'indeed',
#  'rampenbau',
#  '50-meter-variante,',
#  'recruiting-bemühungen',
#  'schwerpunktbahnhöfen.',
#  '„wissen',
#  '11.07.2023',
#  'kleiderspenden-aktion',
#  'kiziltepe',
#  'star',
#  'warmer',
#  'happens',
#  'schicke',
#  '13.04.2021',
#  'sagt,',
#  'reinigungsfirmen',
#  'tramseiten',
#  '(2025)',
#  '„flott',
#  '28.04.2025',
#  'abzeichnende',
#  'bvg-aufsichtsratsvorsitzende).',
#  'breite:',
#  '23.03.2021',
#  'runderneuert.',
#  'dienstzeiten',
#  'isomatten',
#  'schichauweg.',
#  '09.03.2022',
#  'provisorischer',
#  '14.05.2021',
#  'sommer?',
#  'gelb!',
#  'ausbildungsprozesse',
#  'umstiege,',
#  'fix',
#  'google.',
#  'nachgeahmt,',
#  'reine',
#  '27.05.2022',
#  'sbv',
#  'hochkant',
#  '„brand',
#  '04.10.2021',
#  'profilbildung,',
#  'verbesserungen,',
#  'herzenssache.“',
#  'gründe',
#  'messbare',
#  '20.08.2021',
#  'gleiszeitig',
#  'produziert.',
#  'bewarben',
#  'wurde.“',
#  'zivkovic',
#  'bindungsphase',
#  'alabali-radovan.',
#  'entscheidend“,',
#  '(förster-funke-allee)',
#  'job.',
#  'pressestatement:',
#  'infomaterial.',
#  'entschieden.“',
#  'grundlagenermittlung',
#  '15.11.2023',
#  '…13',
#  '„aufmerksamkeitstöne',
#  'tragetest',
#  'krank.',
#  '(auch)',
#  'sharité',
#  'anhang).',
#  'account.',
#  '20.10.2021',
#  'symbolischen',
#  'maike',
#  'joballtag',
#  'freizeiteinrichtungen.',
#  'turnusmäßig',
#  '08.10.2021',
#  'jk-fahrzeug',
#  '04.06.2021',
#  'erklärung',
#  'gependelt',
#  'lebe',
#  'kostenrahmenschätzung',
#  'losgehen.',
#  'kerner',
#  '28.12.2022',
#  'stand-',
#  'bargeldlos.',
#  'unzufriedenheiten',
#  'visuellen',
#  '06.05.2024',
#  'diggi!',
#  'ändern.“',
#  'begrüßt.',
#  '15.09.2022',
#  'nachbarländer.“',
#  'lagerkapazitäten',
#  'aufgebauten',
#  'lebenszyklus',
#  'gestellt.“',
#  's-bahnhof.',
#  'erstqualifizierung.',
#  'verwenden',
#  '08.06.2022',
#  'fakten?',
#  'la',
#  'erhalten.\xa0',
#  '8000',
#  'expertise',
#  'kollektion.',
#  'aufträge',
#  'motiviert,',
#  'weltgeschichte',
#  'exemplare,',
#  'uhrenstation.',
#  'w.',
#  'ergeben.',
#  'hole',
#  '175,',
#  'sicher!',
#  'lassen.\xa0',
#  'rauchen',
#  'zug!',
#  'guthaben…',
#  'unzureichenden',
#  'u8-strecke',
#  'hardcover',
#  'spur:',
#  'warnt.',
#  'webseiten',
#  '04.02.2025',
#  'beton.',
#  '19.11.2021',
#  '22.10.2024',
#  'kleiderschränke',
#  '„häufige',
#  '08.08.2022',
#  '(76',
#  '16.12.2022',
#  'monate.\xa0\xa0',
#  'aufwerten',
#  'spricht!',
#  '16.05.2022',
#  'situationen.',
#  'shirts',
#  'kusmin-tyburski',
#  'gewinnen.“',
#  'tattoo-artist*innen',
#  'einsehen.',
#  '(albert-einstein-ring)',
#  'ers-tes',
#  'fortsetzen.“',
#  '30.08.2024',
#  '20.09.2023',
#  '„mitliefert“.',
#  '27.10.2022',
#  's-bahnchef',
#  'aufzugsstörungen.',
#  'überzeugen.“',
#  's-bahnnetz.',
#  'entwürfe',
#  '05.09.2022',
#  'social-media-aktivitäten',
#  'abgeben',
#  '(werk)elt',
#  'liniendienst.',
#  '17.11.2023',
#  'bvg-style.“',
#  'schönes',
#  '08.04.2024',
#  'wärme',
#  'vir',
#  'wegklicken.',
#  'buchner',
#  'firmen-abo',
#  'anfällig.',
#  'hallo!',
#  'angekommen',
#  'erfüllen.“',
#  'emma-herwegh-/clara-jaschke-straße).',
#  'das\xa0jelbi-netz\xa0in',
#  'minuten:',
#  'zukunftsgerichtet',
#  'team.',
#  'schulter.“',
#  'sixten',
#  'style',
#  'kinderschminken,',
#  'eingesetzt.“',
#  'abstellanlage,',
#  'erleichtern.“',
#  'javascript,',
#  'verschlissen',
#  'fünf!',
#  '18.10.2024',
#  'bvg/',
#  'gegeben.“',
#  'empfang.',
#  '„urbanliner“',
#  'zukunft-des-oepnv-gemeinsam-berlin-bewegen',
#  '11.11.2022',
#  '01.09.2023',
#  'winter?',
#  'häufigkeit',
#  'materialherkunft',
#  '18.08.2022',
#  'töne?',
#  'stabilität,',
#  'sonntagsdienst',
#  'hintergrundsysteme.',
#  'hält.“',
#  'sharing-mobilitätsangeboten',
#  '11.01.2022',
#  'informationsbüro,',
#  'probeeinsatz.',
#  'influencer*innen',
#  'airbrush-tattoos',
#  'doppel-silber',
#  'betreiben.“',
#  '08.12.2023',
#  'erkennen.“',
#  'auszusteuern.\xa0\xa0',
#  'verwaltungsmitarbeitende',
#  'rein,\u200b',
#  'phase?',
#  'bewegen.“',
#  '17.08.2021',
#  '30.11.2021',
#  '18.02.2022',
#  'fertigung.',
#  'autobahnen',
#  'washington',
#  'lea-grundig-straße/raoul-wallenberg-straße',
#  '13.12.2024',
#  'stille',
#  'podcast-plattformen.',
#  'blindenführhundes.',
#  'launch',
#  'rentenbedingten',
#  'sätzen',
#  '29.08.2024',
#  'dankte',
#  'zugutekommt.',
#  '21.03.2024',
#  'gleiseinbau',
#  'bvg-kosmos',
#  'coaches,',
#  'helferinnen',
#  'stutz',
#  'aufgaben,',
#  'tks',
#  'reduzieren.“',
#  'keh.',
#  '2025,',
#  'reinigungs-mitarbeiter*innen',
#  'herz.“',
#  '18.03.2022',
#  'wissing',
#  'erleichtern.',
#  '16.11.2021',
#  'vorwoche',
#  'ungeöffnete',
#  'u2-hertha-sonderverkehr',
#  '05.07.2022',
#  'wegweisend.',
#  'ein.“',
#  '21.06.2021',
#  '13.03.2023',
#  'mach’s',
#  'fahrgastinformationsflyer',
#  'meisterwerk.“',
#  '„ordnungsrahmenprinzip“.',
#  'tattoo',
#  'gelber',
#  'ausgeliefert.',
#  'tramfahrer.“',
#  'partnerships“)',
#  'fahrzeuge.“',
#  '14.03.2023',
#  '08.04.2021',
#  'anwohner*innen.\u202fnach',
#  '2.100',
#  'managen!',
#  'zuvor!“,',
#  'momentane',
#  '25.05.2023',
#  'abzustatten.',
#  'lebens,',
#  'virtueller',
#  '19.10.2022',
#  'gekürzt',
#  'heranzuführen!“',
#  'bvg-job-busses',
#  'entscheidungsprozess',
#  '25.04.2024',
#  'um\xa014:30',
#  'pilotprojekte',
#  'besucht.',
#  'martin',
#  'zeig',
#  '1,12',
#  'meile.',
#  '19.12.2022',
#  'folgetag',
#  'http://www.paritaet-berlin.de/downloads/anlaufstellen_fahrscheine',
#  '29.07.2024',
#  '31.05.2023',
#  'portfoliomanagement',
#  'aus.“',
#  'erfolg.“',
#  'modetestgruppe:',
#  'gasag-vorstandsvorsitzender',
#  'technologien.',
#  'krönchen',
#  'sozialbereich.',
#  'glatt',
#  'job-möglichkeiten',
#  'franzi',
#  'entgeltordnung',
#  '„niederschlag',
#  'schnuppern?',
#  '#wirsindbvg',
#  'erzählen.',
#  'zugute.',
#  'foto-box.',
#  'stellenausschreibungen',
#  'vergleichsmaßstab.',
#  'rettungseinsätze,',
#  'satzung',
#  'entscheiden.“',
#  'bewerbungseingängen',
#  'übernommen.“',
#  'mausgezeichnete',
#  '05.10.2021',
#  '01.06.2021',
#  '20.06.2023',
#  's25.',
#  'individualisiert',
#  'notärzten',
#  'erneuerbare',
#  'themenschwerpunkten\xa0„architektur',
#  '2400',
#  'wendemanöver',
#  '11.08.2022',
#  'stehplätze:',
#  'zielort.',
#  'zukunftsperspektiven',
#  'vereinbarungen',
#  'einstiegstür',
#  'urbanliner:',
#  'stadtmission:',
#  'gag:',
#  'gehalten.“',
#  'fernsehturm.',
#  '29.11.2021',
#  'schließlich:',
#  'mundhaltestelle',
#  'antriebstechnik',
#  'enormer',
#  'herausfordernd',
#  'geliftet',
#  '25.04.2023',
#  'planfeststellungsunterlagen',
#  'wohngebiete.',
#  'verzweigtes',
#  'weiterführung',
#  '12.05.2021',
#  '09.09.2023',
#  'erhebung.',
#  'reiser)',
#  '08.02.2021',
#  'identifiziert.',
#  'statement.',
#  'schulter.',
#  '31479777',
#  'schwangere,',
#  'sehen:',
#  'investiert.',
#  '28.06.2022',
#  'mast-have',
#  'umlaufplan?',
#  'effie-awards',
#  'süß',
#  'besuche,',
#  'general-ganeval-brücke.',
#  'seitenwechsel',
#  'warmer,',
#  '26.11.2021',
#  'klang.“',
#  'gewähren,',
#  'blindenleitsystem.',
#  'bestehen.\xa0',
#  'durchgehend.',
#  'leistung.“',
#  'hektisches',
#  'apropos:',
#  '29.01.2021',
#  'bündeln.“',
#  'allem:',
#  'school:',
#  'werbeagenturen',
#  '20.01.2021',
#  'leistungssteigerungen',
#  '07.08.2024',
#  '11.01.2024',
#  'month.',
#  'gestalter,',
#  'sitzvarianten',
#  'bekommen.“',
#  'siegfriedstraße/herzbergstraße.',
#  'genügt.',
#  'bvg.de/bvg-muva',
#  'kiek',
#  'umgehen!“',
#  'ausrichten',
#  'kleidersammel-aktion.',
#  'ausrücken,',
#  '17.02.2021',
#  '09.02.2022',
#  '15.800.',
#  'bayern',
#  'werkstätten.',
#  'umkämpften',
#  '“es',
#  'eva\xa0kreienkamp',
#  'oliver.paschereit@tu-berlin.de',
#  'designgeschichte',
#  '0,21\xa0mb',
#  'bestreifung',
#  'https://www.doctolib.de/institut/bln/berlin-bvg',
#  'gehen?',
#  'uhr.)',
#  '„uns',
#  '18.05.2022',
#  'mitmenschen.',
#  'auffassungen',
#  'https://www.bvg.de/images/content/service/flyer_barrierefrei_2020.pdf',
#  'erneuern.“',
#  'unglaublichen',
#  '21.07.2022',
#  'würdigte',
#  '17.04.2024',
#  '27.07.2022',
#  'edition',
#  'co-autoren',
#  'zahllosen',
#  '3x',
#  '29.01.2025',
#  'realität!',
#  'schluss!',
#  'effizienz',
#  'begegnet.',
#  '16.04.2025',
#  '30.05.2024',
#  'verändern.“',
#  '29.03.2023',
#  'umleitungen.',
#  '18.12.2021',
#  'vorkommt.',
#  'ampelschaltungen,',
#  'leistungsfähigere',
#  'fusion',
#  'dorotheenstraße/universitätsstraße.',
#  'unter\xa0',
#  'bedeutendes',
#  'bonde.',
#  'feuerwehr.',
#  'nahverkehrs.“',
#  'liegenschaften.“',
#  'verkörperte',
#  'robusten',
#  'markenklang.',
#  'positionieren.',
#  'herunterladen',
#  'grün!“',
#  'rbb-abendschau,',
#  'potsdam).',
#  'leistet,',
#  'bestellter',
#  'genießt.',
#  'kleidersammel-aktion',
#  'bus-betriebshöfe',
#  'mexikoplatz,',
#  'aufgesetzt:',
#  'mitbestimmung',
#  '#nachgefragtabgehakt',
#  '108',
#  'geschaffen.“',
#  'erscheinungsbild',
#  'tools.',
#  'ehre,',
#  'musterhafte',
#  'männer',
#  '13.07.2022',
#  '23.03.2022',
#  'bekommt.',
#  'adobestock',
#  'berlin.”',
#  '03.02.2022',
#  'kalt!',
#  'frühschicht.',
#  'indira-gandhi-straße/gounodstraße',
#  'hilfsorganisationen.',
#  '„gute',
#  '13.11.2023',
#  'wissenschaftsschiene',
#  'biontech.',
#  'planungsschritte',
#  '16.08.2024',
#  '03.01.2023',
#  'schwerpunkte:',
#  'vollwertig',
#  'reinigungsleistung',
#  'gekennzeichnet.',
#  'fahrgastbetriebes',
#  'funktional,',
#  'kennzeichnen.',
#  'standorte.',
#  'bestärken“,',
#  'bietet…',
#  '01.07.2024',
#  'bezeichnet.',
#  '07.09.2022',
#  'status',
#  'ragnhild',
#  'schienenfleißig',
#  'voss',
#  'zukunft:',
#  'überfordert',
#  'ansporn.',
#  '25.05.2021',
#  'rädern“',
#  '26.10.2022',
#  'baukommunikation',
#  'leben“.',
#  'startlöcher',
#  'regionen.“',
#  'einspeisen.',
#  'kerßenfischer.',
#  'job.“',
#  'personalausschuss',
#  'aufgedeckt',
#  'echtzeitstandorte',
#  'begannen.',
#  '(neukölln)',
#  '15.02.2021',
#  'neues!',
#  'heizungen,',
#  'niederlanden.',
#  'fleißige',
#  '10.06.2024',
#  '2026)',
#  'stieß',
#  'kleidung,',
#  'viadukt',
#  'besuchsdienste,',
#  '„möglichkeiten',
#  'fuchs',
#  '„evergreen“',
#  '05.07.2024',
#  'netzlücke',
#  'versiebenfacht',
#  'erhöhen.\xa0',
#  'unterstreichen.\xa0wenn',
#  'schmiedel,',
#  'hinein.“',
#  'erklärvideo',
#  'https://www.bvg.de/de/verbindungen/bvg-muva/aufzugersatz',
#  'fahrgastbetrieb,',
#  '57',
#  '15.08.2022',
#  'zeitalter',
#  'klimaaktivisten',
#  'dank.“',
#  'em-spielen.',
#  '28.02.2023',
#  'betrieblicher',
#  'aktualisiert.',
#  '1x',
#  'panktastische',
#  'intensivierten',
#  'e-mail:',
#  '12.04.2021',
#  'pulli.',
#  'jelbe',
#  'ressourcen',
#  'angehen.“',
#  'prüfe,',
#  'topmodernen',
#  'mittendurch',
#  'ausbilden',
#  'berlijn',
#  'ausschlaggebend',
#  'steglitzeblank',
#  'gedämmt',
#  'parklätze.',
#  '25.06.2021',
#  'sorgfältig',
#  'ungebrochen',
#  'ausbauen.“',
#  'cookies',
#  'messen',
#  '(gwa).',
#  'wachstum”',
#  'hey',
#  'urheber:',
#  'maja',
#  'fälle.',
#  'kleidersammelaktion',
#  'meinungen',
#  'tra,',
#  '„haustür“',
#  'karriere-seite',
#  'verlassen,',
#  'startende',
#  'knifflige',
#  'grenzenlos',
#  '11.03.2022',
#  'anzusagen.',
#  '15.02.2024',
#  'österlicher',
#  'akzeptieren',
#  'würdigt.“',
#  '11.05.2023',
#  'wirkung.“',
#  'intakter',
#  'abzeichnen-de',
#  'siegfried',
#  'hygieneartikel.',
#  'willen.',
#  'angebotskonzepts',
#  'eskalation:',
#  'identität.',
#  'convention',
#  'katja',
#  'geschmeidiger',
#  'erholt.“',
#  'mitarbeitendenzahl',
#  'erzählen',
#  'draufsetzen.',
#  'august-bebel-platz,',
#  'u-bahn-abstellanlagen',
#  'betriebspausen.',
#  'tickets.“',
#  'komm',
#  '20.04.2023',
#  '15.02.2023',
#  'zusammen.“',
#  'kunststoffschwellen.',
#  'wieder!',
#  'halt!',
#  '21.10.2021',
#  'decken,',
#  '06.08.2021',
#  'jahren“,',
#  'wärmebildferngläser.',
#  'netzentwicklung.',
#  'fahrgastbefragung.',
#  'einzugsgebiet.',
#  'prozesse.',
#  '14.10.2021',
#  '„vielfalt“',
#  '05.10.2023',
#  '12.01.2023',
#  'ja,',
#  'geimpft',
#  'quelle:',
#  'herzschmerz!',
#  'zweckmäßig',
#  '16.03.2023',
#  'fühlen.“\xa0',
#  'prägt.“',
#  'verfestigt.',
#  'unterquerung',
#  'dies.',
#  '27.04.2023',
#  'trägern',
#  'regierungsbesuch',
#  'klar!',
#  'tatra-straßenbahnen.',
#  'wahrnahmen,',
#  '„smartrecruiters“',
#  'haltepunkte.',
#  'ordert',
#  'monat.\xa0',
#  'generalplanungsleistungen',
#  '15.07.2024',
#  '2026.\xa0',
#  'beigelegt.',
#  '19.07.2023',
#  '430',
#  'erledigen.“',
#  'elektrobusflotte',
#  'begangen.',
#  '03.07.2024',
#  'bronze',
#  'sicherstellung',
#  '01.11.2022',
#  'deutschland/vcd):',
#  'bvg-designs,',
#  'verliehen',
#  '23.04.2021',
#  'm13.',
#  '06.05.2021',
#  '13.03.2024',
#  'zweifache',
#  '25.08.2021',
#  'lisbeth.',
#  'gleiskörper',
#  'verkehrsmittel.“',
#  '06.05.2022',
#  'gebot',
#  'aussichten',
#  'it-fachkräfte.“',
#  '20.09.2021',
#  'daniela',
#  'daran.',
#  '12,2',
#  'umlaufplan',
#  'huetten',
#  'besprochen.',
#  'wassersportallee.',
#  'unterstützen.“',
#  'kreativer',
#  'körperschall.',
#  'eisregen,',
#  'inoffizielle',
#  'mobilitätspartnerschaft.',
#  'auflösungsvereinbarung',
#  'läuft´s',
#  'fahrzeugpart',
#  'zweckverband',
#  'testfahrzeug',
#  'auswählen,',
#  '):',
#  'euro\xa0',
#  'jette',
#  '30.06.2023',
#  '27.01.2022',
#  'plätze.',
#  'hör',
#  'kundengarantie',
#  'verstanden',
#  'regelbetrieb',
#  'interimsvorstand',
#  '10.06.2022',
#  'lenkanstoß:',
#  '2.5.2025',
#  'expert*innen-vorträge',
#  '09.07.2021',
#  'fahrsimulatoren',
#  'pult-variante',
#  'bewerben“',
#  ...}

# %%
set(top_new.index) - set(top_old.index)
# Out:
# {'25.05.2018.',
#  'philippe',
#  'u-bahn.nötig',
#  'kooperativen',
#  'digitalisierung,',
#  'genannt):',
#  'ausbauen.während',
#  'www.berlkönig.de.\xa0kontaktberliner',
#  'aus.zum',
#  'jahre.neben',
#  'routenkonzept',
#  'akkugestresste',
#  'schillingstraße',
#  'metrobus-linien',
#  'und\xa0menschen,',
#  'eindeutig',
#  'stromnetz.die',
#  'updates',
#  '17.05.2018.\xa0ganz',
#  'u-bahn-strecken',
#  'abgegrenzt',
#  'wurde.\xa0das',
#  'e-mail-adresse',
#  '-tretroller.',
#  'lte-versorgung',
#  'gearbeitet.der',
#  'gewandfür',
#  'aufgehoben.wie',
#  'geräte-,',
#  'keh.während',
#  'akribisch',
#  'durfte.',
#  'das\xa0achte',
#  'verkehrsvertrages.dr.',
#  'europa.mehr',
#  'i/4',
#  'komplett.“',
#  'myfest',
#  'meile“.',
#  '61/63',
#  'nationen.alle',
#  'kreativleistung',
#  '25.11.2019.',
#  '170er',
#  '10-minuten-mindesttakte',
#  '\u200bpressemitteilung,',
#  'november:',
#  'statik',
#  'buntgeschmückte',
#  'sneakers',
#  '-verbünde',
#  'stimmte',
#  'kauft',
#  'verkehrslenkung',
#  'kunst.',
#  'hin.',
#  'kernwerte',
#  'tankstelle.',
#  'mobilität.“„wir',
#  'wbm',
#  'klingsorstraße,',
#  'u7-bahnhöfen',
#  'verlegt.die',
#  'großprojekte',
#  'mohrenstraße:',
#  '14.08.2019.',
#  'versetzen,',
#  'morgenallein',
#  '27.-',
#  'erfüllen.“dr.',
#  'lieferant',
#  'virchow-klinikum.\xa0im',
#  'fernhinweise',
#  'rusbirmingham,',
#  'mobilitätsplattform,',
#  'buchungsprozess',
#  '„autofreie',
#  'marketing)',
#  'barrierefrei.„wir',
#  'vorgeschlagen.',
#  'marzahn.zwischen',
#  '(340',
#  'aufzugseinbau,',
#  'eindeutigen',
#  'nutzer.',
#  '18.06.2018.',
#  '(bts:',
#  'geben“,',
#  'letztem',
#  'einbahnstraßen',
#  'inline-skatern,',
#  'aushänge',
#  'zufriedengeben',
#  'zubringerbusses',
#  '2015,',
#  'an.“die',
#  'software-bausteine',
#  'karneval',
#  'science',
#  'bereit.bereits',
#  'verkäufen',
#  'andauern.die',
#  'auftragen',
#  'personal.daher',
#  'faktenstärke',
#  'weih-nachtsgeschenke.',
#  'materialproben',
#  'geöffnet.\xa0die',
#  'baubereich',
#  'ticketkategorien.“die',
#  'heide',
#  '(der',
#  'beeinflusst',
#  '„fahrinfo',
#  'zurück.\xa0wissenswertes:',
#  'fensterbleche.\xa0',
#  'samstagmorgen,',
#  'energieversorger',
#  '(gneisenaustraße',
#  'frauen.übrigens:',
#  'festgelegt,',
#  'ebusco_2022quelle:',
#  '12:45',
#  'sein.zitatebettina',
#  '10,',
#  'bekommt.dr.',
#  'wiedereröffnungen',
#  '166.die',
#  'nachtbuslinien',
#  'bahnhofstraße,',
#  'buslinien.auf',
#  'zugelassenen',
#  'grundlagen.',
#  'nahverkehr“',
#  '„früher',
#  'straße.alternativ',
#  'weist',
#  'geringem',
#  '17.30',
#  'www.bvg.de/bvg-muva.infos',
#  'wiederhergestellt.',
#  'laufroute',
#  'u7.das',
#  'pc',
#  'kundengremium',
#  'abstellkapazitäten.',
#  'gab.',
#  'radrennens',
#  'richtungsweisenden',
#  'möglich.ersatzweise',
#  'originaler',
#  'geschieht,',
#  '„öffis',
#  'rolle,',
#  'annedore-leber-berufsbildungswerk',
#  'u-bahn.auch',
#  'online-umfrage',
#  'umzustellen.für',
#  'spielen,',
#  'verbindet.',
#  '30-jährigen',
#  'bvg-abteilung',
#  '140donnerstag,',
#  'n1',
#  'heutig.',
#  'heran“,',
#  'gehrenseestraße.für',
#  'ausgelasteten',
#  'wegbeschreibung',
#  'abfahrten,•',
#  'einwohnern',
#  'busbereich.der',
#  'souvenirs',
#  'railroad',
#  'sechs-',
#  'bvg-begeisterte.',
#  'antennen',
#  'grundwasser',
#  '„make-over“.natürlich',
#  'oberhavel)',
#  'werden.beim',
#  '(montags',
#  'verwendung',
#  'sätzenab',
#  'markenmusikdas',
#  'moskau,',
#  'passionierte',
#  'traditionsunternehmen,',
#  'verbessert.ebenfalls',
#  '„adc',
#  'handelt.csr',
#  'profilfreischnitte',
#  'grünanlagen.nutzer*innen',
#  'geräuschadaptive',
#  'bussen\xa0vom',
#  'deutschlandticket.„das',
#  'linienverlauf.die',
#  'puzzle.',
#  '263,',
#  'verschiedenste',
#  'taubenstraße/friedrichstraße,',
#  '27.die',
#  'smartphone-app',
#  'spielzeuge',
#  'wettkampfgeräte',
#  'einsatzkräften',
#  'führungsschienen',
#  'vi,',
#  'genießt',
#  'stellwerkstechnik.',
#  'aufteilen.linie',
#  'sinnemareykjavik,',
#  'raumklima.aber',
#  'anzubieten.“erstmals',
#  'ik18',
#  'mit.den',
#  'erhebung',
#  'können.von',
#  'stellen.der',
#  'eingreifen',
#  'einsatz.um',
#  'uhrwo?',
#  'videoclip?das',
#  'sorgen.um',
#  'leitungsträger',
#  'eröffnet.die',
#  'ausnahmesituationen',
#  'gewohnt.\xa0während',
#  'mitzugestalten.das',
#  'fort.katja',
#  'wird.bettina',
#  'lichtenberg/gudrunstraße\u202fund\u202fbersarinplatz',
#  'technikfans',
#  'enterprises',
#  'analoge',
#  'puchanstraße',
#  'ringverkehr',
#  'kilometerleistung',
#  'überdachungen',
#  'öpnv.alle,',
#  'zeichens',
#  'merkfähigkeit',
#  'cdu):',
#  'exakte',
#  'zurück.dr.',
#  'fertig.für',
#  'bvgder',
#  'olympia-stadionvoller',
#  'aufladbar.christine',
#  'märz\xa0',
#  'hochschulen',
#  'fahr-',
#  'erleben.in',
#  'definiert.',
#  'ausgestattet.seit',
#  '„route',
#  'einzubauen,',
#  'kinderprogramm',
#  'werden.von',
#  'heruntergeladen.das',
#  '15.03.2019',
#  '„s25“.',
#  'ullsteinhaus,',
#  'ausstiegsbeleuchtung',
#  'eingebaut,1418t',
#  'hinzugekommen',
#  'kann.die',
#  '„my',
#  '68\xa0und',
#  'bewerbungsformular',
#  'waltersdorf.',
#  'rücknahme',
#  'schönebergam',
#  'ungefährlichem',
#  'fachkenntnis',
#  'dauern.die',
#  'stabilitätim',
#  '28343',
#  'derzeitiger',
#  'abfahrtssituation.bisher',
#  'lichtenberg.im',
#  'vorbildern',
#  '„ordnungsrahmenprinzip“.bereits',
#  'school:die',
#  'nationaler',
#  '21.03.2019.',
#  'teilen.\xa0blankenburgbegonnen',
#  'unterschiedlichster',
#  'betriebsdienst',
#  'mobilfunkkapazitäten',
#  'heben',
#  'mitzugestalten,',
#  'wonnebergerbirmingham,',
#  'mobilfunkabdeckung',
#  'berlin-hohenschönhausen',
#  'spandauam',
#  'werden.35',
#  'organspendeausweisdie',
#  'sonderticket).',
#  'eingeweiht.bettina',
#  'u3-bahnsteig',
#  'berlin.“ute',
#  'torgauer',
#  'erstellt,',
#  'x9,',
#  'gehrenseestraße.\xa0\xa0als',
#  'siemens-konzern',
#  'kaufhauses',
#  'erreichbar.nach',
#  'übernehmen.“„den',
#  '142,',
#  'bietet……',
#  'quartiere',
#  'berufspendler',
#  'auf\xa0',
#  'bringen.“dr.',
#  'mauerfall“',
#  '%,',
#  '„regional-',
#  'eingeschränktem',
#  'weihnachten,',
#  'unterwegs.auf',
#  'zürich\xa0zeitplan09:30',
#  '743',
#  'anlagen.',
#  'breitbandanwendungen',
#  'fahrspur.',
#  'unterwegs.details',
#  'zukunftsmobilität',
#  'euro.der',
#  '25.02.2019.',
#  'organspender*innen.ganz',
#  'statt.elke',
#  'prämiert.vom',
#  '1911.',
#  'sein.\u200bgroßprojekte',
#  'sehbehindert',
#  'vorsortiert',
#  'bestehenden\u202fbuslinien\u202fin',
#  'netzwerkveranstaltungen',
#  'erwerben.in',
#  'hinmöchten,',
#  'haustürservice',
#  'berufsgruppen,',
#  'feiertage.die',
#  'perron',
#  'schwulenverband',
#  'nikutta10:10',
#  'schonen',
#  'vermittelt.die',
#  'ladevorgang',
#  'bvg.de/jobevents.',
#  'fassade',
#  'gibt.hinweis',
#  'kieztour,',
#  'gelenkbus-flotte',
#  'nutzen.damit',
#  'verlängert.auch',
#  'norden.',
#  'ausklügelten',
#  '17.07.2018.',
#  'veteranenstraße,',
#  'miteinander.\xa0',
#  's41,',
#  'kanskarotterdam,',
#  'dassel.',
#  'mannheim',
#  'straße/leipziger',
#  'fahrgästedonnerstag,',
#  'mitfahrer',
#  'durchsichtigen',
#  'verkehrsszenario',
#  'alten,',
#  'gleiswechsel,',
#  'gebaut.bis',
#  'oliver.paschereit@tu-berlin.dehttp://www.fd.tu-berlin.depd',
#  'fahrzeugsuchende',
#  'pasewalker',
#  'werden.ausführliche',
#  'straßenbahngleis',
#  'straßenbahn-,',
#  'maßstäben',
#  'mantelvertrag',
#  'können.\xa0\xa0los',
#  'berlinerisch',
#  'rasenfläche',
#  'kampagnenauftakt',
#  'genehmigt.jelbi',
#  'ergebnis.“schneller',
#  'werden.„wir',
#  'kleinprofil,',
#  'fahrscheinsortiment',
#  'abwechslung',
#  'wertschätzung.es',
#  'klausingring',
#  'anschlussfahrt',
#  'entstammt',
#  'komponente',
#  'sicherheit:',
#  '28.02.2019.',
#  'heranzuführen!“die',
#  'vergabeprozess.',
#  'bauabschnitten.von',
#  'bieten.dirk',
#  'jobangebot.',
#  '154,',
#  'erfolgreichste',
#  'fahrten\xa0neben',
#  'haus.',
#  'schnelltest',
#  'messenger',
#  'transportation.\xa0dr.',
#  'innovativste',
#  'liefern,',
#  'weht.gemeinsam',
#  'können.“insgesamt',
#  '31.8.2035',
#  'birgit.faeth@bvg.defür',
#  'fahrpläne.deutschlands',
#  'hölzelparis,',
#  'angeliefert',
#  '125kw',
#  '13,8',
#  'forschungseinrichtungen',
#  'belastung.zum',
#  'mai).',
#  'schwellen,',
#  'gekommen.um',
#  'hosen',
#  'bvg-unternehmenskommunikation,',
#  'schaffte',
#  'überprüfungen',
#  'region,',
#  '576\xa0busfreitag,',
#  'umsteigekreuz',
#  'sein?wie',
#  'straßenbahnbetreiber',
#  'einsetzbarer',
#  'bevorzugten',
#  'monats-',
#  'ringverkehr.',
#  'www.bvg.de/karriere.in',
#  'bombardier.lang,',
#  'freitagsfahrplan.',
#  'einzelpersonen',
#  'verlaufende',
#  'zusammenfassen,',
#  'zweigleisige',
#  'euro.alle',
#  'stadtränder.',
#  'kann.für',
#  'verfahren.dr.',
#  '3400',
#  'singapur',
#  'phonetisch',
#  'bvg:„wir',
#  'verlängerter',
#  'ultraschnellen',
#  '122',
#  'zwangsurlaub',
#  'verdichtet.um',
#  '2902/2903',
#  'gleisanlagen.die',
#  'vermindern.',
#  'erleichtern.“die',
#  'morgen“.\xa0die',
#  'anonymisierte',
#  'mehringdamm/ecke',
#  'treppchen',
#  'beengten',
#  'senats.',
#  '500.000.wer',
#  'commercial.',
#  'smartphone-basiertem',
#  'möglich.vorbereitend',
#  's-bahnhofes',
#  '386',
#  'finanziert.weitere',
#  'forschungscampus',
#  'lernen.„unsere',
#  'manager“',
#  'qualität.',
#  'undichtigkeit',
#  'grundlage,',
#  'onlinespot',
#  'herausforderndste',
#  'personenbezug',
#  'arbeitgeberinkampagnedie',
#  'einbezogen.die',
#  'fehlverhalten',
#  '(bmu)',
#  'thälmannplatz',
#  'https://klimatram.berlin/sonderfahrten/das',
#  'lisbeth.unterstützt',
#  'mercedesbenz',
#  'schülerverkehre',
#  'fahrtkosten',
#  'lieferte',
#  'voran.“„autonom',
#  'muss.vom',
#  'innovationscampus',
#  'bvg-historie',
#  'bellevuestraße.',
#  'hönow.\xa0das',
#  'waltersdorf',
#  'geleitet,',
#  'gudrun',
#  '15\xa0300',
#  'beck.',
#  'sharing-angebote.mehr',
#  'stopfen',
#  'einmalig.',
#  'müggelschlösschenweg',
#  'halterungsschienen',
#  'lässt,',
#  'humboldt-universität',
#  'krisen-alltag',
#  'bvg-sitzmusterdesign',
#  'kreisel',
#  'nachgewiesen.auch',
#  'voreingestellt',
#  'tollkühn,',
#  'mauerparkt',
#  'kollektive',
#  'ausgeschildert.skizze',
#  'dienstagfrüh,',
#  'vorletzten',
#  '05.12.2019.',
#  'ladens.',
#  '2012,',
#  'kann.“neben',
#  'umgeleitet.alle',
#  'jahraus',
#  'energieeffiziente',
#  'groß-lichterfelde.doch',
#  'bewegen.\xa0„kluge,',
#  'hilfsstützen',
#  'noch.“',
#  'zurückgebracht.alle',
#  '42.195',
#  'gelegen',
#  'münzautomat',
#  'euro.das',
#  'übersichtlich',
#  'anspruchsvoll,',
#  'uhr.ahoi',
#  'omnibuslinie',
#  'paare',
#  '@bvg_bus',
#  'sein.bvg',
#  '31479777e-mail:',
#  '10-uhr-karten',
#  'bequemer.der',
#  'alt.',
#  'statement.eva',
#  'fahrgastfahrten.triebfeder',
#  'fahrscheinkauf',
#  'wunschzeit',
#  'zusammengenommen',
#  'coronavirus',
#  's-bahnnetz.stimmung',
#  'gegenrichtung)',
#  'geben.pressemitteilung',
#  'bad,',
#  'u3.die',
#  'existierenden',
#  'ersparen',
#  'prozent.um',
#  'sternenhimmel,',
#  'minibusse',
#  'fremd.die',
#  'vielversprechenden',
#  'ersetzt.weiter',
#  'schillerstraße.\xa0(zu',
#  'schöneweide/sterndamm.',
#  'n5',
#  'minimum',
#  'seemannsgarn:',
#  'mobilitätsangebot,',
#  'aussteigen.durch',
#  'kultstatus',
#  'podbielskiallee,',
#  'berufsbildungswerk',
#  'x54,',
#  'zügig',
#  'smartbank',
#  'medebacher',
#  'bundestag',
#  '1284m',
#  'linden“:',
#  'werden.gestartet',
#  'angenehme',
#  'angezeigt.der',
#  'werden.\xa0„wir',
#  'plus.übrigens:',
#  'innenausbau',
#  'reden,',
#  'instandgesetzt',
#  'erreichbar.für',
#  'maskenverweigerer',
#  'mobiler“,',
#  'elektrofahrzeugen',
#  'östlicher',
#  'spritzschutz',
#  'ein.wenige',
#  '(zwei',
#  'stationiert',
#  'faserplatten',
#  'stadt.“eva',
#  'jeder.',
#  'frühverkehr.',
#  'osterwochen',
#  'schienenersatzverkehr',
#  'twitterkanäle',
#  'lob',
#  '2019“,',
#  'gebildet.für',
#  '(am',
#  'läuft,',
#  'spruch',
#  'www.berlin.de/corona.',
#  'sitzung.das',
#  'verkehrswege',
#  'wissenschaftsstandort',
#  'luftiger',
#  'lieber.“die',
#  'daten.',
#  'familienmitglied',
#  'press@viavan.com,',
#  'kreuzenden',
#  'gelenkbusse,',
#  'steht.neben',
#  'verpassten.',
#  'nachbarländer.“hoher',
#  'respekt.“in',
#  '20-minuten-takt.an',
#  '„etwas',
#  'müggelschlößchenweg.die',
#  'hinblick',
#  'fahraufgaben',
#  'logistische',
#  'award,',
#  'medientelefon:',
#  '1045',
#  'rudolfstraße',
#  'haben.“das',
#  'anfühlen',
#  'prinzip.',
#  '2025.neben',
#  'verdoppeln.das',
#  'sind.\xa0*bitte',
#  'netzdesign,',
#  'reichweitenprognose,',
#  'nachfragen,',
#  'hocheffizienten',
#  'können.der',
#  'ermöglichen.regine',
#  '28600markus.falkner@bvg.desandra',
#  'manuel',
#  '2023die',
#  'gounod-',
#  'bvg-spielzeugen',
#  'verwurzelung',
#  'minimalen',
#  'st-vitrinen',
#  'einsatzorten',
#  'zugleich.die',
#  'forschungsprojekts',
#  'anschließenden,',
#  'vertragsstrafen.\xa0\xa0„diese',
#  'ullsteinhaus',
#  'erinnern',
#  'nehmen.“\xa0\xa0',
#  'einfacher.',
#  'campaign.',
#  '11.03.2020.',
#  'start-ups,',
#  'frühschicht.„als',
#  'mehringdamm2x',
#  'benannt.der',
#  'vollbahnen',
#  'u-bahnflotte,',
#  'umsetzbar',
#  'träumen',
#  'impfungen',
#  'straßenebene.der',
#  'geordnetes',
#  '28.10.2019',
#  'steglitz\u202fkein',
#  'zeitgemäß,',
#  'navigiert',
#  'highspeed-internet',
#  'bvg-chefin',
#  'an.\xa0die',
#  'buckelbleche,',
#  'gesundheitswesen',
#  'führerschein.',
#  '28.10.2019.',
#  'tram-em',
#  'indira-gandhi-straßeindira-gandhi-straße',
#  'brückeneinhub',
#  'doppeldeckomnibussen',
#  'umgeleitete',
#  '100.000.',
#  'regulärer',
#  'sitzmuster.',
#  'busspuren,',
#  'humor',
#  'selbstlernender',
#  'straße\u202fund\u202fu\u202fgüntzelstraße\u202ffährt',
#  'farben.nach',
#  'gleisebene',
#  'entschieden.„mit',
#  'monaten.„uns',
#  'reliefs',
#  'verweise',
#  'innovationsbusses',
#  'u1/u3,',
#  '10-uhr-karte',
#  'aus.bereits',
#  '„easymile',
#  'u-bahntyps',
#  'tonnenantriebantriebsleistung:',
#  'bürgerdienste,',
#  'auszeichnungen.prämiert',
#  'mitzubringen',
#  'teilstrecken,',
#  'takte.im',
#  '„auf',
#  'gebohrt',
#  'beschichtet.',
#  'mrawietz,',
#  'möllendorffstraße/storkower',
#  'beendet.für',
#  'gubener',
#  'fachmännisch',
#  'verkehrsangeboten',
#  'kategorien,',
#  'gleiserneuerung',
#  'umwelthilfe',
#  '\xa0\xa0\xa0\xa0\xa0verkehr',
#  'treuen',
#  'untertage',
#  'siemens-ladestation',
#  '24.08.2020.',
#  'pflegebedürftige',
#  'kultobjekt',
#  'fußläufig',
#  'dörpfeldstraße',
#  'u\u202fosloer',
#  'hotel',
#  'teams10:30',
#  'belastet.',
#  'schienenfahrzeughersteller',
#  'umleitungsverkehr',
#  'siemensstraße,',
#  'drei.für',
#  'hatten.',
#  'fahren.um',
#  'steinberg,',
#  'akzeptanzstudie',
#  'spots',
#  'umsteigerelationen.die',
#  'berlin.“dank',
#  'u-bahn-sparte',
#  'minuten.rund',
#  'kurzüberblickmercedes-benz',
#  'jahrdie',
#  'berlin-mitte.',
#  'abschnitte,',
#  'bus-fahrgäste',
#  'um.\xa0seit',
#  'e-fahrzeuge',
#  'produziert.alle',
#  'vorarbeit',
#  'björnsonstraße,',
#  'gebäudes',
#  'visier.',
#  'mitreisende',
#  'öffentlichkeitsarbeitparitätischer',
#  'ggmbh:',
#  'frauenticket',
#  'n8',
#  'auskommt.',
#  'klang.“premiere',
#  'erhält.bvg-fahrinfo-app:',
#  'bvg-wegeleitsystems,',
#  'offensive.',
#  'wird.“\xa0susanne',
#  'direktverbindung.die',
#  'verkehrserhebung',
#  'persönlichkeit.',
#  'wird.“bereits',
#  'marktentwicklung',
#  'bmu',
#  'längerdie',
#  'handbikern',
#  'können.die',
#  'gelegt.zu',
#  'männer.das',
#  'schätze',
#  'geöffnet.kein',
#  'reykjavik,',
#  'hirschhausen,',
#  'toiletten,',
#  'informieren.bis',
#  'berlintel.:',
#  'fahrgastverkehr',
#  'muss.also',
#  'gepackt.“\xa0ronny',
#  'freimachen!“',
#  'fahrinfo“-app.',
#  'gebrannten',
#  'büschingstraße.',
#  'kinderkarneval',
#  'hühnerbein',
#  'mix',
#  'präsentieren.die',
#  '94zauter@paritaet-berlin.de',
#  'garantieren',
#  'steht.mit',
#  'vorbei,',
#  'stärken.“dr.',
#  '„liebe',
#  'smartphone-basierte',
#  'heckerdamm',
#  'sonntagmorgen.',
#  '3594',
#  'verfahrens,',
#  'op',
#  'fahrzeugge-neration',
#  'krisen-alltag.\xa0doch',
#  'komponisten',
#  'uhr.schon',
#  'sollen.regine',
#  'akzeptiert',
#  'bautrupps',
#  'werden.weitere',
#  'clou',
#  'begleiten.eine',
#  'fördernden',
#  'gefühl,',
#  'erfüllt.',
#  'hauptstadt.während',
#  'foto',
#  'lgbti*',
#  'hilfreich,',
#  'wonneberger',
#  'forschungsprojekt',
#  'gespeichert',
#  'nachtruhe',
#  'leistet',
#  'ausnahmesituation,',
#  'poelchaustraße:',
#  'kmu-bereich',
#  'bvg-verhandlungsführerin.die',
#  'kamila',
#  'servicestandorten',
#  'u7.\xa0der',
#  'sein.„die',
#  'europas,',
#  'projektvolumen',
#  '30.08.2019.',
#  'u-bahnabschnitts',
#  'regulärgute',
#  '(fahrtrichtung',
#  'jetzt.berlin',
#  'wasser.“und',
#  'ablagemöglichkeiten',
#  '110)bus',
#  'bekannt.neben',
#  'sharing-modelle,',
#  'auftragseingang',
#  'cicerostraße.geimpft',
#  'sitzung.\xa0das',
#  'fahrzeuge.auf',
#  'coaches,familien',
#  'beschleunigung“',
#  'valderasprag,',
#  'bahnhofsmodernisierung.',
#  'breitenbach,',
#  'innovationspreis',
#  'auszuwählen',
#  'straßenland.die',
#  'gt6,',
#  'einlegen.',
#  'berlin.dass',
#  'wohngebiete.das',
#  'tragen.die',
#  'gönnen.',
#  'buses,',
#  'ist.“in',
#  'tunneldecken',
#  'können.“hintergrund',
#  'osten,',
#  '09.11.2018.\xa0ab',
#  'verfolgten',
#  'steglitz4x',
#  '23.06.2020.',
#  'venture',
#  'eqt-fans',
#  'abweichungen',
#  'simon',
#  'freitag/samstag',
#  'beson-dere',
#  'berufsausbildung.',
#  'regelfahrplan.',
#  'istván',
#  'viktoria-luise-platz',
#  'eingerichtet.und',
#  'wasserbetriebeband',
#  '13.09.2018.',
#  'gegeben.“auch',
#  'aussprechen',
#  'enorm“,',
#  'ausstadler',
#  'halten.\u200bfahrgäste',
#  'praxisnah',
#  'soziologie',
#  'fahrpläne,',
#  'schöneweide.eine',
#  'wartungstrupps',
#  'kontroverse',
#  'betriebsschluss:',
#  'collignon,',
#  'werden.dank',
#  'plattform-app.',
#  'fahrtendie',
#  'instandhaltungsfristen,',
#  'prozent.auch',
#  'ablesbar.',
#  'hönow.für',
#  'darüber.u2',
#  'verputzt',
#  'ralf',
#  'etge',
#  'muvain',
#  'martina',
#  'zusammenarbeit.“jenny',
#  'weit:',
#  'tun“,',
#  'nutzerfreundlicher',
#  'freigegeben.zwischen',
#  'ausgang.als',
#  'halten.“das',
#  'hervorragenden',
#  'aufgestellt?',
#  'malhefte',
#  'panke',
#  '12.auf',
#  'future“',
#  'lokale,',
#  'zurückzugreifen.',
#  'fahrzeugflotten',
#  'vorzeigebetrieb',
#  'halemweg',
#  'geboren',
#  'ersetzt.aktuell',
#  'omnibusbestellungen',
#  'hinweg,',
#  'weiter.„groß',
#  'verknüpft',
#  'gesellschaftsverantwortung“)',
#  'gesunkenen',
#  '1060',
#  'wasserbetrieben',
#  'verkehrsinfrastruktur.',
#  'können.im',
#  'anspruchsvoll',
#  'meldeten',
#  'nutzenmit',
#  'metro-modus.',
#  'gsm-basisstationen,',
#  'geschäftspartner',
#  'dafür.',
#  'weberweise',
#  'angefahren.zu',
#  'frankfurt',
#  'noch!',
#  'einsatzfähigen',
#  'faktendie',
#  'tools',
#  'radelnden',
#  '(nahe',
#  'begonnenen',
#  '„digitales',
#  'dankbarkeit',
#  '„hätten',
#  'anmeldung,',
#  'verlagert.',
#  'km.',
#  'teilnehmer',
#  '2020alle',
#  'übertragen.\xa0facebookhttps://www.facebook.com/bus-em-european-busdriver-championship-169972920392670/\xa0\xa0hinweis',
#  'werden.m5,',
#  'farbton',
#  'absolvieren.wie',
#  'plakaten,',
#  'getrennte',
#  'bezahlen,',
#  ...}

# %%
# Pfade
INPUT_FOLDER = os.path.join("..", "input", "pm_bvg_raw")
OUTPUT_FOLDER = os.path.join("..", "output")

# %%
# Als SQLite-Datenbank speichern
SQL_CLEAN_PATH = os.path.join(OUTPUT_FOLDER, "dwh_pm_bvg.sqlite3")
conn = sqlite3.connect(SQL_CLEAN_PATH)
df_all.to_sql("wordcount_pm_clean", conn, if_exists="replace", index=False)
conn.close()

print(f"Bereinigte Wortzählung gespeichert unter: {SQL_CLEAN_PATH}")
# Out:
# Bereinigte Wortzählung gespeichert unter: ..\output\dwh_pm_bvg.sqlite3

# %%
# Prüfung Tabellen in Datenbank
# Verbindung zur Datenbank aufbauen
conn = sqlite3.connect(os.path.join(OUTPUT_FOLDER, "dwh_pm_bvg.sqlite3"))

# Cursor-Objekt erstellen
cursor = conn.cursor()

# Abfrage: Alle Tabellennamen aus der Datenbank holen
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")

# Ergebnis holen
tables = cursor.fetchall()

# Tabellen ausgeben
print("Tabellen in der Datenbank:")
for table in tables:
    print(table[0])

# Verbindung schließen
conn.close()
# Out:
# Tabellen in der Datenbank:
# pm_bvg_valid
# wordcount_pm
# wordcount_pm_clean
